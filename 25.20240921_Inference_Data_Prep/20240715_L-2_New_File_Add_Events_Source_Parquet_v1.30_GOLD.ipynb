# %% [markdown]
# # <font color = lightcoral>Prepare Additional Data
# >
# #### <font color = red> Source_Master_Appendix with event shortlist concatanted with template description
#
# **20240715_flask_app_model_change_v1.00.py**
#
# > FYI only --> Note the change in transformer model (for higher precision)
# >

# %% [markdown]
# ![image.png](attachment:1bfb110c-7de7-4e1e-8208-aa88324962fe.png)

# %% [markdown]
# ## <font color = grey> Admin

# %%
import pandas as pd
import os
import gzip
import time
import warnings
import os
import shutil
from datetime import datetime
import time
# Set display option to show the full length of the column
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore")

# Determine the base directory based on the effective user ID
if os.geteuid() == 0:  # root user
    base_dir = '/root'
else:
    base_dir = '/home/sagemaker-user'

# Set the environment variable
os.environ['BASE_DIR'] = base_dir

# Verify the base directory
print(f"Base directory set to: {base_dir}")

import warnings
warnings.simplefilter("ignore")
# Out:
# Base directory set to: /home/sagemaker-user

# %% [markdown]
# ---

# %% [markdown]
# # <font color = lightsteelblue> 5 Key Files

# %%
import pandas as pd
import numpy as np
import time

data_dir = '/home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files'

################################## Part 1: Parsed Raw File ###################################

print("\n" + "*"*100)
print("********************** Part 1: Parsed Raw File ******************************************")
print("*"*100 + "\n")

parsed_file =  f"{data_dir}/01.BGL.log_structured.csv"
parsed_file_df = pd.read_csv(parsed_file)
display(parsed_file_df.head())
print("Shape of Parsed Raw File:", parsed_file_df.shape)

######################### Part 2: Encoded File with Feature for Model Training ######################

print("\n" + "*"*100)
print("********************** Part 2: Input Data with Features ******************************************")
print("*"*100 + "\n")

encoded_feature_input_file = f"{data_dir}/03.20240715_143154_orig_input_w_seq_mapping_master_FINAL.parquet"
encoded_feature_input_file_df = pd.read_parquet(encoded_feature_input_file)
display(encoded_feature_input_file_df.iloc[:, :25].head())
print("Shape of Encoded File with Features:", encoded_feature_input_file_df.shape)

######################### Part 3: Encoded File where Train_Test = Test HEAD ###############################

print("\n" + "*"*100)
print("********************** Part 3: Test Set - HEAD *******************************")
print("*"*100 + "\n")

encoded_feature_input_test_df = encoded_feature_input_file_df[encoded_feature_input_file_df['Train_Test'] == 'Test']
display(encoded_feature_input_test_df.iloc[:, :25].head(10))
print("Shape of Encoded File where Train_Test = Test:", encoded_feature_input_test_df.shape)


######################### Part 4: Encoded File where Train_Test = Test MIDDLE ###############################

# Part 4: Encoded File where Train_Test = Test (Records 100-200)
print("\n" + "*"*100)
print("********************** Part 4: Test Set - Records 100-200 *******************************")
print("*"*100 + "\n")


encoded_feature_input_test_df = encoded_feature_input_file_df[encoded_feature_input_file_df['Train_Test'] == 'Test']
display(encoded_feature_input_test_df.iloc[100:110, :25])
print("Shape of Encoded File where Train_Test = Test:", encoded_feature_input_test_df.shape)

######################### Part 5: Encoded File where Train_Test = Test TAIL ###############################

print("\n" + "*"*100)
print("********************** Part 5: Test Set - TAIL *******************************")
print("*"*100 + "\n")

encoded_feature_input_test_df = encoded_feature_input_file_df[encoded_feature_input_file_df['Train_Test'] == 'Test']
display(encoded_feature_input_test_df.iloc[:, :25].tail(10))
print("Shape of Encoded File where Train_Test = Test:", encoded_feature_input_test_df.shape)


######################### Part 6: Event_ID to Template Mapping #######################################

print("\n" + "*"*100)
print("********************** Part 6: Event_ID to Template Mapping ******************************************")
print("*"*100 + "\n")

eventid_template_file = f"{data_dir}/04.20240711_Template_to_EventID_Mapping_v1.00.csv"
eventid_template_df = pd.read_csv(eventid_template_file)
display(eventid_template_df.head())
print("Shape of Event_ID to Template Mapping:", eventid_template_df.shape)

######################### Part 7: Event_ID to Encoding Mapping #######################################

print("\n" + "*"*100)
print("********************** Part 7: Event_ID to Encoding Mapping ******************************************")
print("*"*100 + "\n")

eventid_encoding_file = f"{data_dir}/05.20240711_EventID_to_EncodedInteger_Mapping_v1.00.csv"
eventid_encoding_df = pd.read_csv(eventid_encoding_file)
display(eventid_encoding_df.head())
print("Shape of Event_ID to Encoding Mapping:", eventid_encoding_df.shape)

######################### Part 8: First Two Records from X_test and y_test #######################

print("\n" + "*"*100)
print("********************** Part 8: First Two Records from X_test and y_test *****************************")
print("*"*100 + "\n")

file_prefix = "06.20240714_062624_non_overlap_full_test"  # Replace with your actual file prefix

# Load the test data
X_test = np.load(f"{data_dir}/{file_prefix}_X_test.npy")
y_test = np.load(f"{data_dir}/{file_prefix}_y_test.npy")

# Convert the first two records to DataFrames for better display
X_test_first_two = pd.DataFrame(X_test[:2].reshape(-1, X_test.shape[2]))
y_test_first_two = pd.DataFrame(y_test[:2], columns=['Actual'])

# Display the first two records
print("First two records from X_test:")
display(X_test_first_two)

print("\nFirst two records from y_test:")
display(y_test_first_two)
# Out:
# ****************************************************************************************************
# ********************** Part 1: Parsed Raw File ******************************************
# ****************************************************************************************************
#    LineId Label          Id        Date                Code1  \
# 0       1     -  1117838570  2005.06.03  R02-M1-N0-C:J12-U11
# 1       2     -  1117838570  2005.06.03  R02-M1-N0-C:J12-U11
# 2       3     -  1117838570  2005.06.03  R02-M1-N0-C:J12-U11
# 3       4     -  1117838570  2005.06.03  R02-M1-N0-C:J12-U11
# 4       5     -  1117838570  2005.06.03  R02-M1-N0-C:J12-U11
#
#                          Time                Code2 Component1 Component2  \
# 0  2005-06-03-15.42.50.363779  R02-M1-N0-C:J12-U11        RAS     KERNEL
# 1  2005-06-03-15.42.50.527847  R02-M1-N0-C:J12-U11        RAS     KERNEL
# 2  2005-06-03-15.42.50.675872  R02-M1-N0-C:J12-U11        RAS     KERNEL
# 3  2005-06-03-15.42.50.823719  R02-M1-N0-C:J12-U11        RAS     KERNEL
# 4  2005-06-03-15.42.50.982731  R02-M1-N0-C:J12-U11        RAS     KERNEL
#
#   Level                                   Content   EventId  \
# 0  INFO  instruction cache parity error corrected  3aa50e45
# 1  INFO  instruction cache parity error corrected  3aa50e45
# 2  INFO  instruction cache parity error corrected  3aa50e45
# 3  INFO  instruction cache parity error corrected  3aa50e45
# 4  INFO  instruction cache parity error corrected  3aa50e45
#
#                               EventTemplate
# 0  instruction cache parity error corrected
# 1  instruction cache parity error corrected
# 2  instruction cache parity error corrected
# 3  instruction cache parity error corrected
# 4  instruction cache parity error corrected
# Shape of Parsed Raw File: (4713493, 13)
#
# ****************************************************************************************************
# ********************** Part 2: Input Data with Features ******************************************
# ****************************************************************************************************
#    Seq_Num Train_Test          time_start  time_start_int  Class  \
# 0        0      Train 2005-06-03 16:00:00               0      0
# 1        1      Train 2005-06-03 16:05:00               1      0
# 2        2      Train 2005-06-03 16:10:00               2      0
# 3        3      Train 2005-06-03 16:15:00               3      0
# 4        4      Train 2005-06-03 16:25:00               5      0
#
#    unique_events  most_frequent_event  transitions   entropy  hour_of_day  \
# 0              6                  228            6  0.171708           16
# 1              2                  987            2  0.598270           16
# 2              6                  399           18  0.655243           16
# 3              5                  328            6  1.039660           16
# 4              4                  399            3  0.895333           16
#
#    day_of_week  event_count  top_event_frequency  prev_event_count  \
# 0            4          465                35431             913.0
# 1            4            7                35433             465.0
# 2            4           81                35431               7.0
# 3            4           66                35431              81.0
# 4            4           14                35433              66.0
#
#    transition_rate  high_transition_rate  prev_entropy  entropy_change  \
# 0         0.012903                     0      0.000000        0.171708
# 1         0.285714                     0      0.171708        0.426562
# 2         0.222222                     0      0.598270        0.056973
# 3         0.090909                     0      0.655243        0.384418
# 4         0.214286                     0      1.039660       -0.144328
#
#    rolling_event_count  rolling_unique_event_count  EventId_1  EventId_2  \
# 0               4895.0                        18.0        228        228
# 1               4257.0                        19.0        729        987
# 2               2756.0                        23.0        734        430
# 3               1532.0                        25.0        987        987
# 4                633.0                        28.0         95        504
#
#    EventId_3  EventId_4  EventId_5
# 0        228        228        228
# 1        987        987        987
# 2        504         95         95
# 3        987        987        328
# 4        504        399        399
# Shape of Encoded File with Features: (14537, 35453)
#
# ****************************************************************************************************
# ********************** Part 3: Test Set - HEAD *******************************
# ****************************************************************************************************
#        Seq_Num Train_Test          time_start  time_start_int  Class  \
# 11615    11615       Test 2005-11-08 16:10:00           45506      0
# 11616    11616       Test 2005-11-08 16:30:00           45510      0
# 11617    11617       Test 2005-11-08 16:55:00           45515      0
# 11618    11618       Test 2005-11-08 17:25:00           45521      1
# 11619    11619       Test 2005-11-08 17:30:00           45522      0
# 11620    11620       Test 2005-11-08 17:45:00           45525      0
# 11621    11621       Test 2005-11-08 18:25:00           45533      0
# 11622    11622       Test 2005-11-08 18:35:00           45535      0
# 11623    11623       Test 2005-11-08 18:40:00           45536      0
# 11624    11624       Test 2005-11-08 18:50:00           45538      0
#
#        unique_events  most_frequent_event  transitions   entropy  hour_of_day  \
# 11615              1                   68            0  0.000000           16
# 11616              4                  399            9  1.251989           16
# 11617              1                  176            0  0.000000           16
# 11618              2                   74            1  0.693147           17
# 11619              1                  176            0  0.000000           17
# 11620              1                   68            0  0.000000           17
# 11621              3                   95            2  1.098612           18
# 11622              1                   68            0  0.000000           18
# 11623              1                  228            0  0.000000           18
# 11624              2                   68            1  0.500402           18
#
#        day_of_week  event_count  top_event_frequency  prev_event_count  \
# 11615            1            1                35433               8.0
# 11616            1           15                35433               1.0
# 11617            1            1                35433              15.0
# 11618            1         1024                35433               1.0
# 11619            1            1                35433            1024.0
# 11620            1            1                35433               1.0
# 11621            1            3                35433               1.0
# 11622            1            2                35433               3.0
# 11623            1            1                35433               2.0
# 11624            1           10                35433               1.0
#
#        transition_rate  high_transition_rate  prev_entropy  entropy_change  \
# 11615         0.000000                     0      0.000000        0.000000
# 11616         0.600000                     1      0.000000        1.251989
# 11617         0.000000                     0      1.251989       -1.251989
# 11618         0.000977                     0      0.000000        0.693147
# 11619         0.000000                     0      0.693147       -0.693147
# 11620         0.000000                     0      0.000000        0.000000
# 11621         0.666667                     1      0.000000        1.098612
# 11622         0.000000                     0      1.098612       -1.098612
# 11623         0.000000                     0      0.000000        0.000000
# 11624         0.100000                     0      0.000000        0.500402
#
#        rolling_event_count  rolling_unique_event_count  EventId_1  EventId_2  \
# 11615                 26.0                        10.0         68          0
# 11616                 33.0                        13.0         95        399
# 11617                 26.0                        13.0        176          0
# 11618               1049.0                        14.0         74         74
# 11619               1042.0                        14.0        176          0
# 11620               1042.0                        14.0         68          0
# 11621               1030.0                        13.0         95        399
# 11622               1031.0                        13.0         68         68
# 11623                  8.0                        12.0        228          0
# 11624                 17.0                        13.0        504        504
#
#        EventId_3  EventId_4  EventId_5
# 11615          0          0          0
# 11616        399         95         95
# 11617          0          0          0
# 11618         74         74         74
# 11619          0          0          0
# 11620          0          0          0
# 11621         80          0          0
# 11622          0          0          0
# 11623          0          0          0
# 11624         68         68         68
# Shape of Encoded File where Train_Test = Test: (2922, 35453)
#
# ****************************************************************************************************
# ********************** Part 4: Test Set - Records 100-200 *******************************
# ****************************************************************************************************
#        Seq_Num Train_Test          time_start  time_start_int  Class  \
# 11715    11715       Test 2005-11-10 09:40:00           46004      0
# 11716    11716       Test 2005-11-10 10:25:00           46013      0
# 11717    11717       Test 2005-11-10 11:55:00           46031      0
# 11718    11718       Test 2005-11-10 12:10:00           46034      0
# 11719    11719       Test 2005-11-10 13:00:00           46044      0
# 11720    11720       Test 2005-11-10 13:35:00           46051      0
# 11721    11721       Test 2005-11-10 14:10:00           46058      0
# 11722    11722       Test 2005-11-10 14:40:00           46064      0
# 11723    11723       Test 2005-11-10 15:20:00           46072      0
# 11724    11724       Test 2005-11-10 15:50:00           46078      0
#
#        unique_events  most_frequent_event  transitions   entropy  hour_of_day  \
# 11715              1                  976            0  0.000000            9
# 11716              2                  231            1  0.693147           10
# 11717              1                  976            0  0.000000           11
# 11718              7                  399          135  0.675366           12
# 11719              3                   95            2  1.098612           13
# 11720              4                   95            3  1.285293           13
# 11721              5                   95            8  1.526878           14
# 11722              5                   95            5  1.545423           14
# 11723              5                   95            7  1.581094           15
# 11724              4                  763            4  1.377820           15
#
#        day_of_week  event_count  top_event_frequency  prev_event_count  \
# 11715            3            1                35433               1.0
# 11716            3            2                35433               1.0
# 11717            3            1                35433               2.0
# 11718            3          799                35406               1.0
# 11719            3            3                35433             799.0
# 11720            3           13                35433               3.0
# 11721            3           16                35432              13.0
# 11722            3           12                35432              16.0
# 11723            3            9                35432              12.0
# 11724            3           13                35433               9.0
#
#        transition_rate  high_transition_rate  prev_entropy  entropy_change  \
# 11715         0.000000                     0      0.000000        0.000000
# 11716         0.500000                     0      0.000000        0.693147
# 11717         0.000000                     0      0.693147       -0.693147
# 11718         0.168961                     0      0.000000        0.675366
# 11719         0.666667                     1      0.675366        0.423247
# 11720         0.230769                     0      1.098612        0.186681
# 11721         0.500000                     0      1.285293        0.241585
# 11722         0.416667                     0      1.526878        0.018545
# 11723         0.777778                     1      1.545423        0.035671
# 11724         0.307692                     0      1.581094       -0.203274
#
#        rolling_event_count  rolling_unique_event_count  EventId_1  EventId_2  \
# 11715                 91.0                        20.0        976          0
# 11716                 16.0                        17.0        231        976
# 11717                  6.0                        11.0        976          0
# 11718                804.0                        17.0         95         95
# 11719                806.0                        19.0         95        399
# 11720                818.0                        22.0         95         95
# 11721                832.0                        25.0         95        776
# 11722                843.0                        29.0         95         95
# 11723                 53.0                        27.0         95        776
# 11724                 63.0                        28.0         95         95
#
#        EventId_3  EventId_4  EventId_5
# 11715          0          0          0
# 11716          0          0          0
# 11717          0          0          0
# 11718         95        399         95
# 11719         80          0          0
# 11720         95         95        763
# 11721         95         95         95
# 11722         95        776        399
# 11723         95        763        399
# 11724         95        763        763
# Shape of Encoded File where Train_Test = Test: (2922, 35453)
#
# ****************************************************************************************************
# ********************** Part 5: Test Set - TAIL *******************************
# ****************************************************************************************************
#        Seq_Num Train_Test          time_start  time_start_int  Class  \
# 14527    14527       Test 2006-01-04 01:10:00           61742      0
# 14528    14528       Test 2006-01-04 01:15:00           61743      0
# 14529    14529       Test 2006-01-04 04:45:00           61785      0
# 14530    14530       Test 2006-01-04 07:25:00           61817      0
# 14531    14531       Test 2006-01-04 07:30:00           61818      0
# 14532    14532       Test 2006-01-04 07:35:00           61819      0
# 14533    14533       Test 2006-01-04 07:40:00           61820      0
# 14534    14534       Test 2006-01-04 07:45:00           61821      0
# 14535    14535       Test 2006-01-04 07:50:00           61822      0
# 14536    14536       Test 2006-01-04 08:00:00           61824      1
#
#        unique_events  most_frequent_event  transitions   entropy  hour_of_day  \
# 14527              2                  193            1  0.693147            1
# 14528              6                  812            7  1.529248            1
# 14529              1                  228            0  0.000000            4
# 14530              3                  647           13  1.058508            7
# 14531              2                  193            3  0.693147            7
# 14532              1                  606            0  0.000000            7
# 14533              6                  156            5  1.609438            7
# 14534              2                  193            1  0.693147            7
# 14535              3                  156            2  1.039721            7
# 14536              1                   99            0  0.000000            8
#
#        day_of_week  event_count  top_event_frequency  prev_event_count  \
# 14527            2            2                35433               2.0
# 14528            2           15                35431               2.0
# 14529            2            1                35433              15.0
# 14530            2           32                35433               1.0
# 14531            2            4                35433              32.0
# 14532            2            1                35433               4.0
# 14533            2           10                35431               1.0
# 14534            2            2                35433              10.0
# 14535            2            4                35433               2.0
# 14536            2            8                35433               4.0
#
#        transition_rate  high_transition_rate  prev_entropy  entropy_change  \
# 14527         0.500000                     0      0.693147        0.000000
# 14528         0.466667                     0      0.693147        0.836101
# 14529         0.000000                     0      1.529248       -1.529248
# 14530         0.406250                     0      0.000000        1.058508
# 14531         0.750000                     1      1.058508       -0.365360
# 14532         0.000000                     0      0.693147       -0.693147
# 14533         0.500000                     0      0.000000        1.609438
# 14534         0.500000                     0      1.609438       -0.916291
# 14535         0.500000                     0      0.693147        0.346574
# 14536         0.000000                     0      1.039721       -1.039721
#
#        rolling_event_count  rolling_unique_event_count  EventId_1  EventId_2  \
# 14527                  9.0                        14.0        193        556
# 14528                 23.0                        19.0        258        156
# 14529                 22.0                        18.0        228          0
# 14530                 52.0                        19.0        647        647
# 14531                 54.0                        19.0        193        556
# 14532                 53.0                        18.0        606          0
# 14533                 48.0                        18.0        812        647
# 14534                 49.0                        19.0        193        556
# 14535                 21.0                        19.0        193        556
# 14536                 25.0                        18.0         99         99
#
#        EventId_3  EventId_4  EventId_5
# 14527          0          0          0
# 14528        156        812        812
# 14529          0          0          0
# 14530        812        812        812
# 14531        193        556          0
# 14532          0          0          0
# 14533        647        258        193
# 14534          0          0          0
# 14535        156        156          0
# 14536         99         99         99
# Shape of Encoded File where Train_Test = Test: (2922, 35453)
#
# ****************************************************************************************************
# ********************** Part 6: Event_ID to Template Mapping ******************************************
# ****************************************************************************************************
#     EventId  \
# 0  3aa50e45
# 1  b9250ad9
# 2  fc5f0940
# 3  1840cbfe
# 4  828a502b
#
#                                                                       EventTemplate  \
# 0                                          instruction cache parity error corrected
# 1  MidplaneSwitchController performing bit sparing on R<*>-M<*>-L<*>-U<*>-C bit <*>
# 2                                                               generating core.<*>
# 3         <*> ddr errors(s) detected and corrected on rank <*>, symbol <*>, bit <*>
# 4                             <*> <*> <*> error(s) (dcr <*>) detected and corrected
#
#    Occurrences
# 0       105924
# 1          964
# 2      1706751
# 3        33939
# 4         5040
# Shape of Event_ID to Template Mapping: (1000, 3)
#
# ****************************************************************************************************
# ********************** Part 7: Event_ID to Encoding Mapping ******************************************
# ****************************************************************************************************
#     EventId  EncodedValue
# 0  0025df56             0
# 1  0045c3a8             1
# 2  004a68ba             2
# 3  00980b01             3
# 4  00d49120             4
# Shape of Event_ID to Encoding Mapping: (1000, 2)
#
# ****************************************************************************************************
# ********************** Part 8: First Two Records from X_test and y_test *****************************
# ****************************************************************************************************
#
# First two records from X_test:
#          0         1      2         3         4         5         6   \
# 0   45510.0 -0.364160   11.0 -0.072711 -0.866508  0.596130 -0.952078
# 1   45514.0  0.104469   80.0 -0.057064  1.006346  0.596130 -0.952078
# 2   45519.0 -0.364160   41.0 -0.072711 -0.866508  0.596130 -0.952078
# 3   45525.0 -0.207950   13.0 -0.070972  0.170372  0.751345 -0.952078
# 4   45526.0 -0.364160   41.0 -0.072711 -0.866508  0.751345 -0.952078
# 5   45529.0 -0.364160   11.0 -0.072711 -0.866508  0.751345 -0.952078
# 6   45537.0 -0.051740   20.0 -0.069234  0.776909  0.906560 -0.952078
# 7   45539.0 -0.364160   11.0 -0.072711 -0.866508  0.906560 -0.952078
# 8   45540.0 -0.364160   49.0 -0.072711 -0.866508  0.906560 -0.952078
# 9   45542.0 -0.207950   11.0 -0.070972 -0.117955  0.906560 -0.952078
# 10  45544.0  0.416889   80.0 -0.025770 -0.226906  1.061775 -0.952078
# 21  113.573195
# 22   33.563072
# 23    6.906228
# 24    6.906228
# 25  -17.147523
# 26    6.906228
# 27   88.012914
# 28   27.656285
# 29    6.906228
# 30    6.906228
# 31    9.815895
# 32  -98.485269
# 33   16.057502
# 34   23.897420
# 35   -1.432371
# 36   27.656285
# 37  -72.653864
# 38  113.573195
# 39   33.563072
# First two records from y_test:
#    Actual
# 0     0.0
# 1     0.0

# %% [markdown]
# # <font color = blue> Create new Source Appendix File with event ID level Detail for Agent Use Only
# ### <font color = blue> One Time Only
#
# ![image.png](attachment:9b2dc1a7-761a-4d12-89e8-78d1744ba683.png)

# %%
# thanks, I intend for this file to be a mapping file (with actual event ids) as well, so would like to reserve 20 columns for each row in order of frequency in that row

# so for example, for seq_num = 1223, I would like to add the following columns:

# ***** Task 1 ********

# 10 columns for most_frequent_events (most_frequent_event_1, ...)
# 1 column for most_frequent_sequence_2_events
# 1 column for most_frequent_sequence_3_events
# 1 column for most_frequent_sequence_4_events

# ***** Task 2 ********

# 10 columns for least frequent events (least_frequent_event_1, ..)
# 1 column for least_frequent_sequence_2_events
# 1 column for least_frequent_sequence_3_events
# 1 column for least_frequent_sequence_4_events

# ***** Task 3 ********

# identify top 10 rare events and print them out
# add a column called rare_event_present (as 0 or 1)
# add 10 columns called rare_event_1, 2, ...

# Please give me the code in stages starting with task 1. We can then move on to Task 2 and so on

# Please save the new file as 03B<timestamp>orig_input_event_list_mapper

# %% [markdown]
# # Task 1: Adding Most Frequent Events and Sequences
# ## Part 1: Setup and Helper Functions
#
# **Process**
# * Original Source File with all EventIDs - 35k: <font color = red>03.20240715_143154_orig_input_w_seq_info_FINAL.parquet
#
# * Master Tracking File for Mapping (only selected EventIDs): <font color = red>03B.20240716_072206_orig_parquet_mapper_agents.parquet

# %%
import pandas as pd
from collections import Counter
import itertools
from datetime import datetime

data_dir = '/home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files'
encoded_feature_input_file = f"{data_dir}/03.20240715_143154_orig_input_w_seq_info_FINAL.parquet"
encoded_feature_input_file_df = pd.read_parquet(encoded_feature_input_file)

# Event ID columns
event_id_columns = [col for col in encoded_feature_input_file_df.columns if col.startswith('EventId_')]

# Function to get the most frequent events in a row
def get_most_frequent_events(row, top_n=10):
    event_counter = Counter(row[event_id_columns])
    most_common_events = event_counter.most_common(top_n)
    return [event for event, count in most_common_events]

# Function to get the most frequent sequences in a row
def get_most_frequent_sequence(row, n):
    sequences = [tuple(row[event_id_columns][i:i+n]) for i in range(len(row[event_id_columns]) - n + 1)]
    sequence_counter = Counter(sequences)
    if sequence_counter:
        return sequence_counter.most_common(1)[0][0]
    else:
        return tuple([None] * n)

# %% [markdown]
# ## Part 2: Adding 10 Most Frequent Events Columns

# %%
for i in range(1, 11):
    column_name = f'most_frequent_event_{i}'
    print(f"Processing {column_name}")
    encoded_feature_input_file_df[column_name] = None  # Initialize column

    for index, row in encoded_feature_input_file_df.iterrows():
        most_frequent_events = get_most_frequent_events(row)
        if i-1 < len(most_frequent_events):
            encoded_feature_input_file_df.at[index, column_name] = most_frequent_events[i-1]
        
        if (index + 1) % 100 == 0:
            print(f"Processed {index + 1} rows for {column_name}")

    # Save after processing each column
    timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
    intermediate_file = f"{data_dir}/03B{timestamp}_step_most_frequent_events.parquet"
    encoded_feature_input_file_df.to_parquet(intermediate_file, index=False)
    print(f"Intermediate file saved: {intermediate_file}")
# Out:
# Processing most_frequent_event_1
# Processed 100 rows for most_frequent_event_1
# Processed 200 rows for most_frequent_event_1
# Processed 300 rows for most_frequent_event_1
# Processed 400 rows for most_frequent_event_1
# Processed 500 rows for most_frequent_event_1
# Processed 600 rows for most_frequent_event_1
# Processed 700 rows for most_frequent_event_1
# Processed 800 rows for most_frequent_event_1
# Processed 900 rows for most_frequent_event_1
# Processed 1000 rows for most_frequent_event_1
# Processed 1100 rows for most_frequent_event_1
# Processed 1200 rows for most_frequent_event_1
# Processed 1300 rows for most_frequent_event_1
# Processed 1400 rows for most_frequent_event_1
# Processed 1500 rows for most_frequent_event_1
# Processed 1600 rows for most_frequent_event_1
# Processed 1700 rows for most_frequent_event_1
# Processed 1800 rows for most_frequent_event_1
# Processed 1900 rows for most_frequent_event_1
# Processed 2000 rows for most_frequent_event_1
# Processed 2100 rows for most_frequent_event_1
# Processed 2200 rows for most_frequent_event_1
# Processed 2300 rows for most_frequent_event_1
# Processed 2400 rows for most_frequent_event_1
# Processed 2500 rows for most_frequent_event_1
# Processed 2600 rows for most_frequent_event_1
# Processed 2700 rows for most_frequent_event_1
# Processed 2800 rows for most_frequent_event_1
# Processed 2900 rows for most_frequent_event_1
# Processed 3000 rows for most_frequent_event_1
# Processed 3100 rows for most_frequent_event_1
# Processed 3200 rows for most_frequent_event_1
# Processed 3300 rows for most_frequent_event_1
# Processed 3400 rows for most_frequent_event_1
# Processed 3500 rows for most_frequent_event_1
# Processed 3600 rows for most_frequent_event_1
# Processed 3700 rows for most_frequent_event_1
# Processed 3800 rows for most_frequent_event_1
# Processed 3900 rows for most_frequent_event_1
# Processed 4000 rows for most_frequent_event_1
# Processed 4100 rows for most_frequent_event_1
# Processed 4200 rows for most_frequent_event_1
# Processed 4300 rows for most_frequent_event_1
# Processed 4400 rows for most_frequent_event_1
# Processed 4500 rows for most_frequent_event_1
# Processed 4600 rows for most_frequent_event_1
# Processed 4700 rows for most_frequent_event_1
# Processed 4800 rows for most_frequent_event_1
# Processed 4900 rows for most_frequent_event_1
# Processed 5000 rows for most_frequent_event_1
# Processed 5100 rows for most_frequent_event_1
# Processed 5200 rows for most_frequent_event_1
# Processed 5300 rows for most_frequent_event_1
# Processed 5400 rows for most_frequent_event_1
# Processed 5500 rows for most_frequent_event_1
# Processed 5600 rows for most_frequent_event_1
# Processed 5700 rows for most_frequent_event_1
# Processed 5800 rows for most_frequent_event_1
# Processed 5900 rows for most_frequent_event_1
# Processed 6000 rows for most_frequent_event_1
# Processed 6100 rows for most_frequent_event_1
# Processed 6200 rows for most_frequent_event_1
# Processed 6300 rows for most_frequent_event_1
# Processed 6400 rows for most_frequent_event_1
# Processed 6500 rows for most_frequent_event_1
# Processed 6600 rows for most_frequent_event_1
# Processed 6700 rows for most_frequent_event_1
# Processed 6800 rows for most_frequent_event_1
# Processed 6900 rows for most_frequent_event_1
# Processed 7000 rows for most_frequent_event_1
# Processed 7100 rows for most_frequent_event_1
# Processed 7200 rows for most_frequent_event_1
# Processed 7300 rows for most_frequent_event_1
# Processed 7400 rows for most_frequent_event_1
# Processed 7500 rows for most_frequent_event_1
# Processed 7600 rows for most_frequent_event_1
# Processed 7700 rows for most_frequent_event_1
# Processed 7800 rows for most_frequent_event_1
# Processed 7900 rows for most_frequent_event_1
# Processed 8000 rows for most_frequent_event_1
# Processed 8100 rows for most_frequent_event_1
# Processed 8200 rows for most_frequent_event_1
# Processed 8300 rows for most_frequent_event_1
# Processed 8400 rows for most_frequent_event_1
# Processed 8500 rows for most_frequent_event_1
# Processed 8600 rows for most_frequent_event_1
# Processed 8700 rows for most_frequent_event_1
# Processed 8800 rows for most_frequent_event_1
# Processed 8900 rows for most_frequent_event_1
# Processed 9000 rows for most_frequent_event_1
# Processed 9100 rows for most_frequent_event_1
# Processed 9200 rows for most_frequent_event_1
# Processed 9300 rows for most_frequent_event_1
# Processed 9400 rows for most_frequent_event_1
# Processed 9500 rows for most_frequent_event_1
# Processed 9600 rows for most_frequent_event_1
# Processed 9700 rows for most_frequent_event_1
# Processed 9800 rows for most_frequent_event_1
# Processed 9900 rows for most_frequent_event_1
# Processed 10000 rows for most_frequent_event_1
# Processed 10100 rows for most_frequent_event_1
# Processed 10200 rows for most_frequent_event_1
# Processed 10300 rows for most_frequent_event_1
# Processed 10400 rows for most_frequent_event_1
# Processed 10500 rows for most_frequent_event_1
# Processed 10600 rows for most_frequent_event_1
# Processed 10700 rows for most_frequent_event_1
# Processed 10800 rows for most_frequent_event_1
# Processed 10900 rows for most_frequent_event_1
# Processed 11000 rows for most_frequent_event_1
# Processed 11100 rows for most_frequent_event_1
# Processed 11200 rows for most_frequent_event_1
# Processed 11300 rows for most_frequent_event_1
# Processed 11400 rows for most_frequent_event_1
# Processed 11500 rows for most_frequent_event_1
# Processed 11600 rows for most_frequent_event_1
# Processed 11700 rows for most_frequent_event_1
# Processed 11800 rows for most_frequent_event_1
# Processed 11900 rows for most_frequent_event_1
# Processed 12000 rows for most_frequent_event_1
# Processed 12100 rows for most_frequent_event_1
# Processed 12200 rows for most_frequent_event_1
# Processed 12300 rows for most_frequent_event_1
# Processed 12400 rows for most_frequent_event_1
# Processed 12500 rows for most_frequent_event_1
# Processed 12600 rows for most_frequent_event_1
# Processed 12700 rows for most_frequent_event_1
# Processed 12800 rows for most_frequent_event_1
# Processed 12900 rows for most_frequent_event_1
# Processed 13000 rows for most_frequent_event_1
# Processed 13100 rows for most_frequent_event_1
# Processed 13200 rows for most_frequent_event_1
# Processed 13300 rows for most_frequent_event_1
# Processed 13400 rows for most_frequent_event_1
# Processed 13500 rows for most_frequent_event_1
# Processed 13600 rows for most_frequent_event_1
# Processed 13700 rows for most_frequent_event_1
# Processed 13800 rows for most_frequent_event_1
# Processed 13900 rows for most_frequent_event_1
# Processed 14000 rows for most_frequent_event_1
# Processed 14100 rows for most_frequent_event_1
# Processed 14200 rows for most_frequent_event_1
# Processed 14300 rows for most_frequent_event_1
# Processed 14400 rows for most_frequent_event_1
# Processed 14500 rows for most_frequent_event_1
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716061007_step_most_frequent_events.parquet
# Processing most_frequent_event_2
# Processed 100 rows for most_frequent_event_2
# Processed 200 rows for most_frequent_event_2
# Processed 300 rows for most_frequent_event_2
# Processed 400 rows for most_frequent_event_2
# Processed 500 rows for most_frequent_event_2
# Processed 600 rows for most_frequent_event_2
# Processed 700 rows for most_frequent_event_2
# Processed 800 rows for most_frequent_event_2
# Processed 900 rows for most_frequent_event_2
# Processed 1000 rows for most_frequent_event_2
# Processed 1100 rows for most_frequent_event_2
# Processed 1200 rows for most_frequent_event_2
# Processed 1300 rows for most_frequent_event_2
# Processed 1400 rows for most_frequent_event_2
# Processed 1500 rows for most_frequent_event_2
# Processed 1600 rows for most_frequent_event_2
# Processed 1700 rows for most_frequent_event_2
# Processed 1800 rows for most_frequent_event_2
# Processed 1900 rows for most_frequent_event_2
# Processed 2000 rows for most_frequent_event_2
# Processed 2100 rows for most_frequent_event_2
# Processed 2200 rows for most_frequent_event_2
# Processed 2300 rows for most_frequent_event_2
# Processed 2400 rows for most_frequent_event_2
# Processed 2500 rows for most_frequent_event_2
# Processed 2600 rows for most_frequent_event_2
# Processed 2700 rows for most_frequent_event_2
# Processed 2800 rows for most_frequent_event_2
# Processed 2900 rows for most_frequent_event_2
# Processed 3000 rows for most_frequent_event_2
# Processed 3100 rows for most_frequent_event_2
# Processed 3200 rows for most_frequent_event_2
# Processed 3300 rows for most_frequent_event_2
# Processed 3400 rows for most_frequent_event_2
# Processed 3500 rows for most_frequent_event_2
# Processed 3600 rows for most_frequent_event_2
# Processed 3700 rows for most_frequent_event_2
# Processed 3800 rows for most_frequent_event_2
# Processed 3900 rows for most_frequent_event_2
# Processed 4000 rows for most_frequent_event_2
# Processed 4100 rows for most_frequent_event_2
# Processed 4200 rows for most_frequent_event_2
# Processed 4300 rows for most_frequent_event_2
# Processed 4400 rows for most_frequent_event_2
# Processed 4500 rows for most_frequent_event_2
# Processed 4600 rows for most_frequent_event_2
# Processed 4700 rows for most_frequent_event_2
# Processed 4800 rows for most_frequent_event_2
# Processed 4900 rows for most_frequent_event_2
# Processed 5000 rows for most_frequent_event_2
# Processed 5100 rows for most_frequent_event_2
# Processed 5200 rows for most_frequent_event_2
# Processed 5300 rows for most_frequent_event_2
# Processed 5400 rows for most_frequent_event_2
# Processed 5500 rows for most_frequent_event_2
# Processed 5600 rows for most_frequent_event_2
# Processed 5700 rows for most_frequent_event_2
# Processed 5800 rows for most_frequent_event_2
# Processed 5900 rows for most_frequent_event_2
# Processed 6000 rows for most_frequent_event_2
# Processed 6100 rows for most_frequent_event_2
# Processed 6200 rows for most_frequent_event_2
# Processed 6300 rows for most_frequent_event_2
# Processed 6400 rows for most_frequent_event_2
# Processed 6500 rows for most_frequent_event_2
# Processed 6600 rows for most_frequent_event_2
# Processed 6700 rows for most_frequent_event_2
# Processed 6800 rows for most_frequent_event_2
# Processed 6900 rows for most_frequent_event_2
# Processed 7000 rows for most_frequent_event_2
# Processed 7100 rows for most_frequent_event_2
# Processed 7200 rows for most_frequent_event_2
# Processed 7300 rows for most_frequent_event_2
# Processed 7400 rows for most_frequent_event_2
# Processed 7500 rows for most_frequent_event_2
# Processed 7600 rows for most_frequent_event_2
# Processed 7700 rows for most_frequent_event_2
# Processed 7800 rows for most_frequent_event_2
# Processed 7900 rows for most_frequent_event_2
# Processed 8000 rows for most_frequent_event_2
# Processed 8100 rows for most_frequent_event_2
# Processed 8200 rows for most_frequent_event_2
# Processed 8300 rows for most_frequent_event_2
# Processed 8400 rows for most_frequent_event_2
# Processed 8500 rows for most_frequent_event_2
# Processed 8600 rows for most_frequent_event_2
# Processed 8700 rows for most_frequent_event_2
# Processed 8800 rows for most_frequent_event_2
# Processed 8900 rows for most_frequent_event_2
# Processed 9000 rows for most_frequent_event_2
# Processed 9100 rows for most_frequent_event_2
# Processed 9200 rows for most_frequent_event_2
# Processed 9300 rows for most_frequent_event_2
# Processed 9400 rows for most_frequent_event_2
# Processed 9500 rows for most_frequent_event_2
# Processed 9600 rows for most_frequent_event_2
# Processed 9700 rows for most_frequent_event_2
# Processed 9800 rows for most_frequent_event_2
# Processed 9900 rows for most_frequent_event_2
# Processed 10000 rows for most_frequent_event_2
# Processed 10100 rows for most_frequent_event_2
# Processed 10200 rows for most_frequent_event_2
# Processed 10300 rows for most_frequent_event_2
# Processed 10400 rows for most_frequent_event_2
# Processed 10500 rows for most_frequent_event_2
# Processed 10600 rows for most_frequent_event_2
# Processed 10700 rows for most_frequent_event_2
# Processed 10800 rows for most_frequent_event_2
# Processed 10900 rows for most_frequent_event_2
# Processed 11000 rows for most_frequent_event_2
# Processed 11100 rows for most_frequent_event_2
# Processed 11200 rows for most_frequent_event_2
# Processed 11300 rows for most_frequent_event_2
# Processed 11400 rows for most_frequent_event_2
# Processed 11500 rows for most_frequent_event_2
# Processed 11600 rows for most_frequent_event_2
# Processed 11700 rows for most_frequent_event_2
# Processed 11800 rows for most_frequent_event_2
# Processed 11900 rows for most_frequent_event_2
# Processed 12000 rows for most_frequent_event_2
# Processed 12100 rows for most_frequent_event_2
# Processed 12200 rows for most_frequent_event_2
# Processed 12300 rows for most_frequent_event_2
# Processed 12400 rows for most_frequent_event_2
# Processed 12500 rows for most_frequent_event_2
# Processed 12600 rows for most_frequent_event_2
# Processed 12700 rows for most_frequent_event_2
# Processed 12800 rows for most_frequent_event_2
# Processed 12900 rows for most_frequent_event_2
# Processed 13000 rows for most_frequent_event_2
# Processed 13100 rows for most_frequent_event_2
# Processed 13200 rows for most_frequent_event_2
# Processed 13300 rows for most_frequent_event_2
# Processed 13400 rows for most_frequent_event_2
# Processed 13500 rows for most_frequent_event_2
# Processed 13600 rows for most_frequent_event_2
# Processed 13700 rows for most_frequent_event_2
# Processed 13800 rows for most_frequent_event_2
# Processed 13900 rows for most_frequent_event_2
# Processed 14000 rows for most_frequent_event_2
# Processed 14100 rows for most_frequent_event_2
# Processed 14200 rows for most_frequent_event_2
# Processed 14300 rows for most_frequent_event_2
# Processed 14400 rows for most_frequent_event_2
# Processed 14500 rows for most_frequent_event_2
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716061623_step_most_frequent_events.parquet
# Processing most_frequent_event_3
# Processed 100 rows for most_frequent_event_3
# Processed 200 rows for most_frequent_event_3
# Processed 300 rows for most_frequent_event_3
# Processed 400 rows for most_frequent_event_3
# Processed 500 rows for most_frequent_event_3
# Processed 600 rows for most_frequent_event_3
# Processed 700 rows for most_frequent_event_3
# Processed 800 rows for most_frequent_event_3
# Processed 900 rows for most_frequent_event_3
# Processed 1000 rows for most_frequent_event_3
# Processed 1100 rows for most_frequent_event_3
# Processed 1200 rows for most_frequent_event_3
# Processed 1300 rows for most_frequent_event_3
# Processed 1400 rows for most_frequent_event_3
# Processed 1500 rows for most_frequent_event_3
# Processed 1600 rows for most_frequent_event_3
# Processed 1700 rows for most_frequent_event_3
# Processed 1800 rows for most_frequent_event_3
# Processed 1900 rows for most_frequent_event_3
# Processed 2000 rows for most_frequent_event_3
# Processed 2100 rows for most_frequent_event_3
# Processed 2200 rows for most_frequent_event_3
# Processed 2300 rows for most_frequent_event_3
# Processed 2400 rows for most_frequent_event_3
# Processed 2500 rows for most_frequent_event_3
# Processed 2600 rows for most_frequent_event_3
# Processed 2700 rows for most_frequent_event_3
# Processed 2800 rows for most_frequent_event_3
# Processed 2900 rows for most_frequent_event_3
# Processed 3000 rows for most_frequent_event_3
# Processed 3100 rows for most_frequent_event_3
# Processed 3200 rows for most_frequent_event_3
# Processed 3300 rows for most_frequent_event_3
# Processed 3400 rows for most_frequent_event_3
# Processed 3500 rows for most_frequent_event_3
# Processed 3600 rows for most_frequent_event_3
# Processed 3700 rows for most_frequent_event_3
# Processed 3800 rows for most_frequent_event_3
# Processed 3900 rows for most_frequent_event_3
# Processed 4000 rows for most_frequent_event_3
# Processed 4100 rows for most_frequent_event_3
# Processed 4200 rows for most_frequent_event_3
# Processed 4300 rows for most_frequent_event_3
# Processed 4400 rows for most_frequent_event_3
# Processed 4500 rows for most_frequent_event_3
# Processed 4600 rows for most_frequent_event_3
# Processed 4700 rows for most_frequent_event_3
# Processed 4800 rows for most_frequent_event_3
# Processed 4900 rows for most_frequent_event_3
# Processed 5000 rows for most_frequent_event_3
# Processed 5100 rows for most_frequent_event_3
# Processed 5200 rows for most_frequent_event_3
# Processed 5300 rows for most_frequent_event_3
# Processed 5400 rows for most_frequent_event_3
# Processed 5500 rows for most_frequent_event_3
# Processed 5600 rows for most_frequent_event_3
# Processed 5700 rows for most_frequent_event_3
# Processed 5800 rows for most_frequent_event_3
# Processed 5900 rows for most_frequent_event_3
# Processed 6000 rows for most_frequent_event_3
# Processed 6100 rows for most_frequent_event_3
# Processed 6200 rows for most_frequent_event_3
# Processed 6300 rows for most_frequent_event_3
# Processed 6400 rows for most_frequent_event_3
# Processed 6500 rows for most_frequent_event_3
# Processed 6600 rows for most_frequent_event_3
# Processed 6700 rows for most_frequent_event_3
# Processed 6800 rows for most_frequent_event_3
# Processed 6900 rows for most_frequent_event_3
# Processed 7000 rows for most_frequent_event_3
# Processed 7100 rows for most_frequent_event_3
# Processed 7200 rows for most_frequent_event_3
# Processed 7300 rows for most_frequent_event_3
# Processed 7400 rows for most_frequent_event_3
# Processed 7500 rows for most_frequent_event_3
# Processed 7600 rows for most_frequent_event_3
# Processed 7700 rows for most_frequent_event_3
# Processed 7800 rows for most_frequent_event_3
# Processed 7900 rows for most_frequent_event_3
# Processed 8000 rows for most_frequent_event_3
# Processed 8100 rows for most_frequent_event_3
# Processed 8200 rows for most_frequent_event_3
# Processed 8300 rows for most_frequent_event_3
# Processed 8400 rows for most_frequent_event_3
# Processed 8500 rows for most_frequent_event_3
# Processed 8600 rows for most_frequent_event_3
# Processed 8700 rows for most_frequent_event_3
# Processed 8800 rows for most_frequent_event_3
# Processed 8900 rows for most_frequent_event_3
# Processed 9000 rows for most_frequent_event_3
# Processed 9100 rows for most_frequent_event_3
# Processed 9200 rows for most_frequent_event_3
# Processed 9300 rows for most_frequent_event_3
# Processed 9400 rows for most_frequent_event_3
# Processed 9500 rows for most_frequent_event_3
# Processed 9600 rows for most_frequent_event_3
# Processed 9700 rows for most_frequent_event_3
# Processed 9800 rows for most_frequent_event_3
# Processed 9900 rows for most_frequent_event_3
# Processed 10000 rows for most_frequent_event_3
# Processed 10100 rows for most_frequent_event_3
# Processed 10200 rows for most_frequent_event_3
# Processed 10300 rows for most_frequent_event_3
# Processed 10400 rows for most_frequent_event_3
# Processed 10500 rows for most_frequent_event_3
# Processed 10600 rows for most_frequent_event_3
# Processed 10700 rows for most_frequent_event_3
# Processed 10800 rows for most_frequent_event_3
# Processed 10900 rows for most_frequent_event_3
# Processed 11000 rows for most_frequent_event_3
# Processed 11100 rows for most_frequent_event_3
# Processed 11200 rows for most_frequent_event_3
# Processed 11300 rows for most_frequent_event_3
# Processed 11400 rows for most_frequent_event_3
# Processed 11500 rows for most_frequent_event_3
# Processed 11600 rows for most_frequent_event_3
# Processed 11700 rows for most_frequent_event_3
# Processed 11800 rows for most_frequent_event_3
# Processed 11900 rows for most_frequent_event_3
# Processed 12000 rows for most_frequent_event_3
# Processed 12100 rows for most_frequent_event_3
# Processed 12200 rows for most_frequent_event_3
# Processed 12300 rows for most_frequent_event_3
# Processed 12400 rows for most_frequent_event_3
# Processed 12500 rows for most_frequent_event_3
# Processed 12600 rows for most_frequent_event_3
# Processed 12700 rows for most_frequent_event_3
# Processed 12800 rows for most_frequent_event_3
# Processed 12900 rows for most_frequent_event_3
# Processed 13000 rows for most_frequent_event_3
# Processed 13100 rows for most_frequent_event_3
# Processed 13200 rows for most_frequent_event_3
# Processed 13300 rows for most_frequent_event_3
# Processed 13400 rows for most_frequent_event_3
# Processed 13500 rows for most_frequent_event_3
# Processed 13600 rows for most_frequent_event_3
# Processed 13700 rows for most_frequent_event_3
# Processed 13800 rows for most_frequent_event_3
# Processed 13900 rows for most_frequent_event_3
# Processed 14000 rows for most_frequent_event_3
# Processed 14100 rows for most_frequent_event_3
# Processed 14200 rows for most_frequent_event_3
# Processed 14300 rows for most_frequent_event_3
# Processed 14400 rows for most_frequent_event_3
# Processed 14500 rows for most_frequent_event_3
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716062251_step_most_frequent_events.parquet
# Processing most_frequent_event_4
# Processed 100 rows for most_frequent_event_4
# Processed 200 rows for most_frequent_event_4
# Processed 300 rows for most_frequent_event_4
# Processed 400 rows for most_frequent_event_4
# Processed 500 rows for most_frequent_event_4
# Processed 600 rows for most_frequent_event_4
# Processed 700 rows for most_frequent_event_4
# Processed 800 rows for most_frequent_event_4
# Processed 900 rows for most_frequent_event_4
# Processed 1000 rows for most_frequent_event_4
# Processed 1100 rows for most_frequent_event_4
# Processed 1200 rows for most_frequent_event_4
# Processed 1300 rows for most_frequent_event_4
# Processed 1400 rows for most_frequent_event_4
# Processed 1500 rows for most_frequent_event_4
# Processed 1600 rows for most_frequent_event_4
# Processed 1700 rows for most_frequent_event_4
# Processed 1800 rows for most_frequent_event_4
# Processed 1900 rows for most_frequent_event_4
# Processed 2000 rows for most_frequent_event_4
# Processed 2100 rows for most_frequent_event_4
# Processed 2200 rows for most_frequent_event_4
# Processed 2300 rows for most_frequent_event_4
# Processed 2400 rows for most_frequent_event_4
# Processed 2500 rows for most_frequent_event_4
# Processed 2600 rows for most_frequent_event_4
# Processed 2700 rows for most_frequent_event_4
# Processed 2800 rows for most_frequent_event_4
# Processed 2900 rows for most_frequent_event_4
# Processed 3000 rows for most_frequent_event_4
# Processed 3100 rows for most_frequent_event_4
# Processed 3200 rows for most_frequent_event_4
# Processed 3300 rows for most_frequent_event_4
# Processed 3400 rows for most_frequent_event_4
# Processed 3500 rows for most_frequent_event_4
# Processed 3600 rows for most_frequent_event_4
# Processed 3700 rows for most_frequent_event_4
# Processed 3800 rows for most_frequent_event_4
# Processed 3900 rows for most_frequent_event_4
# Processed 4000 rows for most_frequent_event_4
# Processed 4100 rows for most_frequent_event_4
# Processed 4200 rows for most_frequent_event_4
# Processed 4300 rows for most_frequent_event_4
# Processed 4400 rows for most_frequent_event_4
# Processed 4500 rows for most_frequent_event_4
# Processed 4600 rows for most_frequent_event_4
# Processed 4700 rows for most_frequent_event_4
# Processed 4800 rows for most_frequent_event_4
# Processed 4900 rows for most_frequent_event_4
# Processed 5000 rows for most_frequent_event_4
# Processed 5100 rows for most_frequent_event_4
# Processed 5200 rows for most_frequent_event_4
# Processed 5300 rows for most_frequent_event_4
# Processed 5400 rows for most_frequent_event_4
# Processed 5500 rows for most_frequent_event_4
# Processed 5600 rows for most_frequent_event_4
# Processed 5700 rows for most_frequent_event_4
# Processed 5800 rows for most_frequent_event_4
# Processed 5900 rows for most_frequent_event_4
# Processed 6000 rows for most_frequent_event_4
# Processed 6100 rows for most_frequent_event_4
# Processed 6200 rows for most_frequent_event_4
# Processed 6300 rows for most_frequent_event_4
# Processed 6400 rows for most_frequent_event_4
# Processed 6500 rows for most_frequent_event_4
# Processed 6600 rows for most_frequent_event_4
# Processed 6700 rows for most_frequent_event_4
# Processed 6800 rows for most_frequent_event_4
# Processed 6900 rows for most_frequent_event_4
# Processed 7000 rows for most_frequent_event_4
# Processed 7100 rows for most_frequent_event_4
# Processed 7200 rows for most_frequent_event_4
# Processed 7300 rows for most_frequent_event_4
# Processed 7400 rows for most_frequent_event_4
# Processed 7500 rows for most_frequent_event_4
# Processed 7600 rows for most_frequent_event_4
# Processed 7700 rows for most_frequent_event_4
# Processed 7800 rows for most_frequent_event_4
# Processed 7900 rows for most_frequent_event_4
# Processed 8000 rows for most_frequent_event_4
# Processed 8100 rows for most_frequent_event_4
# Processed 8200 rows for most_frequent_event_4
# Processed 8300 rows for most_frequent_event_4
# Processed 8400 rows for most_frequent_event_4
# Processed 8500 rows for most_frequent_event_4
# Processed 8600 rows for most_frequent_event_4
# Processed 8700 rows for most_frequent_event_4
# Processed 8800 rows for most_frequent_event_4
# Processed 8900 rows for most_frequent_event_4
# Processed 9000 rows for most_frequent_event_4
# Processed 9100 rows for most_frequent_event_4
# Processed 9200 rows for most_frequent_event_4
# Processed 9300 rows for most_frequent_event_4
# Processed 9400 rows for most_frequent_event_4
# Processed 9500 rows for most_frequent_event_4
# Processed 9600 rows for most_frequent_event_4
# Processed 9700 rows for most_frequent_event_4
# Processed 9800 rows for most_frequent_event_4
# Processed 9900 rows for most_frequent_event_4
# Processed 10000 rows for most_frequent_event_4
# Processed 10100 rows for most_frequent_event_4
# Processed 10200 rows for most_frequent_event_4
# Processed 10300 rows for most_frequent_event_4
# Processed 10400 rows for most_frequent_event_4
# Processed 10500 rows for most_frequent_event_4
# Processed 10600 rows for most_frequent_event_4
# Processed 10700 rows for most_frequent_event_4
# Processed 10800 rows for most_frequent_event_4
# Processed 10900 rows for most_frequent_event_4
# Processed 11000 rows for most_frequent_event_4
# Processed 11100 rows for most_frequent_event_4
# Processed 11200 rows for most_frequent_event_4
# Processed 11300 rows for most_frequent_event_4
# Processed 11400 rows for most_frequent_event_4
# Processed 11500 rows for most_frequent_event_4
# Processed 11600 rows for most_frequent_event_4
# Processed 11700 rows for most_frequent_event_4
# Processed 11800 rows for most_frequent_event_4
# Processed 11900 rows for most_frequent_event_4
# Processed 12000 rows for most_frequent_event_4
# Processed 12100 rows for most_frequent_event_4
# Processed 12200 rows for most_frequent_event_4
# Processed 12300 rows for most_frequent_event_4
# Processed 12400 rows for most_frequent_event_4
# Processed 12500 rows for most_frequent_event_4
# Processed 12600 rows for most_frequent_event_4
# Processed 12700 rows for most_frequent_event_4
# Processed 12800 rows for most_frequent_event_4
# Processed 12900 rows for most_frequent_event_4
# Processed 13000 rows for most_frequent_event_4
# Processed 13100 rows for most_frequent_event_4
# Processed 13200 rows for most_frequent_event_4
# Processed 13300 rows for most_frequent_event_4
# Processed 13400 rows for most_frequent_event_4
# Processed 13500 rows for most_frequent_event_4
# Processed 13600 rows for most_frequent_event_4
# Processed 13700 rows for most_frequent_event_4
# Processed 13800 rows for most_frequent_event_4
# Processed 13900 rows for most_frequent_event_4
# Processed 14000 rows for most_frequent_event_4
# Processed 14100 rows for most_frequent_event_4
# Processed 14200 rows for most_frequent_event_4
# Processed 14300 rows for most_frequent_event_4
# Processed 14400 rows for most_frequent_event_4
# Processed 14500 rows for most_frequent_event_4
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716062919_step_most_frequent_events.parquet
# Processing most_frequent_event_5
# Processed 100 rows for most_frequent_event_5
# Processed 200 rows for most_frequent_event_5
# Processed 300 rows for most_frequent_event_5
# Processed 400 rows for most_frequent_event_5
# Processed 500 rows for most_frequent_event_5
# Processed 600 rows for most_frequent_event_5
# Processed 700 rows for most_frequent_event_5
# Processed 800 rows for most_frequent_event_5
# Processed 900 rows for most_frequent_event_5
# Processed 1000 rows for most_frequent_event_5
# Processed 1100 rows for most_frequent_event_5
# Processed 1200 rows for most_frequent_event_5
# Processed 1300 rows for most_frequent_event_5
# Processed 1400 rows for most_frequent_event_5
# Processed 1500 rows for most_frequent_event_5
# Processed 1600 rows for most_frequent_event_5
# Processed 1700 rows for most_frequent_event_5
# Processed 1800 rows for most_frequent_event_5
# Processed 1900 rows for most_frequent_event_5
# Processed 2000 rows for most_frequent_event_5
# Processed 2100 rows for most_frequent_event_5
# Processed 2200 rows for most_frequent_event_5
# Processed 2300 rows for most_frequent_event_5
# Processed 2400 rows for most_frequent_event_5
# Processed 2500 rows for most_frequent_event_5
# Processed 2600 rows for most_frequent_event_5
# Processed 2700 rows for most_frequent_event_5
# Processed 2800 rows for most_frequent_event_5
# Processed 2900 rows for most_frequent_event_5
# Processed 3000 rows for most_frequent_event_5
# Processed 3100 rows for most_frequent_event_5
# Processed 3200 rows for most_frequent_event_5
# Processed 3300 rows for most_frequent_event_5
# Processed 3400 rows for most_frequent_event_5
# Processed 3500 rows for most_frequent_event_5
# Processed 3600 rows for most_frequent_event_5
# Processed 3700 rows for most_frequent_event_5
# Processed 3800 rows for most_frequent_event_5
# Processed 3900 rows for most_frequent_event_5
# Processed 4000 rows for most_frequent_event_5
# Processed 4100 rows for most_frequent_event_5
# Processed 4200 rows for most_frequent_event_5
# Processed 4300 rows for most_frequent_event_5
# Processed 4400 rows for most_frequent_event_5
# Processed 4500 rows for most_frequent_event_5
# Processed 4600 rows for most_frequent_event_5
# Processed 4700 rows for most_frequent_event_5
# Processed 4800 rows for most_frequent_event_5
# Processed 4900 rows for most_frequent_event_5
# Processed 5000 rows for most_frequent_event_5
# Processed 5100 rows for most_frequent_event_5
# Processed 5200 rows for most_frequent_event_5
# Processed 5300 rows for most_frequent_event_5
# Processed 5400 rows for most_frequent_event_5
# Processed 5500 rows for most_frequent_event_5
# Processed 5600 rows for most_frequent_event_5
# Processed 5700 rows for most_frequent_event_5
# Processed 5800 rows for most_frequent_event_5
# Processed 5900 rows for most_frequent_event_5
# Processed 6000 rows for most_frequent_event_5
# Processed 6100 rows for most_frequent_event_5
# Processed 6200 rows for most_frequent_event_5
# Processed 6300 rows for most_frequent_event_5
# Processed 6400 rows for most_frequent_event_5
# Processed 6500 rows for most_frequent_event_5
# Processed 6600 rows for most_frequent_event_5
# Processed 6700 rows for most_frequent_event_5
# Processed 6800 rows for most_frequent_event_5
# Processed 6900 rows for most_frequent_event_5
# Processed 7000 rows for most_frequent_event_5
# Processed 7100 rows for most_frequent_event_5
# Processed 7200 rows for most_frequent_event_5
# Processed 7300 rows for most_frequent_event_5
# Processed 7400 rows for most_frequent_event_5
# Processed 7500 rows for most_frequent_event_5
# Processed 7600 rows for most_frequent_event_5
# Processed 7700 rows for most_frequent_event_5
# Processed 7800 rows for most_frequent_event_5
# Processed 7900 rows for most_frequent_event_5
# Processed 8000 rows for most_frequent_event_5
# Processed 8100 rows for most_frequent_event_5
# Processed 8200 rows for most_frequent_event_5
# Processed 8300 rows for most_frequent_event_5
# Processed 8400 rows for most_frequent_event_5
# Processed 8500 rows for most_frequent_event_5
# Processed 8600 rows for most_frequent_event_5
# Processed 8700 rows for most_frequent_event_5
# Processed 8800 rows for most_frequent_event_5
# Processed 8900 rows for most_frequent_event_5
# Processed 9000 rows for most_frequent_event_5
# Processed 9100 rows for most_frequent_event_5
# Processed 9200 rows for most_frequent_event_5
# Processed 9300 rows for most_frequent_event_5
# Processed 9400 rows for most_frequent_event_5
# Processed 9500 rows for most_frequent_event_5
# Processed 9600 rows for most_frequent_event_5
# Processed 9700 rows for most_frequent_event_5
# Processed 9800 rows for most_frequent_event_5
# Processed 9900 rows for most_frequent_event_5
# Processed 10000 rows for most_frequent_event_5
# Processed 10100 rows for most_frequent_event_5
# Processed 10200 rows for most_frequent_event_5
# Processed 10300 rows for most_frequent_event_5
# Processed 10400 rows for most_frequent_event_5
# Processed 10500 rows for most_frequent_event_5
# Processed 10600 rows for most_frequent_event_5
# Processed 10700 rows for most_frequent_event_5
# Processed 10800 rows for most_frequent_event_5
# Processed 10900 rows for most_frequent_event_5
# Processed 11000 rows for most_frequent_event_5
# Processed 11100 rows for most_frequent_event_5
# Processed 11200 rows for most_frequent_event_5
# Processed 11300 rows for most_frequent_event_5
# Processed 11400 rows for most_frequent_event_5
# Processed 11500 rows for most_frequent_event_5
# Processed 11600 rows for most_frequent_event_5
# Processed 11700 rows for most_frequent_event_5
# Processed 11800 rows for most_frequent_event_5
# Processed 11900 rows for most_frequent_event_5
# Processed 12000 rows for most_frequent_event_5
# Processed 12100 rows for most_frequent_event_5
# Processed 12200 rows for most_frequent_event_5
# Processed 12300 rows for most_frequent_event_5
# Processed 12400 rows for most_frequent_event_5
# Processed 12500 rows for most_frequent_event_5
# Processed 12600 rows for most_frequent_event_5
# Processed 12700 rows for most_frequent_event_5
# Processed 12800 rows for most_frequent_event_5
# Processed 12900 rows for most_frequent_event_5
# Processed 13000 rows for most_frequent_event_5
# Processed 13100 rows for most_frequent_event_5
# Processed 13200 rows for most_frequent_event_5
# Processed 13300 rows for most_frequent_event_5
# Processed 13400 rows for most_frequent_event_5
# Processed 13500 rows for most_frequent_event_5
# Processed 13600 rows for most_frequent_event_5
# Processed 13700 rows for most_frequent_event_5
# Processed 13800 rows for most_frequent_event_5
# Processed 13900 rows for most_frequent_event_5
# Processed 14000 rows for most_frequent_event_5
# Processed 14100 rows for most_frequent_event_5
# Processed 14200 rows for most_frequent_event_5
# Processed 14300 rows for most_frequent_event_5
# Processed 14400 rows for most_frequent_event_5
# Processed 14500 rows for most_frequent_event_5
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716063541_step_most_frequent_events.parquet
# Processing most_frequent_event_6
# Processed 100 rows for most_frequent_event_6
# Processed 200 rows for most_frequent_event_6
# Processed 300 rows for most_frequent_event_6
# Processed 400 rows for most_frequent_event_6
# Processed 500 rows for most_frequent_event_6
# Processed 600 rows for most_frequent_event_6
# Processed 700 rows for most_frequent_event_6
# Processed 800 rows for most_frequent_event_6
# Processed 900 rows for most_frequent_event_6
# Processed 1000 rows for most_frequent_event_6
# Processed 1100 rows for most_frequent_event_6
# Processed 1200 rows for most_frequent_event_6
# Processed 1300 rows for most_frequent_event_6
# Processed 1400 rows for most_frequent_event_6
# Processed 1500 rows for most_frequent_event_6
# Processed 1600 rows for most_frequent_event_6
# Processed 1700 rows for most_frequent_event_6
# Processed 1800 rows for most_frequent_event_6
# Processed 1900 rows for most_frequent_event_6
# Processed 2000 rows for most_frequent_event_6
# Processed 2100 rows for most_frequent_event_6
# Processed 2200 rows for most_frequent_event_6
# Processed 2300 rows for most_frequent_event_6
# Processed 2400 rows for most_frequent_event_6
# Processed 2500 rows for most_frequent_event_6
# Processed 2600 rows for most_frequent_event_6
# Processed 2700 rows for most_frequent_event_6
# Processed 2800 rows for most_frequent_event_6
# Processed 2900 rows for most_frequent_event_6
# Processed 3000 rows for most_frequent_event_6
# Processed 3100 rows for most_frequent_event_6
# Processed 3200 rows for most_frequent_event_6
# Processed 3300 rows for most_frequent_event_6
# Processed 3400 rows for most_frequent_event_6
# Processed 3500 rows for most_frequent_event_6
# Processed 3600 rows for most_frequent_event_6
# Processed 3700 rows for most_frequent_event_6
# Processed 3800 rows for most_frequent_event_6
# Processed 3900 rows for most_frequent_event_6
# Processed 4000 rows for most_frequent_event_6
# Processed 4100 rows for most_frequent_event_6
# Processed 4200 rows for most_frequent_event_6
# Processed 4300 rows for most_frequent_event_6
# Processed 4400 rows for most_frequent_event_6
# Processed 4500 rows for most_frequent_event_6
# Processed 4600 rows for most_frequent_event_6
# Processed 4700 rows for most_frequent_event_6
# Processed 4800 rows for most_frequent_event_6
# Processed 4900 rows for most_frequent_event_6
# Processed 5000 rows for most_frequent_event_6
# Processed 5100 rows for most_frequent_event_6
# Processed 5200 rows for most_frequent_event_6
# Processed 5300 rows for most_frequent_event_6
# Processed 5400 rows for most_frequent_event_6
# Processed 5500 rows for most_frequent_event_6
# Processed 5600 rows for most_frequent_event_6
# Processed 5700 rows for most_frequent_event_6
# Processed 5800 rows for most_frequent_event_6
# Processed 5900 rows for most_frequent_event_6
# Processed 6000 rows for most_frequent_event_6
# Processed 6100 rows for most_frequent_event_6
# Processed 6200 rows for most_frequent_event_6
# Processed 6300 rows for most_frequent_event_6
# Processed 6400 rows for most_frequent_event_6
# Processed 6500 rows for most_frequent_event_6
# Processed 6600 rows for most_frequent_event_6
# Processed 6700 rows for most_frequent_event_6
# Processed 6800 rows for most_frequent_event_6
# Processed 6900 rows for most_frequent_event_6
# Processed 7000 rows for most_frequent_event_6
# Processed 7100 rows for most_frequent_event_6
# Processed 7200 rows for most_frequent_event_6
# Processed 7300 rows for most_frequent_event_6
# Processed 7400 rows for most_frequent_event_6
# Processed 7500 rows for most_frequent_event_6
# Processed 7600 rows for most_frequent_event_6
# Processed 7700 rows for most_frequent_event_6
# Processed 7800 rows for most_frequent_event_6
# Processed 7900 rows for most_frequent_event_6
# Processed 8000 rows for most_frequent_event_6
# Processed 8100 rows for most_frequent_event_6
# Processed 8200 rows for most_frequent_event_6
# Processed 8300 rows for most_frequent_event_6
# Processed 8400 rows for most_frequent_event_6
# Processed 8500 rows for most_frequent_event_6
# Processed 8600 rows for most_frequent_event_6
# Processed 8700 rows for most_frequent_event_6
# Processed 8800 rows for most_frequent_event_6
# Processed 8900 rows for most_frequent_event_6
# Processed 9000 rows for most_frequent_event_6
# Processed 9100 rows for most_frequent_event_6
# Processed 9200 rows for most_frequent_event_6
# Processed 9300 rows for most_frequent_event_6
# Processed 9400 rows for most_frequent_event_6
# Processed 9500 rows for most_frequent_event_6
# Processed 9600 rows for most_frequent_event_6
# Processed 9700 rows for most_frequent_event_6
# Processed 9800 rows for most_frequent_event_6
# Processed 9900 rows for most_frequent_event_6
# Processed 10000 rows for most_frequent_event_6
# Processed 10100 rows for most_frequent_event_6
# Processed 10200 rows for most_frequent_event_6
# Processed 10300 rows for most_frequent_event_6
# Processed 10400 rows for most_frequent_event_6
# Processed 10500 rows for most_frequent_event_6
# Processed 10600 rows for most_frequent_event_6
# Processed 10700 rows for most_frequent_event_6
# Processed 10800 rows for most_frequent_event_6
# Processed 10900 rows for most_frequent_event_6
# Processed 11000 rows for most_frequent_event_6
# Processed 11100 rows for most_frequent_event_6
# Processed 11200 rows for most_frequent_event_6
# Processed 11300 rows for most_frequent_event_6
# Processed 11400 rows for most_frequent_event_6
# Processed 11500 rows for most_frequent_event_6
# Processed 11600 rows for most_frequent_event_6
# Processed 11700 rows for most_frequent_event_6
# Processed 11800 rows for most_frequent_event_6
# Processed 11900 rows for most_frequent_event_6
# Processed 12000 rows for most_frequent_event_6
# Processed 12100 rows for most_frequent_event_6
# Processed 12200 rows for most_frequent_event_6
# Processed 12300 rows for most_frequent_event_6
# Processed 12400 rows for most_frequent_event_6
# Processed 12500 rows for most_frequent_event_6
# Processed 12600 rows for most_frequent_event_6
# Processed 12700 rows for most_frequent_event_6
# Processed 12800 rows for most_frequent_event_6
# Processed 12900 rows for most_frequent_event_6
# Processed 13000 rows for most_frequent_event_6
# Processed 13100 rows for most_frequent_event_6
# Processed 13200 rows for most_frequent_event_6
# Processed 13300 rows for most_frequent_event_6
# Processed 13400 rows for most_frequent_event_6
# Processed 13500 rows for most_frequent_event_6
# Processed 13600 rows for most_frequent_event_6
# Processed 13700 rows for most_frequent_event_6
# Processed 13800 rows for most_frequent_event_6
# Processed 13900 rows for most_frequent_event_6
# Processed 14000 rows for most_frequent_event_6
# Processed 14100 rows for most_frequent_event_6
# Processed 14200 rows for most_frequent_event_6
# Processed 14300 rows for most_frequent_event_6
# Processed 14400 rows for most_frequent_event_6
# Processed 14500 rows for most_frequent_event_6
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716064213_step_most_frequent_events.parquet
# Processing most_frequent_event_7
# Processed 100 rows for most_frequent_event_7
# Processed 200 rows for most_frequent_event_7
# Processed 300 rows for most_frequent_event_7
# Processed 400 rows for most_frequent_event_7
# Processed 500 rows for most_frequent_event_7
# Processed 600 rows for most_frequent_event_7
# Processed 700 rows for most_frequent_event_7
# Processed 800 rows for most_frequent_event_7
# Processed 900 rows for most_frequent_event_7
# Processed 1000 rows for most_frequent_event_7
# Processed 1100 rows for most_frequent_event_7
# Processed 1200 rows for most_frequent_event_7
# Processed 1300 rows for most_frequent_event_7
# Processed 1400 rows for most_frequent_event_7
# Processed 1500 rows for most_frequent_event_7
# Processed 1600 rows for most_frequent_event_7
# Processed 1700 rows for most_frequent_event_7
# Processed 1800 rows for most_frequent_event_7
# Processed 1900 rows for most_frequent_event_7
# Processed 2000 rows for most_frequent_event_7
# Processed 2100 rows for most_frequent_event_7
# Processed 2200 rows for most_frequent_event_7
# Processed 2300 rows for most_frequent_event_7
# Processed 2400 rows for most_frequent_event_7
# Processed 2500 rows for most_frequent_event_7
# Processed 2600 rows for most_frequent_event_7
# Processed 2700 rows for most_frequent_event_7
# Processed 2800 rows for most_frequent_event_7
# Processed 2900 rows for most_frequent_event_7
# Processed 3000 rows for most_frequent_event_7
# Processed 3100 rows for most_frequent_event_7
# Processed 3200 rows for most_frequent_event_7
# Processed 3300 rows for most_frequent_event_7
# Processed 3400 rows for most_frequent_event_7
# Processed 3500 rows for most_frequent_event_7
# Processed 3600 rows for most_frequent_event_7
# Processed 3700 rows for most_frequent_event_7
# Processed 3800 rows for most_frequent_event_7
# Processed 3900 rows for most_frequent_event_7
# Processed 4000 rows for most_frequent_event_7
# Processed 4100 rows for most_frequent_event_7
# Processed 4200 rows for most_frequent_event_7
# Processed 4300 rows for most_frequent_event_7
# Processed 4400 rows for most_frequent_event_7
# Processed 4500 rows for most_frequent_event_7
# Processed 4600 rows for most_frequent_event_7
# Processed 4700 rows for most_frequent_event_7
# Processed 4800 rows for most_frequent_event_7
# Processed 4900 rows for most_frequent_event_7
# Processed 5000 rows for most_frequent_event_7
# Processed 5100 rows for most_frequent_event_7
# Processed 5200 rows for most_frequent_event_7
# Processed 5300 rows for most_frequent_event_7
# Processed 5400 rows for most_frequent_event_7
# Processed 5500 rows for most_frequent_event_7
# Processed 5600 rows for most_frequent_event_7
# Processed 5700 rows for most_frequent_event_7
# Processed 5800 rows for most_frequent_event_7
# Processed 5900 rows for most_frequent_event_7
# Processed 6000 rows for most_frequent_event_7
# Processed 6100 rows for most_frequent_event_7
# Processed 6200 rows for most_frequent_event_7
# Processed 6300 rows for most_frequent_event_7
# Processed 6400 rows for most_frequent_event_7
# Processed 6500 rows for most_frequent_event_7
# Processed 6600 rows for most_frequent_event_7
# Processed 6700 rows for most_frequent_event_7
# Processed 6800 rows for most_frequent_event_7
# Processed 6900 rows for most_frequent_event_7
# Processed 7000 rows for most_frequent_event_7
# Processed 7100 rows for most_frequent_event_7
# Processed 7200 rows for most_frequent_event_7
# Processed 7300 rows for most_frequent_event_7
# Processed 7400 rows for most_frequent_event_7
# Processed 7500 rows for most_frequent_event_7
# Processed 7600 rows for most_frequent_event_7
# Processed 7700 rows for most_frequent_event_7
# Processed 7800 rows for most_frequent_event_7
# Processed 7900 rows for most_frequent_event_7
# Processed 8000 rows for most_frequent_event_7
# Processed 8100 rows for most_frequent_event_7
# Processed 8200 rows for most_frequent_event_7
# Processed 8300 rows for most_frequent_event_7
# Processed 8400 rows for most_frequent_event_7
# Processed 8500 rows for most_frequent_event_7
# Processed 8600 rows for most_frequent_event_7
# Processed 8700 rows for most_frequent_event_7
# Processed 8800 rows for most_frequent_event_7
# Processed 8900 rows for most_frequent_event_7
# Processed 9000 rows for most_frequent_event_7
# Processed 9100 rows for most_frequent_event_7
# Processed 9200 rows for most_frequent_event_7
# Processed 9300 rows for most_frequent_event_7
# Processed 9400 rows for most_frequent_event_7
# Processed 9500 rows for most_frequent_event_7
# Processed 9600 rows for most_frequent_event_7
# Processed 9700 rows for most_frequent_event_7
# Processed 9800 rows for most_frequent_event_7
# Processed 9900 rows for most_frequent_event_7
# Processed 10000 rows for most_frequent_event_7
# Processed 10100 rows for most_frequent_event_7
# Processed 10200 rows for most_frequent_event_7
# Processed 10300 rows for most_frequent_event_7
# Processed 10400 rows for most_frequent_event_7
# Processed 10500 rows for most_frequent_event_7
# Processed 10600 rows for most_frequent_event_7
# Processed 10700 rows for most_frequent_event_7
# Processed 10800 rows for most_frequent_event_7
# Processed 10900 rows for most_frequent_event_7
# Processed 11000 rows for most_frequent_event_7
# Processed 11100 rows for most_frequent_event_7
# Processed 11200 rows for most_frequent_event_7
# Processed 11300 rows for most_frequent_event_7
# Processed 11400 rows for most_frequent_event_7
# Processed 11500 rows for most_frequent_event_7
# Processed 11600 rows for most_frequent_event_7
# Processed 11700 rows for most_frequent_event_7
# Processed 11800 rows for most_frequent_event_7
# Processed 11900 rows for most_frequent_event_7
# Processed 12000 rows for most_frequent_event_7
# Processed 12100 rows for most_frequent_event_7
# Processed 12200 rows for most_frequent_event_7
# Processed 12300 rows for most_frequent_event_7
# Processed 12400 rows for most_frequent_event_7
# Processed 12500 rows for most_frequent_event_7
# Processed 12600 rows for most_frequent_event_7
# Processed 12700 rows for most_frequent_event_7
# Processed 12800 rows for most_frequent_event_7
# Processed 12900 rows for most_frequent_event_7
# Processed 13000 rows for most_frequent_event_7
# Processed 13100 rows for most_frequent_event_7
# Processed 13200 rows for most_frequent_event_7
# Processed 13300 rows for most_frequent_event_7
# Processed 13400 rows for most_frequent_event_7
# Processed 13500 rows for most_frequent_event_7
# Processed 13600 rows for most_frequent_event_7
# Processed 13700 rows for most_frequent_event_7
# Processed 13800 rows for most_frequent_event_7
# Processed 13900 rows for most_frequent_event_7
# Processed 14000 rows for most_frequent_event_7
# Processed 14100 rows for most_frequent_event_7
# Processed 14200 rows for most_frequent_event_7
# Processed 14300 rows for most_frequent_event_7
# Processed 14400 rows for most_frequent_event_7
# Processed 14500 rows for most_frequent_event_7
# ...
# Processed 10400 rows for most_frequent_event_8
# Processed 10500 rows for most_frequent_event_8
# Processed 10600 rows for most_frequent_event_8
# Processed 10700 rows for most_frequent_event_8
# Processed 10800 rows for most_frequent_event_8
# Processed 10900 rows for most_frequent_event_8
# Processed 11000 rows for most_frequent_event_8
# Processed 11100 rows for most_frequent_event_8
# Processed 11200 rows for most_frequent_event_8
# Processed 11300 rows for most_frequent_event_8
# Processed 11400 rows for most_frequent_event_8
# Processed 11500 rows for most_frequent_event_8
# Processed 11600 rows for most_frequent_event_8
# Processed 11700 rows for most_frequent_event_8
# Processed 11800 rows for most_frequent_event_8
# Processed 11900 rows for most_frequent_event_8
# Processed 12000 rows for most_frequent_event_8
# Processed 12100 rows for most_frequent_event_8
# Processed 12200 rows for most_frequent_event_8
# Processed 12300 rows for most_frequent_event_8
# Processed 12400 rows for most_frequent_event_8
# Processed 12500 rows for most_frequent_event_8
# Processed 12600 rows for most_frequent_event_8
# Processed 12700 rows for most_frequent_event_8
# Processed 12800 rows for most_frequent_event_8
# Processed 12900 rows for most_frequent_event_8
# Processed 13000 rows for most_frequent_event_8
# Processed 13100 rows for most_frequent_event_8
# Processed 13200 rows for most_frequent_event_8
# Processed 13300 rows for most_frequent_event_8
# Processed 13400 rows for most_frequent_event_8
# Processed 13500 rows for most_frequent_event_8
# Processed 13600 rows for most_frequent_event_8
# Processed 13700 rows for most_frequent_event_8
# Processed 13800 rows for most_frequent_event_8
# Processed 13900 rows for most_frequent_event_8
# Processed 14000 rows for most_frequent_event_8
# Processed 14100 rows for most_frequent_event_8
# Processed 14200 rows for most_frequent_event_8
# Processed 14300 rows for most_frequent_event_8
# Processed 14400 rows for most_frequent_event_8
# Processed 14500 rows for most_frequent_event_8
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716065507_step_most_frequent_events.parquet
# Processing most_frequent_event_9
# Processed 100 rows for most_frequent_event_9
# Processed 200 rows for most_frequent_event_9
# Processed 300 rows for most_frequent_event_9
# Processed 400 rows for most_frequent_event_9
# Processed 500 rows for most_frequent_event_9
# Processed 600 rows for most_frequent_event_9
# Processed 700 rows for most_frequent_event_9
# Processed 800 rows for most_frequent_event_9
# Processed 900 rows for most_frequent_event_9
# Processed 1000 rows for most_frequent_event_9
# Processed 1100 rows for most_frequent_event_9
# Processed 1200 rows for most_frequent_event_9
# Processed 1300 rows for most_frequent_event_9
# Processed 1400 rows for most_frequent_event_9
# Processed 1500 rows for most_frequent_event_9
# Processed 1600 rows for most_frequent_event_9
# Processed 1700 rows for most_frequent_event_9
# Processed 1800 rows for most_frequent_event_9
# Processed 1900 rows for most_frequent_event_9
# Processed 2000 rows for most_frequent_event_9
# Processed 2100 rows for most_frequent_event_9
# Processed 2200 rows for most_frequent_event_9
# Processed 2300 rows for most_frequent_event_9
# Processed 2400 rows for most_frequent_event_9
# Processed 2500 rows for most_frequent_event_9
# Processed 2600 rows for most_frequent_event_9
# Processed 2700 rows for most_frequent_event_9
# Processed 2800 rows for most_frequent_event_9
# Processed 2900 rows for most_frequent_event_9
# Processed 3000 rows for most_frequent_event_9
# Processed 3100 rows for most_frequent_event_9
# Processed 3200 rows for most_frequent_event_9
# Processed 3300 rows for most_frequent_event_9
# Processed 3400 rows for most_frequent_event_9
# Processed 3500 rows for most_frequent_event_9
# Processed 3600 rows for most_frequent_event_9
# Processed 3700 rows for most_frequent_event_9
# Processed 3800 rows for most_frequent_event_9
# Processed 3900 rows for most_frequent_event_9
# Processed 4000 rows for most_frequent_event_9
# Processed 4100 rows for most_frequent_event_9
# Processed 4200 rows for most_frequent_event_9
# Processed 4300 rows for most_frequent_event_9
# Processed 4400 rows for most_frequent_event_9
# Processed 4500 rows for most_frequent_event_9
# Processed 4600 rows for most_frequent_event_9
# Processed 4700 rows for most_frequent_event_9
# Processed 4800 rows for most_frequent_event_9
# Processed 4900 rows for most_frequent_event_9
# Processed 5000 rows for most_frequent_event_9
# Processed 5100 rows for most_frequent_event_9
# Processed 5200 rows for most_frequent_event_9
# Processed 5300 rows for most_frequent_event_9
# Processed 5400 rows for most_frequent_event_9
# Processed 5500 rows for most_frequent_event_9
# Processed 5600 rows for most_frequent_event_9
# Processed 5700 rows for most_frequent_event_9
# Processed 5800 rows for most_frequent_event_9
# Processed 5900 rows for most_frequent_event_9
# Processed 6000 rows for most_frequent_event_9
# Processed 6100 rows for most_frequent_event_9
# Processed 6200 rows for most_frequent_event_9
# Processed 6300 rows for most_frequent_event_9
# Processed 6400 rows for most_frequent_event_9
# Processed 6500 rows for most_frequent_event_9
# Processed 6600 rows for most_frequent_event_9
# Processed 6700 rows for most_frequent_event_9
# Processed 6800 rows for most_frequent_event_9
# Processed 6900 rows for most_frequent_event_9
# Processed 7000 rows for most_frequent_event_9
# Processed 7100 rows for most_frequent_event_9
# Processed 7200 rows for most_frequent_event_9
# Processed 7300 rows for most_frequent_event_9
# Processed 7400 rows for most_frequent_event_9
# Processed 7500 rows for most_frequent_event_9
# Processed 7600 rows for most_frequent_event_9
# Processed 7700 rows for most_frequent_event_9
# Processed 7800 rows for most_frequent_event_9
# Processed 7900 rows for most_frequent_event_9
# Processed 8000 rows for most_frequent_event_9
# Processed 8100 rows for most_frequent_event_9
# Processed 8200 rows for most_frequent_event_9
# Processed 8300 rows for most_frequent_event_9
# Processed 8400 rows for most_frequent_event_9
# Processed 8500 rows for most_frequent_event_9
# Processed 8600 rows for most_frequent_event_9
# Processed 8700 rows for most_frequent_event_9
# Processed 8800 rows for most_frequent_event_9
# Processed 8900 rows for most_frequent_event_9
# Processed 9000 rows for most_frequent_event_9
# Processed 9100 rows for most_frequent_event_9
# Processed 9200 rows for most_frequent_event_9
# Processed 9300 rows for most_frequent_event_9
# Processed 9400 rows for most_frequent_event_9
# Processed 9500 rows for most_frequent_event_9
# Processed 9600 rows for most_frequent_event_9
# Processed 9700 rows for most_frequent_event_9
# Processed 9800 rows for most_frequent_event_9
# Processed 9900 rows for most_frequent_event_9
# Processed 10000 rows for most_frequent_event_9
# Processed 10100 rows for most_frequent_event_9
# Processed 10200 rows for most_frequent_event_9
# Processed 10300 rows for most_frequent_event_9
# Processed 10400 rows for most_frequent_event_9
# Processed 10500 rows for most_frequent_event_9
# Processed 10600 rows for most_frequent_event_9
# Processed 10700 rows for most_frequent_event_9
# Processed 10800 rows for most_frequent_event_9
# Processed 10900 rows for most_frequent_event_9
# Processed 11000 rows for most_frequent_event_9
# Processed 11100 rows for most_frequent_event_9
# Processed 11200 rows for most_frequent_event_9
# Processed 11300 rows for most_frequent_event_9
# Processed 11400 rows for most_frequent_event_9
# Processed 11500 rows for most_frequent_event_9
# Processed 11600 rows for most_frequent_event_9
# Processed 11700 rows for most_frequent_event_9
# Processed 11800 rows for most_frequent_event_9
# Processed 11900 rows for most_frequent_event_9
# Processed 12000 rows for most_frequent_event_9
# Processed 12100 rows for most_frequent_event_9
# Processed 12200 rows for most_frequent_event_9
# Processed 12300 rows for most_frequent_event_9
# Processed 12400 rows for most_frequent_event_9
# Processed 12500 rows for most_frequent_event_9
# Processed 12600 rows for most_frequent_event_9
# Processed 12700 rows for most_frequent_event_9
# Processed 12800 rows for most_frequent_event_9
# Processed 12900 rows for most_frequent_event_9
# Processed 13000 rows for most_frequent_event_9
# Processed 13100 rows for most_frequent_event_9
# Processed 13200 rows for most_frequent_event_9
# Processed 13300 rows for most_frequent_event_9
# Processed 13400 rows for most_frequent_event_9
# Processed 13500 rows for most_frequent_event_9
# Processed 13600 rows for most_frequent_event_9
# Processed 13700 rows for most_frequent_event_9
# Processed 13800 rows for most_frequent_event_9
# Processed 13900 rows for most_frequent_event_9
# Processed 14000 rows for most_frequent_event_9
# Processed 14100 rows for most_frequent_event_9
# Processed 14200 rows for most_frequent_event_9
# Processed 14300 rows for most_frequent_event_9
# Processed 14400 rows for most_frequent_event_9
# Processed 14500 rows for most_frequent_event_9
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716070134_step_most_frequent_events.parquet
# Processing most_frequent_event_10
# Processed 100 rows for most_frequent_event_10
# Processed 200 rows for most_frequent_event_10
# Processed 300 rows for most_frequent_event_10
# Processed 400 rows for most_frequent_event_10
# Processed 500 rows for most_frequent_event_10
# Processed 600 rows for most_frequent_event_10
# Processed 700 rows for most_frequent_event_10
# Processed 800 rows for most_frequent_event_10
# Processed 900 rows for most_frequent_event_10
# Processed 1000 rows for most_frequent_event_10
# Processed 1100 rows for most_frequent_event_10
# Processed 1200 rows for most_frequent_event_10
# Processed 1300 rows for most_frequent_event_10
# Processed 1400 rows for most_frequent_event_10
# Processed 1500 rows for most_frequent_event_10
# Processed 1600 rows for most_frequent_event_10
# Processed 1700 rows for most_frequent_event_10
# Processed 1800 rows for most_frequent_event_10
# Processed 1900 rows for most_frequent_event_10
# Processed 2000 rows for most_frequent_event_10
# Processed 2100 rows for most_frequent_event_10
# Processed 2200 rows for most_frequent_event_10
# Processed 2300 rows for most_frequent_event_10
# Processed 2400 rows for most_frequent_event_10
# Processed 2500 rows for most_frequent_event_10
# Processed 2600 rows for most_frequent_event_10
# Processed 2700 rows for most_frequent_event_10
# Processed 2800 rows for most_frequent_event_10
# Processed 2900 rows for most_frequent_event_10
# Processed 3000 rows for most_frequent_event_10
# Processed 3100 rows for most_frequent_event_10
# Processed 3200 rows for most_frequent_event_10
# Processed 3300 rows for most_frequent_event_10
# Processed 3400 rows for most_frequent_event_10
# Processed 3500 rows for most_frequent_event_10
# Processed 3600 rows for most_frequent_event_10
# Processed 3700 rows for most_frequent_event_10
# Processed 3800 rows for most_frequent_event_10
# Processed 3900 rows for most_frequent_event_10
# Processed 4000 rows for most_frequent_event_10
# Processed 4100 rows for most_frequent_event_10
# Processed 4200 rows for most_frequent_event_10
# Processed 4300 rows for most_frequent_event_10
# Processed 4400 rows for most_frequent_event_10
# Processed 4500 rows for most_frequent_event_10
# Processed 4600 rows for most_frequent_event_10
# Processed 4700 rows for most_frequent_event_10
# Processed 4800 rows for most_frequent_event_10
# Processed 4900 rows for most_frequent_event_10
# Processed 5000 rows for most_frequent_event_10
# Processed 5100 rows for most_frequent_event_10
# Processed 5200 rows for most_frequent_event_10
# Processed 5300 rows for most_frequent_event_10
# Processed 5400 rows for most_frequent_event_10
# Processed 5500 rows for most_frequent_event_10
# Processed 5600 rows for most_frequent_event_10
# Processed 5700 rows for most_frequent_event_10
# Processed 5800 rows for most_frequent_event_10
# Processed 5900 rows for most_frequent_event_10
# Processed 6000 rows for most_frequent_event_10
# Processed 6100 rows for most_frequent_event_10
# Processed 6200 rows for most_frequent_event_10
# Processed 6300 rows for most_frequent_event_10
# Processed 6400 rows for most_frequent_event_10
# Processed 6500 rows for most_frequent_event_10
# Processed 6600 rows for most_frequent_event_10
# Processed 6700 rows for most_frequent_event_10
# Processed 6800 rows for most_frequent_event_10
# Processed 6900 rows for most_frequent_event_10
# Processed 7000 rows for most_frequent_event_10
# Processed 7100 rows for most_frequent_event_10
# Processed 7200 rows for most_frequent_event_10
# Processed 7300 rows for most_frequent_event_10
# Processed 7400 rows for most_frequent_event_10
# Processed 7500 rows for most_frequent_event_10
# Processed 7600 rows for most_frequent_event_10
# Processed 7700 rows for most_frequent_event_10
# Processed 7800 rows for most_frequent_event_10
# Processed 7900 rows for most_frequent_event_10
# Processed 8000 rows for most_frequent_event_10
# Processed 8100 rows for most_frequent_event_10
# Processed 8200 rows for most_frequent_event_10
# Processed 8300 rows for most_frequent_event_10
# Processed 8400 rows for most_frequent_event_10
# Processed 8500 rows for most_frequent_event_10
# Processed 8600 rows for most_frequent_event_10
# Processed 8700 rows for most_frequent_event_10
# Processed 8800 rows for most_frequent_event_10
# Processed 8900 rows for most_frequent_event_10
# Processed 9000 rows for most_frequent_event_10
# Processed 9100 rows for most_frequent_event_10
# Processed 9200 rows for most_frequent_event_10
# Processed 9300 rows for most_frequent_event_10
# Processed 9400 rows for most_frequent_event_10
# Processed 9500 rows for most_frequent_event_10
# Processed 9600 rows for most_frequent_event_10
# Processed 9700 rows for most_frequent_event_10
# Processed 9800 rows for most_frequent_event_10
# Processed 9900 rows for most_frequent_event_10
# Processed 10000 rows for most_frequent_event_10
# Processed 10100 rows for most_frequent_event_10
# Processed 10200 rows for most_frequent_event_10
# Processed 10300 rows for most_frequent_event_10
# Processed 10400 rows for most_frequent_event_10
# Processed 10500 rows for most_frequent_event_10
# Processed 10600 rows for most_frequent_event_10
# Processed 10700 rows for most_frequent_event_10
# Processed 10800 rows for most_frequent_event_10
# Processed 10900 rows for most_frequent_event_10
# Processed 11000 rows for most_frequent_event_10
# Processed 11100 rows for most_frequent_event_10
# Processed 11200 rows for most_frequent_event_10
# Processed 11300 rows for most_frequent_event_10
# Processed 11400 rows for most_frequent_event_10
# Processed 11500 rows for most_frequent_event_10
# Processed 11600 rows for most_frequent_event_10
# Processed 11700 rows for most_frequent_event_10
# Processed 11800 rows for most_frequent_event_10
# Processed 11900 rows for most_frequent_event_10
# Processed 12000 rows for most_frequent_event_10
# Processed 12100 rows for most_frequent_event_10
# Processed 12200 rows for most_frequent_event_10
# Processed 12300 rows for most_frequent_event_10
# Processed 12400 rows for most_frequent_event_10
# Processed 12500 rows for most_frequent_event_10
# Processed 12600 rows for most_frequent_event_10
# Processed 12700 rows for most_frequent_event_10
# Processed 12800 rows for most_frequent_event_10
# Processed 12900 rows for most_frequent_event_10
# Processed 13000 rows for most_frequent_event_10
# Processed 13100 rows for most_frequent_event_10
# Processed 13200 rows for most_frequent_event_10
# Processed 13300 rows for most_frequent_event_10
# Processed 13400 rows for most_frequent_event_10
# Processed 13500 rows for most_frequent_event_10
# Processed 13600 rows for most_frequent_event_10
# Processed 13700 rows for most_frequent_event_10
# Processed 13800 rows for most_frequent_event_10
# Processed 13900 rows for most_frequent_event_10
# Processed 14000 rows for most_frequent_event_10
# Processed 14100 rows for most_frequent_event_10
# Processed 14200 rows for most_frequent_event_10
# Processed 14300 rows for most_frequent_event_10
# Processed 14400 rows for most_frequent_event_10
# Processed 14500 rows for most_frequent_event_10
# Intermediate file saved: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716070759_step_most_frequent_events.parquet

# %% [markdown]
# #### Display the created file

# %%
# import pandas as pd

# # Load the latest file
# latest_file = f"{data_dir}/03B20240716070759_step_most_frequent_events.parquet"
# latest_df = pd.read_parquet(latest_file)

# # Display the head of the final dataframe
# display(latest_df.head())

# %% [markdown]
# ### <font color = teal> Create Master Mapping File: <font color = tomato>03B.20240716_072206_orig_parquet_mapper_agents.parquet
# #### Step to Drop EventId_ Columns and Save the DataFrame
# ##### <font color = red>Create Master Tracker File for appending in future runs

# %%
import pandas as pd
from datetime import datetime

data_dir = '/home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files'
encoded_feature_input_file = f"{data_dir}/03B20240716070759_step_most_frequent_events.parquet"
encoded_feature_input_file_df = pd.read_parquet(encoded_feature_input_file)

# Identify EventId columns
event_id_columns = [col for col in encoded_feature_input_file_df.columns if col.startswith('EventId_')]

# Drop all EventId_ columns
encoded_feature_input_file_df.drop(columns=event_id_columns, inplace=True)

# Save the modified DataFrame to a new parquet file
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
output_file = f"{data_dir}/03B{timestamp}_orig_parquet_mapper_agents.parquet"
encoded_feature_input_file_df.to_parquet(output_file, index=False)

print(f"New parquet file saved to: {output_file}")
# Out:
# New parquet file saved to: /home/ubuntu/efs-w210-capstone-ebs/04A.Local_Data_Files/03B20240716072206_orig_parquet_mapper_agents.parquet

# %% [markdown]
# #### <font color = blue> Display the Master Mapping File <font color = tomato>03B.20240716_072206_orig_parquet_mapper_agents.parquet

# %%
import pandas as pd

# Load the latest file
latest_file = f"{data_dir}/03B.20240716_072206_orig_parquet_mapper_agents.parquet"
latest_df = pd.read_parquet(latest_file)

# Display the head of the final dataframe
display(latest_df.head())
# Out:
#    Seq_Num Train_Test          time_start  time_start_int  Class  \
# 0        0      Train 2005-06-03 16:00:00               0      0
# 1        1      Train 2005-06-03 16:05:00               1      0
# 2        2      Train 2005-06-03 16:10:00               2      0
# 3        3      Train 2005-06-03 16:15:00               3      0
# 4        4      Train 2005-06-03 16:25:00               5      0
#
#    unique_events  most_frequent_event  transitions   entropy  hour_of_day  \
# 0              6                  228            6  0.171708           16
# 1              2                  987            2  0.598270           16
# 2              6                  399           18  0.655243           16
# 3              5                  328            6  1.039660           16
# 4              4                  399            3  0.895333           16
#
#    day_of_week  event_count  top_event_frequency  prev_event_count  \
# 0            4          465                35431             913.0
# 1            4            7                35433             465.0
# 2            4           81                35431               7.0
# 3            4           66                35431              81.0
# 4            4           14                35433              66.0
#
#    transition_rate  high_transition_rate  prev_entropy  entropy_change  \
# 0         0.012903                     0      0.000000        0.171708
# 1         0.285714                     0      0.171708        0.426562
# 2         0.222222                     0      0.598270        0.056973
# 3         0.090909                     0      0.655243        0.384418
# 4         0.214286                     0      1.039660       -0.144328
#
#    rolling_event_count  rolling_unique_event_count  most_frequent_event_1  \
# 0               4895.0                        18.0                      0
# 1               4257.0                        19.0                      0
# 2               2756.0                        23.0                      0
# 3               1532.0                        25.0                      0
# 4                633.0                        28.0                      0
#
#    most_frequent_event_2  most_frequent_event_3  most_frequent_event_4  \
# 0                    228                  987.0                  504.0
# 1                    987                  729.0                    NaN
# 2                    399                   95.0                   80.0
# 3                    328                  399.0                  987.0
# 4                    399                  504.0                   95.0
#
#    most_frequent_event_5  most_frequent_event_6  most_frequent_event_7  \
# 0                   95.0                  399.0                   80.0
# 1                    NaN                    NaN                    NaN
# 2                  734.0                  430.0                  504.0
# 3                   95.0                   80.0                    NaN
# 4                   80.0                    NaN                    NaN
#
#    most_frequent_event_8  most_frequent_event_9  most_frequent_event_10
# 0                    NaN                    NaN                     NaN
# 1                    NaN                    NaN                     NaN
# 2                    NaN                    NaN                     NaN
# 3                    NaN                    NaN                     NaN
# 4                    NaN                    NaN                     NaN

# %% [markdown]
# ___
# ## Part 3: Adding Most Frequent Sequence of 2 Events

# %%
print("Processing most_frequent_sequence_2_events")
encoded_feature_input_file_df['most_frequent_sequence_2_events'] = None  # Initialize column

for index, row in encoded_feature_input_file_df.iterrows():
    encoded_feature_input_file_df.at[index, 'most_frequent_sequence_2_events'] = get_most_frequent_sequence(row, 2)
    
    if (index + 1) % 100 == 0:
        print(f"Processed {index + 1} rows for most_frequent_sequence_2_events")

# Save after processing the column
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
intermediate_file = f"{data_dir}/03B{timestamp}_step_most_frequent_sequence_2.parquet"
encoded_feature_input_file_df.to_parquet(intermediate_file, index=False)
print(f"Intermediate file saved: {intermediate_file}")

# %% [markdown]
# ## Part 4: Adding Most Frequent Sequence of 3 Events

# %%
print("Processing most_frequent_sequence_3_events")
encoded_feature_input_file_df['most_frequent_sequence_3_events'] = None  # Initialize column

for index, row in encoded_feature_input_file_df.iterrows():
    encoded_feature_input_file_df.at[index, 'most_frequent_sequence_3_events'] = get_most_frequent_sequence(row, 3)
    
    if (index + 1) % 100 == 0:
        print(f"Processed {index + 1} rows for most_frequent_sequence_3_events")

# Save after processing the column
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
intermediate_file = f"{data_dir}/03B{timestamp}_step_most_frequent_sequence_3.parquet"
encoded_feature_input_file_df.to_parquet(intermediate_file, index=False)
print(f"Intermediate file saved: {intermediate_file}")

# %% [markdown]
# ## Part 5: Adding Most Frequent Sequence of 4 Events

# %%
print("Processing most_frequent_sequence_4_events")
encoded_feature_input_file_df['most_frequent_sequence_4_events'] = None  # Initialize column

for index, row in encoded_feature_input_file_df.iterrows():
    encoded_feature_input_file_df.at[index, 'most_frequent_sequence_4_events'] = get_most_frequent_sequence(row, 4)
    
    if (index + 1) % 100 == 0:
        print(f"Processed {index + 1} rows for most_frequent_sequence_4_events")

# Save after processing the column
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
intermediate_file = f"{data_dir}/03B{timestamp}_step_most_frequent_sequence_4.parquet"
encoded_feature_input_file_df.to_parquet(intermediate_file, index=False)
print(f"Intermediate file saved: {intermediate_file}")

# %% [markdown]
# ## Part 6: Final Save

# %%
# Save the final dataframe to a new parquet file
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
output_file = f"{data_dir}/03B{timestamp}_orig_input_event_list_mapper.parquet"
encoded_feature_input_file_df.to_parquet(output_file, index=False)

print(f"New parquet file saved to: {output_file}")
