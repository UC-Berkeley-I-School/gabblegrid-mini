# %% [markdown]
# # <font color = lightcoral>Setting Random Seed
# >
# ### <font color = red> Non-Overlapping Windows
#
# > Running Combinations for Non-Overlapping Transformer Models
# >
#
# #### <font color = tomato> Current run
#
# ![image.png](attachment:56269dd1-2b14-42d1-b260-6fb4d4ede572.png)
#
# #### <font color = tomato> Prior run
# ![image.png](attachment:5352b68e-f678-448f-af20-11805ef9a5a5.png)

# %% [markdown]
# #### <font color = tomato> Prior Run (with similar factors - but no early stopping)
#
# ![image.png](attachment:a6d3d1bc-1f9f-4026-a4a5-64d863847cc1.png)

# %% [markdown]
# ### <font color = teal> Model Improvement Options

# %% [markdown]
# 1. Feature Engineering
# >
# > Create Additional Features: Extract new features from existing ones.
# >
# > Interaction Features: Combine features to create interaction terms.
# >
# 2. Handling Imbalance
#
# > SMOTE: Synthesize new samples for the minority class.
# >
# > Under-sampling: Reduce the number of samples in the majority class.
# >
# 3. Class Weights
# >
# > Adjust loss function to give more importance to the minority class.
# >
# 4. Model Complexity
#
# > Increase Model Complexity: More layers or hidden units.
# >
# > Different Architectures: Try different types of neural networks.
# >
# 5. Hyperparameter Tuning
# >
# > Use Grid Search to find the best combination of hyperparameters.
# >
# 6. Training Techniques
#
# > Early Stopping: Stop training when validation performance degrades.
# >
# >Learning Rate Scheduling: Adjust the learning rate during training.

# %% [markdown]
# ## <font color = grey> Admin

# %%
import pandas as pd
import os
import gzip
import time
import warnings
import os
import shutil
from datetime import datetime
import time
# Set display option to show the full length of the column
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore")

# Determine the base directory based on the effective user ID
if os.geteuid() == 0:  # root user
    base_dir = '/root'
else:
    base_dir = '/home/sagemaker-user'

# Set the environment variable
os.environ['BASE_DIR'] = base_dir

# Verify the base directory
print(f"Base directory set to: {base_dir}")

import warnings
warnings.simplefilter("ignore")
# Out:
# Base directory set to: /home/sagemaker-user

# %% [markdown]
# ---

# %% [markdown]
# ## <font color = lightsteelblue>EDA of Parsed Source File

# %% [markdown]
# ---

# %%
# import pandas as pd
# import time

# # Define the path to the CSV file
# # file_path = "/root/08.GIT_Repos_REF/23.Library_Transformers_Logbert_HelenG_BGL/output/bgl/BGL.log_structured.csv"

# # file_path = os.path.join(base_dir, '/mnt/efs-w210-capstone/200015/08.GIT_Repos_Anomaly_Detection/23.Library_Transformers_Logbert_HelenG_BGL/output/bgl/BGL.log_structured.csv')
# # file_path = os.path.join(base_dir, '/home/ubuntu/efs-w210-capstone-ebs/08.GIT_Repos_Anomaly_Detection/23.Library_Transformers_Logbert_HelenG_BGL/output/bgl/20240701_BGL_Log_Structuted_v1.00.csv')
# file_path = os.path.join(base_dir,'/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/09.20240704_parsed_bgl/BGL.log_structured.csv')
# # file_path = os.path.join(base_dir,'/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/09.20240704_parsed_bgl/BGL_Sample.log_structured.csv')

# # Start timing
# start_time = time.time()

# # Read the CSV file
# df = pd.read_csv(file_path)

# # Section 1: Preview
# print("\n" + "*"*100)
# print("********************** Section 1: Preview ******************************************")
# print("*"*100 + "\n")
# display(df.head())

# # Section 2: Shape of the DataFrame
# print("\n" + "*"*100)
# print("********************** Section 2: Shape of the DataFrame ****************************")
# print("*"*100 + "\n")
# print(df.shape)

# # Section 3: DataFrame Information
# print("\n" + "*"*100)
# print("********************** Section 3: DataFrame Information ****************************")
# print("*"*100 + "\n")
# print(df.info())

# # Section 4: Summary Statistics (without scientific notation)
# print("\n" + "*"*100)
# print("********************** Section 4: Summary Statistics *******************************")
# print("*"*100 + "\n")
# pd.options.display.float_format = '{:,.0f}'.format
# print(df.describe())

# # Section 5: Unique Event Templates
# print("\n" + "*"*100)
# print("********************** Section 5: Unique Event Templates ***************************")
# print("*"*100 + "\n")
# print(df['EventTemplate'].nunique())

# # Section 6: Count of Each Event Template
# print("\n" + "*"*100)
# print("********************** Section 6: Count of Each Event Template *********************")
# print("*"*100 + "\n")
# print(df['EventTemplate'].value_counts().head())

# # Section 7: Most Frequent Event Templates with Counts (ordered by occurrences)
# print("\n" + "*"*100)
# print("********************** Section 7: Most Frequent Event Templates *********************")
# print("*"*100 + "\n")
# df_sorted = df.groupby(['EventId', 'EventTemplate']).size().reset_index(name='Occurrences')
# df_sorted = df_sorted.sort_values(by='Occurrences', ascending=False).reset_index(drop=True)
# df_sorted.index += 1  # Make the index start from 1
# print(df_sorted.head())

# # Section 8: Alert Analysis
# print("\n" + "*"*100)
# print("********************** Section 8: Alert Analysis ************************************")
# print("*"*100 + "\n")

# # Count of normal vs alert logs
# label_counts = df['Label'].value_counts()
# print(f"Normal logs: {label_counts.get('-', 0)}")
# print(f"Alert logs: {label_counts.sum() - label_counts.get('-', 0)}")

# # Most frequent labels for alerts
# alert_labels = df[df['Label'] != '-']['Label'].value_counts().head()
# print("\nMost frequent alert labels:")
# print(alert_labels)

# # Distribution of alert levels
# alert_levels = df[df['Label'] != '-']['Level'].value_counts()
# print("\nDistribution of alert levels:")
# print(alert_levels)

# # Section 9: Label and Alert Level Analysis
# print("\n" + "*"*100)
# print("********************** Section 9: Label and Alert Level Analysis ********************")
# print("*"*100 + "\n")

# # Distribution of values in the Label column with an indicator for normal or alert
# df['LogType'] = df['Label'].apply(lambda x: 'Normal' if x == '-' else 'Alert')
# label_distribution = df.groupby(['LogType', 'Label']).size()
# print("\nDistribution of values in the Label column with an indicator for normal or alert:")
# display(label_distribution)

# # Distribution of values in the Level column for alerts
# alert_level_distribution = df[df['LogType'] == 'Alert'].groupby('Level').size().reset_index(name='count')
# alert_level_distribution['LogType'] = 'Alert'
# print("\nDistribution of values in the Level column for alerts:")
# display(alert_level_distribution[['LogType', 'Level', 'count']])

# # Distribution of values in the Level column for normal logs with an indicator for normal or alert
# normal_level_distribution = df[df['LogType'] == 'Normal'].groupby('Level').size().reset_index(name='count')
# normal_level_distribution['LogType'] = 'Normal'
# print("\nDistribution of values in the Level column for normal logs with an indicator for normal or alert:")
# display(normal_level_distribution[['LogType', 'Level', 'count']])

# # Section 10: Combined LogType, Label, Level, and Count
# print("\n" + "*"*100)
# print("********************** Section 10: Combined LogType, Label, Level, and Count ********")
# print("*"*100 + "\n")

# combined_distribution = df.groupby(['LogType', 'Label', 'Level']).size().reset_index(name='count')
# combined_distribution = combined_distribution.sort_values(by=['LogType', 'count', 'Label'], ascending=[False, False, True])
# display(combined_distribution)

# # Section 11: Count Unique Values in Each Column
# print("\n" + "*"*100)
# print("********************** Section 11: Count Unique Values in Each Column ****************")
# print("*"*100 + "\n")
# print(df.nunique())

# # Section 12: Random Sample of 10 Alert Rows
# print("\n" + "*"*100)
# print("********************** Section 12: Random Sample of 10 Alert Rows ********************")
# print("*"*100 + "\n")
# alert_rows = df[df['Label'] != '-']
# sample_alert_rows = alert_rows.sample(n=10) if len(alert_rows) >= 10 else alert_rows
# display(sample_alert_rows)

# # Section 13: Analysis of Rows for Normal and Alert Labels
# print("\n" + "*"*100)
# print("********************** Section 13: Analysis of Rows for Normal and Alert Labels ********")
# print("*"*100 + "\n")

# # Grouping by LogType to count rows for Normal and Alert logs
# logtype_counts = df['LogType'].value_counts()
# total_logs = logtype_counts.sum()
# normal_percentage = (logtype_counts['Normal'] / total_logs) * 100
# alert_percentage = (logtype_counts['Alert'] / total_logs) * 100

# print(f"Normal logs: {logtype_counts['Normal']} ({normal_percentage:.2f}%)")
# print(f"Alert logs: {logtype_counts['Alert']} ({alert_percentage:.2f}%)")

# # End timing
# end_time = time.time()
# duration = end_time - start_time
# print("\n" + "_"*100)
# print(f"\nTime taken: {duration:.2f} seconds")
# print("\n" + "_"*100)

# %% [markdown]
# ---

# %% [markdown]
# ## <font color = lightsteelblue>EDA of Final Features File

# %%
# import pandas as pd
# import time
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Start timing
# start_time = time.time()

# data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/12.20240709_More_New_Features/01.Full_Base'
# input_file = f"{data_dir}/20240709_full_more_new_features_v1.00.parquet"
# output_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/12.20240709_More_New_Features/02.Full_Train_Test'

# # Section 1: Preview
# print("\n" + "*"*100)
# print("********************** Section 1: Preview ******************************************")
# print("*"*100 + "\n")

# # Load the parquet file
# df = pd.read_parquet(input_file)

# # Display the head of the DataFrame
# display(df.iloc[:, :20].head())

# # Section 2: Basic Information
# print("\n" + "*"*100)
# print("********************** Section 2: Basic Information ******************************************")
# print("*"*100 + "\n")

# # 1. Display the shape of the DataFrame
# print(f"Shape of the DataFrame: {df.shape}\n")

# # 2. Display the class distribution
# print("Class distribution:")
# print(df['Class'].value_counts(), "\n")

# # 3. Check for NaN values and display columns with issues
# print("Columns with NaN values:")
# nan_columns = df.columns[df.isna().any()].tolist()
# if nan_columns:
#     print(df[nan_columns].isna().sum(), "\n")
# else:
#     print("No NaN values found.\n")

# # 4. Display correlation matrix for numerical columns as a heatmap
# print("Correlation matrix for numerical columns:")
# corr_matrix = df.iloc[:, :20].corr()
# plt.figure(figsize=(10, 8))
# sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
# plt.title("Correlation Matrix Heatmap")
# plt.show()

# # # 5. Display the top 5 rows of the first 20 EventId columns
# event_id_columns = [col for col in df.columns if col.startswith('EventId_')]
# # print("Top 5 rows of the first 20 EventId columns:")
# # print(df[event_id_columns[:20]].head(), "\n")

# # 6. Display the distribution of 'unique_events' and 'transitions' columns
# print("Distribution of 'unique_events' and 'transitions' columns:")
# print(df[['unique_events', 'transitions']].describe(), "\n")

# # Section 3: Distribution by Class
# print("\n" + "*"*100)
# print("********************** Section 3: Distribution by Class ******************************************")
# print("*"*100 + "\n")

# # 1. Distribution of 'transitions' by class
# print("Distribution of 'transitions' by class:")
# print(df.groupby('Class')['transitions'].describe(), "\n")

# # 2. Distribution of 'unique_events' by class
# print("Distribution of 'unique_events' by class:")
# print(df.groupby('Class')['unique_events'].describe(), "\n")

# # Section 4: Common Sequences
# print("\n" + "*"*100)
# print("********** Section 4: Top 5 Most Common Unique Event Sequences by Class with Sampling ***************")
# print("*"*100 + "\n")

# # Sampling 1% from class 0 and 5% from class 1 based on maximum transitions
# class_0_sample = df[df['Class'] == 0].nlargest(int(len(df[df['Class'] == 0]) * 0.01), 'transitions')
# class_1_sample = df[df['Class'] == 1].nlargest(int(len(df[df['Class'] == 1]) * 0.05), 'transitions')

# # Combine the samples
# sampled_df = pd.concat([class_0_sample, class_1_sample])

# # Use a subset of EventId columns for processing
# subset_event_id_columns = event_id_columns[:100]  # Adjust this number as needed

# # Create sequences of unique events from the subset of EventId columns
# sampled_df['unique_sequence'] = sampled_df[subset_event_id_columns].apply(lambda row: '-'.join(row.astype(str).unique()), axis=1)

# # Calculate the top 5 most common unique sequences by class, including transitions
# top_unique_sequences_sampled = sampled_df.groupby(['Class', 'unique_sequence', 'transitions']).size().reset_index(name='counts').sort_values(['Class', 'counts'], ascending=[True, False]).groupby('Class').head(5)

# # Display the top unique sequences with transitions
# display(top_unique_sequences_sampled)

# # End timing
# end_time = time.time()
# duration = end_time - start_time
# print("\n" + "_"*100)
# print(f"\nTime taken for EDA: {duration:.2f} seconds")
# print("\n" + "_"*100)

# %% [markdown]
# ___
# # <font color = darkkhaki> (D). Data Prep --> Create sample for sanity testing

# %%
# import pandas as pd

# # Load the data
# data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/09.20240704_parsed_bgl'
# input_file = f"{data_dir}/20240704__full__new_features_v1.10.parquet"
# df = pd.read_parquet(input_file)

# # Split the data
# train_size = int(0.8 * len(df))
# train_df = df[:train_size]
# test_df = df[train_size:]

# # Save the splits
# train_output_file = f"{data_dir}/20240704__train__new_features_v1.10.parquet"
# test_output_file = f"{data_dir}/20240704__test__new_features_v1.10.parquet"

# train_df.to_parquet(train_output_file)
# test_df.to_parquet(test_output_file)

# %%
# import pandas as pd

# ####################### Full Base ######################################
# # data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/01.Full_Base/'
# # input_file = f"{data_dir}/20240704__full__new_features_v1.10.parquet"

# ####################### Sample Base ######################################
# data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/03.Sample_Base/'
# input_file = f"{data_dir}/20240704__sample__new_features_v1.50.parquet"

# ####################### Full Test_Train ######################################
# # data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/02.Full_Train_Test/'
# # input_file = f"{data_dir}/20240704__train__new_features_v1.10.parquet"
# # input_file = f"{data_dir}/20240704__test__new_features_v1.10.parquet"

# ####################### Sample Test_Train ######################################
# # data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/04.Sample_Train_Test/'
# # input_file = f"{data_dir}/20240705_train_claude.parquet"
# # input_file = f"{data_dir}/20240705_test_claude.parquet"
# # input_file = f"{data_dir}/X_train.parquet"

# # Read the parquet file
# df = pd.read_parquet(input_file)

# # Count the number of rows
# row_count = len(df)

# print("*"*100 + "\n")
# print("************************************** # Rows ********************************")

# print(f"The number of rows in the parquet file is: {row_count}")

# # print("*"*100 + "\n")
# print("************************************** Distinct Records by Class ****************")

# # Count the number of distinct records by Class
# distinct_class_counts = df['Class'].value_counts()

# print(f"The count of distinct records by Class is:\n{distinct_class_counts}")

# print("************************************** Shape ***************************")

# print(df.shape)

# print("************************************** Columns *************************")

# print(df.columns)

# # print("*"*100 + "\n")
# print("************************************** Display Sample ********************************")

# # Select the first 8 columns (assuming they exist)
# first_eight_columns = df.iloc[:, :12]  # Use indexing for columns

# # Display the first few rows of the selected columns
# display(first_eight_columns.head(5))

# %% [markdown]
# ----

# %% [markdown]
# # <font color = tomato> Loop

# %%
################################### Parameters and Hyperparameters ################################

# Parameters and Hyperparameters
data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/12.20240709_More_New_Features/01.Full_Base'
input_file = f"{data_dir}/20240709_full_more_new_features_v1.00.parquet"
output_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/12.20240709_More_New_Features/02.Full_Train_Test'
model_save_dir = '/home/ubuntu/efs-w210-capstone-ebs/04.Saved_Models/01.Non_Overlapping'
jupyter_notebook_name = '20240710_(I-1)_Transformers_Non_Overlapping_EarlyStopping_Other_v1.00'  # Replace with the actual name of your notebook

# Generate timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
results_file = f"{output_dir}/{timestamp}_results_df.csv"

# Hyperparameter variations to test
max_events_list = [20, 30, 40]  # Different values to test
hidden_size_list = [64]  # Different values to test
dropout_list = [0.3]  # Different values to test
num_layers_list = [2]  # Different values to test
input_length_list = [10, 20, 30]  # Different values to test
gap_list = [1,2,3,4, 5]  # Different values to test
prediction_period_list = [1]  # Different values to test
num_epochs_list = [25, 50]  # Different values to test

test_size = 0.2
shuffle = False

output_size = 1
batch_size = 16
learning_rate = 0.001

import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# DataFrame to track results
results_df = pd.DataFrame(columns=['Run', 'Max Events', 'Input Length', 'Hidden Size', 'Dropout', 'Num Layers', 'Gap', 'Prediction Period', 'Num Epochs', 'Precision', 'Recall', 'Accuracy', 'F1', 'TN', 'FP', 'FN', 'TP'])

run_id = 0

# Start timing
start_time = time.time()

for max_events in max_events_list:
    for input_length in input_length_list:
        for hidden_size in hidden_size_list:
            for dropout in dropout_list:
                for num_layers in num_layers_list:
                    for gap in gap_list:
                        for prediction_period in prediction_period_list:
                            for num_epochs in num_epochs_list:
                                run_id += 1
                                print(f"Run {run_id}: max_events={max_events}, input_length={input_length}, hidden_size={hidden_size}, dropout={dropout}, num_layers={num_layers}, gap={gap}, prediction_period={prediction_period}, num_epochs={num_epochs}")

                                # Set random seed for reproducibility
                                random_seed = 42
                                np.random.seed(random_seed)
                                random.seed(random_seed)
                                torch.manual_seed(random_seed)
                                torch.cuda.manual_seed(random_seed)

                                # Generate a unique model save path for this run
                                model_save_path = f"{model_save_dir}/{timestamp}_{jupyter_notebook_name}_run_{run_id}_checkpoint.pt"

                                ################################### Data Preprocessing ################################

                                # Load the data
                                df = pd.read_parquet(input_file)

                                # Select derived features and a subset of EventID columns
                                selected_columns = ['time_start_int', 'Class', 'unique_events', 'most_frequent_event', 'transitions', 'entropy', 
                                                    'hour_of_day', 'day_of_week', 'event_count', 'top_event_frequency', 'prev_event_count', 
                                                    'transition_rate', 'high_transition_rate', 'prev_entropy', 'entropy_change', 
                                                    'rolling_event_count', 'rolling_unique_event_count']
                                event_id_columns = [col for col in df.columns if col.startswith('EventId_')]

                                # Replace -1 values with 0
                                df[event_id_columns].replace(-1, 0, inplace=True)

                                # Scale numerical features
                                scaler = StandardScaler()
                                numerical_features = ['unique_events', 'transitions', 'entropy', 'hour_of_day', 'day_of_week', 'event_count', 
                                                      'top_event_frequency', 'prev_event_count', 'transition_rate', 'prev_entropy', 
                                                      'entropy_change', 'rolling_event_count', 'rolling_unique_event_count']
                                df[selected_columns[2:]] = scaler.fit_transform(df[selected_columns[2:]])

                                # Encode categorical features
                                label_encoder = LabelEncoder()
                                df['most_frequent_event'] = label_encoder.fit_transform(df['most_frequent_event'])

                                # Apply PCA to EventID columns to reduce them to the number of features specified by max_events
                                pca = PCA(n_components=max_events)
                                event_id_pca = pca.fit_transform(df[event_id_columns])

                                # Create a new DataFrame with the reduced EventID features
                                event_id_pca_df = pd.DataFrame(event_id_pca, columns=[f'EventId_PCA_{i+1}' for i in range(max_events)])

                                # Combine the reduced EventID features with the selected columns
                                df_reduced = pd.concat([df[selected_columns], event_id_pca_df], axis=1)

                                # Verify the number of features
                                input_size = df_reduced.shape[1] - 2  # Subtract 2 for 'Class' and 'time_start_int' columns

                                ################################### Create Sequences ################################

                                def create_sequences(data, time_index_col, feature_cols, target_col, input_length, gap=1, prediction_period=1):
                                    sequences = []
                                    targets = []
                                    
                                    start_idx = 0
                                    total_length = len(data)
                                    while start_idx + input_length + gap + prediction_period <= total_length:
                                        end_idx = start_idx + input_length
                                        sequence = data[feature_cols].iloc[start_idx:end_idx].values
                                        target = data[target_col].iloc[end_idx + gap:end_idx + gap + prediction_period].values[0]
                                        sequences.append(sequence)
                                        targets.append(target)
                                        start_idx = end_idx + gap + prediction_period  # Move to the next non-overlapping sequence
                                    
                                    return np.array(sequences), np.array(targets)

                                feature_cols = [col for col in df_reduced.columns if col != 'Class']
                                target_col = 'Class'

                                X, y = create_sequences(df_reduced, 'time_start_int', feature_cols, target_col, input_length=input_length, gap=gap, prediction_period=prediction_period)

                                ################################### Split & SMOTE ################################

                                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, shuffle=shuffle, random_state=random_seed)

                                # Flatten X_train to 2D array for SMOTE
                                X_train = X_train.reshape(X_train.shape[0], -1)

                                # Apply SMOTE
                                smote = SMOTE(random_state=random_seed)
                                X_train, y_train = smote.fit_resample(X_train, y_train)

                                # Reshape X_train back to 3D array
                                n_samples = X_train.shape[0]
                                input_size = X_train.shape[1] // input_length  # Calculate the input size after SMOTE
                                X_train = X_train.reshape(n_samples, input_length, input_size)

                                # Drop the first column from X_train and X_test
                                X_train = X_train[:, :, 1:]
                                X_test = X_test.reshape(X_test.shape[0], input_length, input_size)
                                X_test = X_test[:, :, 1:]

                                ################################### Transformer ################################

                                # Define the Transformer model
                                class TransformerModel(nn.Module):
                                    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
                                        super(TransformerModel, self).__init__()
                                        self.embedding = nn.Linear(input_size, hidden_size)
                                        self.pos_encoder = nn.Embedding(input_length, hidden_size)
                                        self.transformer = nn.Transformer(hidden_size, nhead=4, num_encoder_layers=num_layers, num_decoder_layers=num_layers, dropout=dropout)
                                        self.fc = nn.Linear(hidden_size, output_size)
                                    
                                    def forward(self, x):
                                        x = self.embedding(x)
                                        positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)
                                        x = x + self.pos_encoder(positions)
                                        x = self.transformer(x, x)
                                        x = self.fc(x[:, -1, :])
                                        return x

                                # Convert data to PyTorch tensors
                                X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
                                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
                                X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
                                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

                                # Create DataLoader
                                train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
                                train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

                                # Create DataLoader for validation data
                                val_dataset = TensorDataset(X_test_tensor, y_test_tensor)
                                val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

                                # Initialize the model, loss function, optimizer, and scheduler
                                model = TransformerModel(input_size - 1, hidden_size, num_layers, output_size, dropout)  # Correct input size
                                criterion = nn.BCEWithLogitsLoss()  # For binary classification
                                optimizer = optim.Adam(model.parameters(), lr=learning_rate)
                                scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, verbose=True)

                                # Early stopping
                                class EarlyStopping:
                                    def __init__(self, patience=5, verbose=False, delta=0, model_save_path="checkpoint.pt"):
                                        self.patience = patience
                                        self.verbose = verbose
                                        self.counter = 0
                                        self.best_score = None
                                        self.early_stop = False
                                        self.val_loss_min = np.Inf
                                        self.delta = delta
                                        self.model_save_path = model_save_path

                                    def __call__(self, val_loss, model):
                                        score = -val_loss

                                        if self.best_score is None:
                                            self.best_score = score
                                            self.save_checkpoint(val_loss, model)
                                        elif score < self.best_score + self.delta:
                                            self.counter += 1
                                            if self.verbose:
                                                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
                                            if self.counter >= self.patience:
                                                self.early_stop = True
                                        else:
                                            self.best_score = score
                                            self.save_checkpoint(val_loss, model)
                                            self.counter = 0

                                    def save_checkpoint(self, val_loss, model):
                                        '''Saves model when validation loss decreases.'''
                                        if self.verbose:
                                            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
                                        torch.save(model.state_dict(), self.model_save_path)  # save the state dict
                                        self.val_loss_min = val_loss

                                early_stopping = EarlyStopping(patience=5, verbose=True, model_save_path=model_save_path)

                                # Training loop with validation and early stopping
                                best_val_loss = float('inf')

                                for epoch in range(num_epochs):
                                    model.train()
                                    for X_batch, y_batch in train_loader:
                                        outputs = model(X_batch)
                                        loss = criterion(outputs, y_batch)
                                        
                                        optimizer.zero_grad()
                                        loss.backward()
                                        optimizer.step()

                                    model.eval()
                                    val_loss = 0.0
                                    with torch.no_grad():
                                        for X_val_batch, y_val_batch in val_loader:
                                            val_outputs = model(X_val_batch)
                                            val_loss += criterion(val_outputs, y_val_batch).item()

                                    val_loss /= len(val_loader)
                                    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {val_loss:.4f}')
                                    
                                    scheduler.step(val_loss)
                                    early_stopping(val_loss, model)

                                    if early_stopping.early_stop:
                                        print("Early stopping")
                                        break

                                # Load the best model
                                model.load_state_dict(torch.load(model_save_path))

                                ################################### Model Eval ################################

                                # Evaluate the model on the test set
                                model.eval()
                                with torch.no_grad():
                                    test_outputs = model(X_test_tensor)
                                    test_outputs = torch.sigmoid(test_outputs)  # Apply sigmoid to get probabilities
                                    test_outputs = test_outputs.cpu().numpy()

                                    # Convert y_test_tensor to NumPy array only if it is a tensor
                                    if isinstance(y_test_tensor, torch.Tensor):
                                        y_test_tensor = y_test_tensor.cpu().numpy()

                                    test_preds = (test_outputs > 0.5).astype(int)  # Convert probabilities to binary predictions

                                # Calculate evaluation metrics
                                conf_matrix = confusion_matrix(y_test_tensor, test_preds)
                                precision = precision_score(y_test_tensor, test_preds, zero_division=0)
                                recall = recall_score(y_test_tensor, test_preds, zero_division=0)
                                accuracy = accuracy_score(y_test_tensor, test_preds)
                                f1 = f1_score(y_test_tensor, test_preds, zero_division=0)
                                tn, fp, fn, tp = conf_matrix.ravel()

                                # Append results to DataFrame
                                results_df = pd.concat([results_df, pd.DataFrame([{
                                    'Run': run_id,
                                    'Max Events': max_events,
                                    'Input Length': input_length,
                                    'Hidden Size': hidden_size,
                                    'Dropout': dropout,
                                    'Num Layers': num_layers,
                                    'Gap': gap,
                                    'Prediction Period': prediction_period,
                                    'Num Epochs': num_epochs,
                                    'Precision': precision,
                                    'Recall': recall,
                                    'Accuracy': accuracy,
                                    'F1': f1,
                                    'TN': tn,
                                    'FP': fp,
                                    'FN': fn,
                                    'TP': tp
                                }])], ignore_index=True)

                                # Save the results DataFrame to a CSV file
                                results_df.to_csv(results_file, index=False)

                                # Print the results of the current run
                                print(f"Run {run_id} Results: Max Events={max_events}, Input Length={input_length}, Hidden Size={hidden_size}, Dropout={dropout}, Num Layers={num_layers}, Gap={gap}, Prediction Period={prediction_period}, Num Epochs={num_epochs}, Precision={precision:.6f}, Recall={recall:.6f}, Accuracy={accuracy:.6f}, F1={f1:.6f}, TN={tn}, FP={fp}, FN={fn}, TP={tp}")

                                print(f"Run {run_id} completed")
                                print("*"*100 + "\n")

pd.set_option('display.float_format', lambda x: '%.6f' % x)

# Display the results DataFrame
display(results_df)

# End timing
end_time = time.time()
duration = end_time - start_time
print("\n" + "_"*100)
print(f"\nTime taken for main loop: {duration:.2f} seconds")
print("\n" + "_"*100)

################################### Plot Results ################################

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set a pastel color palette with different colors for each plot
colors = sns.color_palette("pastel", 8)

# Plot the results
fig, axes = plt.subplots(2, 4, figsize=(20, 10))

metrics = ['Precision', 'Recall', 'Accuracy', 'F1', 'TN', 'FP', 'FN', 'TP']
for i, metric in enumerate(metrics):
    ax = axes[i//4, i%4]
    
    # Plot the metric with thicker lines and different colors
    ax.plot(results_df['Run'], results_df[metric], color=colors[i], linewidth=2.5)
    
    # Annotate the points
    for j, txt in enumerate(results_df[metric]):
        if not np.isnan(txt):  # Only label non-NaN points
            ax.annotate(f'{txt:.2f}', (results_df['Run'][j], results_df[metric][j]), fontsize=8)
    
    ax.set_title(metric)
    ax.set_xlabel('Run')
    ax.set_ylabel(metric)

plt.tight_layout()
plt.show()
# Out:
# Run 1: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.8477, Validation Loss: 0.8964
# Validation loss decreased (inf --> 0.896425).  Saving model ...
# Epoch [2/25], Loss: 0.7209, Validation Loss: 0.7637
# Validation loss decreased (0.896425 --> 0.763672).  Saving model ...
# Epoch [3/25], Loss: 0.7141, Validation Loss: 0.7922
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.7001, Validation Loss: 0.7169
# Validation loss decreased (0.763672 --> 0.716880).  Saving model ...
# Epoch [5/25], Loss: 0.6948, Validation Loss: 0.7317
# EarlyStopping counter: 1 out of 5
# Epoch [6/25], Loss: 0.7081, Validation Loss: 0.7019
# Validation loss decreased (0.716880 --> 0.701890).  Saving model ...
# Epoch [7/25], Loss: 0.7148, Validation Loss: 0.5741
# Validation loss decreased (0.701890 --> 0.574065).  Saving model ...
# Epoch [8/25], Loss: 0.6646, Validation Loss: 0.7314
# EarlyStopping counter: 1 out of 5
# Epoch [9/25], Loss: 0.6653, Validation Loss: 0.7133
# EarlyStopping counter: 2 out of 5
# Epoch [10/25], Loss: 0.6677, Validation Loss: 0.6715
# EarlyStopping counter: 3 out of 5
# Epoch [11/25], Loss: 0.6932, Validation Loss: 0.7461
# EarlyStopping counter: 4 out of 5
# Epoch [12/25], Loss: 0.6467, Validation Loss: 0.6853
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 1 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.921811, F1=0.000000, TN=224, FP=0, FN=19, TP=0
# Run 1 completed
# ****************************************************************************************************
#
# Run 2: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.8477, Validation Loss: 0.8964
# Validation loss decreased (inf --> 0.896425).  Saving model ...
# Epoch [2/50], Loss: 0.7209, Validation Loss: 0.7637
# Validation loss decreased (0.896425 --> 0.763672).  Saving model ...
# Epoch [3/50], Loss: 0.7141, Validation Loss: 0.7922
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.7001, Validation Loss: 0.7169
# Validation loss decreased (0.763672 --> 0.716880).  Saving model ...
# Epoch [5/50], Loss: 0.6948, Validation Loss: 0.7317
# EarlyStopping counter: 1 out of 5
# Epoch [6/50], Loss: 0.7081, Validation Loss: 0.7019
# Validation loss decreased (0.716880 --> 0.701890).  Saving model ...
# Epoch [7/50], Loss: 0.7148, Validation Loss: 0.5741
# Validation loss decreased (0.701890 --> 0.574065).  Saving model ...
# Epoch [8/50], Loss: 0.6646, Validation Loss: 0.7314
# EarlyStopping counter: 1 out of 5
# Epoch [9/50], Loss: 0.6653, Validation Loss: 0.7133
# EarlyStopping counter: 2 out of 5
# Epoch [10/50], Loss: 0.6677, Validation Loss: 0.6715
# EarlyStopping counter: 3 out of 5
# Epoch [11/50], Loss: 0.6932, Validation Loss: 0.7461
# EarlyStopping counter: 4 out of 5
# Epoch [12/50], Loss: 0.6467, Validation Loss: 0.6853
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 2 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.921811, F1=0.000000, TN=224, FP=0, FN=19, TP=0
# Run 2 completed
# ****************************************************************************************************
#
# Run 3: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7147, Validation Loss: 0.7671
# Validation loss decreased (inf --> 0.767129).  Saving model ...
# Epoch [2/25], Loss: 0.7036, Validation Loss: 0.7218
# Validation loss decreased (0.767129 --> 0.721760).  Saving model ...
# Epoch [3/25], Loss: 0.6766, Validation Loss: 0.6782
# Validation loss decreased (0.721760 --> 0.678181).  Saving model ...
# Epoch [4/25], Loss: 0.7353, Validation Loss: 0.6127
# Validation loss decreased (0.678181 --> 0.612747).  Saving model ...
# Epoch [5/25], Loss: 0.7247, Validation Loss: 0.5784
# Validation loss decreased (0.612747 --> 0.578360).  Saving model ...
# Epoch [6/25], Loss: 0.6724, Validation Loss: 0.7162
# EarlyStopping counter: 1 out of 5
# Epoch [7/25], Loss: 0.6176, Validation Loss: 0.5229
# Validation loss decreased (0.578360 --> 0.522925).  Saving model ...
# Epoch [8/25], Loss: 0.6630, Validation Loss: 0.6381
# EarlyStopping counter: 1 out of 5
# Epoch [9/25], Loss: 0.7177, Validation Loss: 0.5778
# EarlyStopping counter: 2 out of 5
# Epoch [10/25], Loss: 0.7526, Validation Loss: 0.5825
# EarlyStopping counter: 3 out of 5
# Epoch [11/25], Loss: 0.6102, Validation Loss: 0.5989
# EarlyStopping counter: 4 out of 5
# Epoch [12/25], Loss: 0.7060, Validation Loss: 0.6307
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 3 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=25, Precision=0.500000, Recall=0.071429, Accuracy=0.937500, F1=0.125000, TN=209, FP=1, FN=13, TP=1
# Run 3 completed
# ****************************************************************************************************
#
# Run 4: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7147, Validation Loss: 0.7671
# Validation loss decreased (inf --> 0.767129).  Saving model ...
# Epoch [2/50], Loss: 0.7036, Validation Loss: 0.7218
# Validation loss decreased (0.767129 --> 0.721760).  Saving model ...
# Epoch [3/50], Loss: 0.6766, Validation Loss: 0.6782
# Validation loss decreased (0.721760 --> 0.678181).  Saving model ...
# Epoch [4/50], Loss: 0.7353, Validation Loss: 0.6127
# Validation loss decreased (0.678181 --> 0.612747).  Saving model ...
# Epoch [5/50], Loss: 0.7247, Validation Loss: 0.5784
# Validation loss decreased (0.612747 --> 0.578360).  Saving model ...
# Epoch [6/50], Loss: 0.6724, Validation Loss: 0.7162
# EarlyStopping counter: 1 out of 5
# Epoch [7/50], Loss: 0.6176, Validation Loss: 0.5229
# Validation loss decreased (0.578360 --> 0.522925).  Saving model ...
# Epoch [8/50], Loss: 0.6630, Validation Loss: 0.6381
# EarlyStopping counter: 1 out of 5
# Epoch [9/50], Loss: 0.7177, Validation Loss: 0.5778
# EarlyStopping counter: 2 out of 5
# Epoch [10/50], Loss: 0.7526, Validation Loss: 0.5825
# EarlyStopping counter: 3 out of 5
# Epoch [11/50], Loss: 0.6102, Validation Loss: 0.5989
# EarlyStopping counter: 4 out of 5
# Epoch [12/50], Loss: 0.7060, Validation Loss: 0.6307
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 4 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=50, Precision=0.500000, Recall=0.071429, Accuracy=0.937500, F1=0.125000, TN=209, FP=1, FN=13, TP=1
# Run 4 completed
# ****************************************************************************************************
#
# Run 5: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.5940, Validation Loss: 0.6188
# Validation loss decreased (inf --> 0.618811).  Saving model ...
# Epoch [2/25], Loss: 0.3493, Validation Loss: 0.8138
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.4756, Validation Loss: 0.9159
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.2567, Validation Loss: 0.7328
# EarlyStopping counter: 3 out of 5
# Epoch [5/25], Loss: 0.6902, Validation Loss: 0.6463
# EarlyStopping counter: 4 out of 5
# Epoch [6/25], Loss: 0.5911, Validation Loss: 0.6353
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 5 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=25, Precision=0.162162, Recall=0.352941, Accuracy=0.798077, F1=0.222222, TN=160, FP=31, FN=11, TP=6
# Run 5 completed
# ****************************************************************************************************
#
# Run 6: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.5940, Validation Loss: 0.6188
# Validation loss decreased (inf --> 0.618811).  Saving model ...
# Epoch [2/50], Loss: 0.3493, Validation Loss: 0.8138
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.4756, Validation Loss: 0.9159
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.2567, Validation Loss: 0.7328
# EarlyStopping counter: 3 out of 5
# Epoch [5/50], Loss: 0.6902, Validation Loss: 0.6463
# EarlyStopping counter: 4 out of 5
# Epoch [6/50], Loss: 0.5911, Validation Loss: 0.6353
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 6 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=50, Precision=0.162162, Recall=0.352941, Accuracy=0.798077, F1=0.222222, TN=160, FP=31, FN=11, TP=6
# Run 6 completed
# ****************************************************************************************************
#
# Run 7: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6571, Validation Loss: 0.8183
# Validation loss decreased (inf --> 0.818342).  Saving model ...
# Epoch [2/25], Loss: 0.6768, Validation Loss: 0.5707
# Validation loss decreased (0.818342 --> 0.570659).  Saving model ...
# Epoch [3/25], Loss: 0.7135, Validation Loss: 0.6407
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.6467, Validation Loss: 0.6160
# EarlyStopping counter: 2 out of 5
# Epoch [5/25], Loss: 0.6280, Validation Loss: 0.6335
# EarlyStopping counter: 3 out of 5
# Epoch [6/25], Loss: 0.7109, Validation Loss: 0.6576
# EarlyStopping counter: 4 out of 5
# Epoch [7/25], Loss: 0.6857, Validation Loss: 0.6586
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 7 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=25, Precision=0.272727, Recall=0.130435, Accuracy=0.855670, F1=0.176471, TN=163, FP=8, FN=20, TP=3
# Run 7 completed
# ****************************************************************************************************
#
# Run 8: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6571, Validation Loss: 0.8183
# Validation loss decreased (inf --> 0.818342).  Saving model ...
# Epoch [2/50], Loss: 0.6768, Validation Loss: 0.5707
# Validation loss decreased (0.818342 --> 0.570659).  Saving model ...
# Epoch [3/50], Loss: 0.7135, Validation Loss: 0.6407
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.6467, Validation Loss: 0.6160
# EarlyStopping counter: 2 out of 5
# Epoch [5/50], Loss: 0.6280, Validation Loss: 0.6335
# EarlyStopping counter: 3 out of 5
# Epoch [6/50], Loss: 0.7109, Validation Loss: 0.6576
# EarlyStopping counter: 4 out of 5
# Epoch [7/50], Loss: 0.6857, Validation Loss: 0.6586
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 8 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=50, Precision=0.272727, Recall=0.130435, Accuracy=0.855670, F1=0.176471, TN=163, FP=8, FN=20, TP=3
# Run 8 completed
# ****************************************************************************************************
#
# Run 9: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.5967, Validation Loss: 0.4496
# Validation loss decreased (inf --> 0.449603).  Saving model ...
# Epoch [2/25], Loss: 0.6444, Validation Loss: 0.6692
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.6012, Validation Loss: 0.5270
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.6729, Validation Loss: 0.6564
# EarlyStopping counter: 3 out of 5
# Epoch [5/25], Loss: 0.6112, Validation Loss: 0.5986
# EarlyStopping counter: 4 out of 5
# Epoch [6/25], Loss: 0.7729, Validation Loss: 0.6200
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 9 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.917582, F1=0.000000, TN=167, FP=0, FN=15, TP=0
# Run 9 completed
# ****************************************************************************************************
#
# Run 10: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.5967, Validation Loss: 0.4496
# Validation loss decreased (inf --> 0.449603).  Saving model ...
# Epoch [2/50], Loss: 0.6444, Validation Loss: 0.6692
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.6012, Validation Loss: 0.5270
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.6729, Validation Loss: 0.6564
# EarlyStopping counter: 3 out of 5
# Epoch [5/50], Loss: 0.6112, Validation Loss: 0.5986
# EarlyStopping counter: 4 out of 5
# Epoch [6/50], Loss: 0.7729, Validation Loss: 0.6200
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 10 Results: Max Events=20, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.917582, F1=0.000000, TN=167, FP=0, FN=15, TP=0
# Run 10 completed
# ****************************************************************************************************
#
# Run 11: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6599, Validation Loss: 0.6050
# Validation loss decreased (inf --> 0.605026).  Saving model ...
# Epoch [2/25], Loss: 0.7194, Validation Loss: 0.5167
# Validation loss decreased (0.605026 --> 0.516702).  Saving model ...
# Epoch [3/25], Loss: 0.7146, Validation Loss: 0.6148
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.6972, Validation Loss: 0.5739
# EarlyStopping counter: 2 out of 5
# Epoch [5/25], Loss: 0.8188, Validation Loss: 0.5212
# EarlyStopping counter: 3 out of 5
# Epoch [6/25], Loss: 0.6210, Validation Loss: 0.7276
# EarlyStopping counter: 4 out of 5
# Epoch [7/25], Loss: 0.6471, Validation Loss: 0.6662
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 11 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.924242, F1=0.000000, TN=122, FP=1, FN=9, TP=0
# Run 11 completed
# ****************************************************************************************************
#
# Run 12: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6599, Validation Loss: 0.6050
# Validation loss decreased (inf --> 0.605026).  Saving model ...
# Epoch [2/50], Loss: 0.7194, Validation Loss: 0.5167
# Validation loss decreased (0.605026 --> 0.516702).  Saving model ...
# Epoch [3/50], Loss: 0.7146, Validation Loss: 0.6148
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.6972, Validation Loss: 0.5739
# EarlyStopping counter: 2 out of 5
# Epoch [5/50], Loss: 0.8188, Validation Loss: 0.5212
# EarlyStopping counter: 3 out of 5
# Epoch [6/50], Loss: 0.6210, Validation Loss: 0.7276
# EarlyStopping counter: 4 out of 5
# Epoch [7/50], Loss: 0.6471, Validation Loss: 0.6662
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 12 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.924242, F1=0.000000, TN=122, FP=1, FN=9, TP=0
# Run 12 completed
# ****************************************************************************************************
#
# Run 13: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6255, Validation Loss: 0.9222
# Validation loss decreased (inf --> 0.922206).  Saving model ...
# Epoch [2/25], Loss: 0.7132, Validation Loss: 0.6882
# Validation loss decreased (0.922206 --> 0.688199).  Saving model ...
# Epoch [3/25], Loss: 0.6860, Validation Loss: 0.5696
# Validation loss decreased (0.688199 --> 0.569551).  Saving model ...
# Epoch [4/25], Loss: 0.6726, Validation Loss: 0.6637
# EarlyStopping counter: 1 out of 5
# Epoch [5/25], Loss: 0.7254, Validation Loss: 0.6773
# EarlyStopping counter: 2 out of 5
# Epoch [6/25], Loss: 0.6913, Validation Loss: 0.7467
# EarlyStopping counter: 3 out of 5
# Epoch [7/25], Loss: 0.6803, Validation Loss: 0.7048
# EarlyStopping counter: 4 out of 5
# Epoch [8/25], Loss: 0.6636, Validation Loss: 0.6855
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 13 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.929134, F1=0.000000, TN=118, FP=0, FN=9, TP=0
# Run 13 completed
# ****************************************************************************************************
#
# Run 14: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6255, Validation Loss: 0.9222
# Validation loss decreased (inf --> 0.922206).  Saving model ...
# Epoch [2/50], Loss: 0.7132, Validation Loss: 0.6882
# Validation loss decreased (0.922206 --> 0.688199).  Saving model ...
# Epoch [3/50], Loss: 0.6860, Validation Loss: 0.5696
# Validation loss decreased (0.688199 --> 0.569551).  Saving model ...
# Epoch [4/50], Loss: 0.6726, Validation Loss: 0.6637
# EarlyStopping counter: 1 out of 5
# Epoch [5/50], Loss: 0.7254, Validation Loss: 0.6773
# EarlyStopping counter: 2 out of 5
# Epoch [6/50], Loss: 0.6913, Validation Loss: 0.7467
# EarlyStopping counter: 3 out of 5
# Epoch [7/50], Loss: 0.6803, Validation Loss: 0.7048
# EarlyStopping counter: 4 out of 5
# Epoch [8/50], Loss: 0.6636, Validation Loss: 0.6855
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 14 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.929134, F1=0.000000, TN=118, FP=0, FN=9, TP=0
# Run 14 completed
# ****************************************************************************************************
#
# Run 15: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6277, Validation Loss: 0.5960
# Validation loss decreased (inf --> 0.595954).  Saving model ...
# Epoch [2/25], Loss: 0.7187, Validation Loss: 0.8972
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.6032, Validation Loss: 0.9234
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.6476, Validation Loss: 0.5949
# Validation loss decreased (0.595954 --> 0.594913).  Saving model ...
# Epoch [5/25], Loss: 0.6902, Validation Loss: 0.8279
# EarlyStopping counter: 1 out of 5
# Epoch [6/25], Loss: 0.9363, Validation Loss: 0.8929
# EarlyStopping counter: 2 out of 5
# Epoch [7/25], Loss: 0.5598, Validation Loss: 0.7732
# EarlyStopping counter: 3 out of 5
# Epoch [8/25], Loss: 0.5755, Validation Loss: 0.8420
# EarlyStopping counter: 4 out of 5
# Epoch [9/25], Loss: 0.3566, Validation Loss: 0.7160
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 15 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=25, Precision=0.086207, Recall=0.714286, Accuracy=0.545455, F1=0.153846, TN=61, FP=53, FN=2, TP=5
# Run 15 completed
# ****************************************************************************************************
#
# Run 16: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6277, Validation Loss: 0.5960
# Validation loss decreased (inf --> 0.595954).  Saving model ...
# Epoch [2/50], Loss: 0.7187, Validation Loss: 0.8972
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.6032, Validation Loss: 0.9234
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.6476, Validation Loss: 0.5949
# Validation loss decreased (0.595954 --> 0.594913).  Saving model ...
# Epoch [5/50], Loss: 0.6902, Validation Loss: 0.8279
# EarlyStopping counter: 1 out of 5
# Epoch [6/50], Loss: 0.9363, Validation Loss: 0.8929
# EarlyStopping counter: 2 out of 5
# Epoch [7/50], Loss: 0.5598, Validation Loss: 0.7732
# EarlyStopping counter: 3 out of 5
# Epoch [8/50], Loss: 0.5755, Validation Loss: 0.8420
# EarlyStopping counter: 4 out of 5
# Epoch [9/50], Loss: 0.3566, Validation Loss: 0.7160
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 16 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=50, Precision=0.086207, Recall=0.714286, Accuracy=0.545455, F1=0.153846, TN=61, FP=53, FN=2, TP=5
# Run 16 completed
# ****************************************************************************************************
#
# Run 17: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7413, Validation Loss: 0.7712
# Validation loss decreased (inf --> 0.771156).  Saving model ...
# Epoch [2/25], Loss: 0.7470, Validation Loss: 0.5978
# Validation loss decreased (0.771156 --> 0.597772).  Saving model ...
# Epoch [3/25], Loss: 0.6617, Validation Loss: 0.6932
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.6052, Validation Loss: 0.7427
# EarlyStopping counter: 2 out of 5
# Epoch [5/25], Loss: 0.6408, Validation Loss: 0.6053
# EarlyStopping counter: 3 out of 5
# Epoch [6/25], Loss: 0.6001, Validation Loss: 0.8045
# EarlyStopping counter: 4 out of 5
# Epoch [7/25], Loss: 0.6158, Validation Loss: 0.6898
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 17 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.880342, F1=0.000000, TN=103, FP=8, FN=6, TP=0
# Run 17 completed
# ****************************************************************************************************
#
# Run 18: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7413, Validation Loss: 0.7712
# Validation loss decreased (inf --> 0.771156).  Saving model ...
# Epoch [2/50], Loss: 0.7470, Validation Loss: 0.5978
# Validation loss decreased (0.771156 --> 0.597772).  Saving model ...
# Epoch [3/50], Loss: 0.6617, Validation Loss: 0.6932
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.6052, Validation Loss: 0.7427
# EarlyStopping counter: 2 out of 5
# Epoch [5/50], Loss: 0.6408, Validation Loss: 0.6053
# EarlyStopping counter: 3 out of 5
# Epoch [6/50], Loss: 0.6001, Validation Loss: 0.8045
# EarlyStopping counter: 4 out of 5
# Epoch [7/50], Loss: 0.6158, Validation Loss: 0.6898
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 18 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.880342, F1=0.000000, TN=103, FP=8, FN=6, TP=0
# Run 18 completed
# ****************************************************************************************************
#
# Run 19: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7217, Validation Loss: 0.7190
# Validation loss decreased (inf --> 0.719048).  Saving model ...
# Epoch [2/25], Loss: 0.7043, Validation Loss: 0.6550
# Validation loss decreased (0.719048 --> 0.654968).  Saving model ...
# Epoch [3/25], Loss: 0.7189, Validation Loss: 0.5544
# Validation loss decreased (0.654968 --> 0.554376).  Saving model ...
# Epoch [4/25], Loss: 0.6790, Validation Loss: 0.4546
# Validation loss decreased (0.554376 --> 0.454558).  Saving model ...
# Epoch [5/25], Loss: 0.6597, Validation Loss: 0.8267
# EarlyStopping counter: 1 out of 5
# Epoch [6/25], Loss: 0.6424, Validation Loss: 0.7310
# EarlyStopping counter: 2 out of 5
# Epoch [7/25], Loss: 0.7066, Validation Loss: 0.6669
# EarlyStopping counter: 3 out of 5
# Epoch [8/25], Loss: 0.6611, Validation Loss: 0.7107
# EarlyStopping counter: 4 out of 5
# Epoch [9/25], Loss: 0.6417, Validation Loss: 0.6888
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 19 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.928571, F1=0.000000, TN=104, FP=0, FN=8, TP=0
# Run 19 completed
# ****************************************************************************************************
#
# Run 20: max_events=20, input_length=20, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7217, Validation Loss: 0.7190
# Validation loss decreased (inf --> 0.719048).  Saving model ...
# Epoch [2/50], Loss: 0.7043, Validation Loss: 0.6550
# Validation loss decreased (0.719048 --> 0.654968).  Saving model ...
# Epoch [3/50], Loss: 0.7189, Validation Loss: 0.5544
# Validation loss decreased (0.654968 --> 0.554376).  Saving model ...
# Epoch [4/50], Loss: 0.6790, Validation Loss: 0.4546
# Validation loss decreased (0.554376 --> 0.454558).  Saving model ...
# Epoch [5/50], Loss: 0.6597, Validation Loss: 0.8267
# EarlyStopping counter: 1 out of 5
# Epoch [6/50], Loss: 0.6424, Validation Loss: 0.7310
# EarlyStopping counter: 2 out of 5
# Epoch [7/50], Loss: 0.7066, Validation Loss: 0.6669
# EarlyStopping counter: 3 out of 5
# Epoch [8/50], Loss: 0.6611, Validation Loss: 0.7107
# EarlyStopping counter: 4 out of 5
# Epoch [9/50], Loss: 0.6417, Validation Loss: 0.6888
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 20 Results: Max Events=20, Input Length=20, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.928571, F1=0.000000, TN=104, FP=0, FN=8, TP=0
# Run 20 completed
# ****************************************************************************************************
#
# Run 21: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6595, Validation Loss: 0.5019
# Validation loss decreased (inf --> 0.501885).  Saving model ...
# Epoch [2/25], Loss: 0.7161, Validation Loss: 0.6602
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.6846, Validation Loss: 0.5954
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.7748, Validation Loss: 0.9447
# EarlyStopping counter: 3 out of 5
# Epoch [5/25], Loss: 0.6308, Validation Loss: 0.6363
# EarlyStopping counter: 4 out of 5
# Epoch [6/25], Loss: 0.6845, Validation Loss: 0.6642
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 21 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.901099, F1=0.000000, TN=82, FP=0, FN=9, TP=0
# Run 21 completed
# ****************************************************************************************************
#
# Run 22: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6595, Validation Loss: 0.5019
# Validation loss decreased (inf --> 0.501885).  Saving model ...
# Epoch [2/50], Loss: 0.7161, Validation Loss: 0.6602
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.6846, Validation Loss: 0.5954
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.7748, Validation Loss: 0.9447
# EarlyStopping counter: 3 out of 5
# Epoch [5/50], Loss: 0.6308, Validation Loss: 0.6363
# EarlyStopping counter: 4 out of 5
# Epoch [6/50], Loss: 0.6845, Validation Loss: 0.6642
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 22 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.901099, F1=0.000000, TN=82, FP=0, FN=9, TP=0
# Run 22 completed
# ****************************************************************************************************
#
# Run 23: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6825, Validation Loss: 0.6138
# Validation loss decreased (inf --> 0.613794).  Saving model ...
# Epoch [2/25], Loss: 0.7396, Validation Loss: 0.8096
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.6770, Validation Loss: 0.5929
# Validation loss decreased (0.613794 --> 0.592859).  Saving model ...
# Epoch [4/25], Loss: 0.6862, Validation Loss: 0.5303
# Validation loss decreased (0.592859 --> 0.530314).  Saving model ...
# Epoch [5/25], Loss: 0.6702, Validation Loss: 0.7133
# EarlyStopping counter: 1 out of 5
# Epoch [6/25], Loss: 0.6609, Validation Loss: 0.7060
# EarlyStopping counter: 2 out of 5
# Epoch [7/25], Loss: 0.5872, Validation Loss: 0.5463
# EarlyStopping counter: 3 out of 5
# Epoch [8/25], Loss: 0.6478, Validation Loss: 0.7005
# EarlyStopping counter: 4 out of 5
# Epoch [9/25], Loss: 0.6457, Validation Loss: 0.6255
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 23 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.954545, F1=0.000000, TN=84, FP=0, FN=4, TP=0
# Run 23 completed
# ****************************************************************************************************
#
# Run 24: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6825, Validation Loss: 0.6138
# Validation loss decreased (inf --> 0.613794).  Saving model ...
# Epoch [2/50], Loss: 0.7396, Validation Loss: 0.8096
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.6770, Validation Loss: 0.5929
# Validation loss decreased (0.613794 --> 0.592859).  Saving model ...
# Epoch [4/50], Loss: 0.6862, Validation Loss: 0.5303
# Validation loss decreased (0.592859 --> 0.530314).  Saving model ...
# Epoch [5/50], Loss: 0.6702, Validation Loss: 0.7133
# EarlyStopping counter: 1 out of 5
# Epoch [6/50], Loss: 0.6609, Validation Loss: 0.7060
# EarlyStopping counter: 2 out of 5
# Epoch [7/50], Loss: 0.5872, Validation Loss: 0.5463
# EarlyStopping counter: 3 out of 5
# Epoch [8/50], Loss: 0.6478, Validation Loss: 0.7005
# EarlyStopping counter: 4 out of 5
# Epoch [9/50], Loss: 0.6457, Validation Loss: 0.6255
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 24 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.954545, F1=0.000000, TN=84, FP=0, FN=4, TP=0
# Run 24 completed
# ****************************************************************************************************
#
# Run 25: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6068, Validation Loss: 0.5256
# Validation loss decreased (inf --> 0.525563).  Saving model ...
# Epoch [2/25], Loss: 0.6054, Validation Loss: 0.7153
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.6187, Validation Loss: 0.5747
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.6416, Validation Loss: 0.5069
# Validation loss decreased (0.525563 --> 0.506937).  Saving model ...
# Epoch [5/25], Loss: 0.5176, Validation Loss: 0.7338
# EarlyStopping counter: 1 out of 5
# Epoch [6/25], Loss: 0.7339, Validation Loss: 0.6868
# EarlyStopping counter: 2 out of 5
# Epoch [7/25], Loss: 0.5192, Validation Loss: 0.5897
# EarlyStopping counter: 3 out of 5
# Epoch [8/25], Loss: 0.4382, Validation Loss: 0.6282
# EarlyStopping counter: 4 out of 5
# Epoch [9/25], Loss: 0.5000, Validation Loss: 0.6995
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 25 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=25, Precision=0.166667, Recall=0.666667, Accuracy=0.744186, F1=0.266667, TN=60, FP=20, FN=2, TP=4
# Run 25 completed
# ****************************************************************************************************
#
# Run 26: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6068, Validation Loss: 0.5256
# Validation loss decreased (inf --> 0.525563).  Saving model ...
# Epoch [2/50], Loss: 0.6054, Validation Loss: 0.7153
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.6187, Validation Loss: 0.5747
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.6416, Validation Loss: 0.5069
# Validation loss decreased (0.525563 --> 0.506937).  Saving model ...
# Epoch [5/50], Loss: 0.5176, Validation Loss: 0.7338
# EarlyStopping counter: 1 out of 5
# Epoch [6/50], Loss: 0.7339, Validation Loss: 0.6868
# EarlyStopping counter: 2 out of 5
# Epoch [7/50], Loss: 0.5192, Validation Loss: 0.5897
# EarlyStopping counter: 3 out of 5
# Epoch [8/50], Loss: 0.4382, Validation Loss: 0.6282
# EarlyStopping counter: 4 out of 5
# Epoch [9/50], Loss: 0.5000, Validation Loss: 0.6995
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 26 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=50, Precision=0.166667, Recall=0.666667, Accuracy=0.744186, F1=0.266667, TN=60, FP=20, FN=2, TP=4
# Run 26 completed
# ****************************************************************************************************
#
# Run 27: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6211, Validation Loss: 0.8060
# Validation loss decreased (inf --> 0.806032).  Saving model ...
# Epoch [2/25], Loss: 0.7240, Validation Loss: 0.5706
# Validation loss decreased (0.806032 --> 0.570595).  Saving model ...
# Epoch [3/25], Loss: 0.7495, Validation Loss: 0.8059
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.6693, Validation Loss: 0.7958
# EarlyStopping counter: 2 out of 5
# Epoch [5/25], Loss: 0.6458, Validation Loss: 0.6598
# EarlyStopping counter: 3 out of 5
# Epoch [6/25], Loss: 0.6054, Validation Loss: 0.8360
# EarlyStopping counter: 4 out of 5
# Epoch [7/25], Loss: 0.6933, Validation Loss: 0.6977
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 27 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.819277, F1=0.000000, TN=68, FP=6, FN=9, TP=0
# Run 27 completed
# ****************************************************************************************************
#
# Run 28: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6211, Validation Loss: 0.8060
# Validation loss decreased (inf --> 0.806032).  Saving model ...
# Epoch [2/50], Loss: 0.7240, Validation Loss: 0.5706
# Validation loss decreased (0.806032 --> 0.570595).  Saving model ...
# Epoch [3/50], Loss: 0.7495, Validation Loss: 0.8059
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.6693, Validation Loss: 0.7958
# EarlyStopping counter: 2 out of 5
# Epoch [5/50], Loss: 0.6458, Validation Loss: 0.6598
# EarlyStopping counter: 3 out of 5
# Epoch [6/50], Loss: 0.6054, Validation Loss: 0.8360
# EarlyStopping counter: 4 out of 5
# Epoch [7/50], Loss: 0.6933, Validation Loss: 0.6977
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 28 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.819277, F1=0.000000, TN=68, FP=6, FN=9, TP=0
# Run 28 completed
# ****************************************************************************************************
#
# Run 29: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7276, Validation Loss: 0.9255
# Validation loss decreased (inf --> 0.925528).  Saving model ...
# Epoch [2/25], Loss: 0.7911, Validation Loss: 0.5948
# Validation loss decreased (0.925528 --> 0.594850).  Saving model ...
# Epoch [3/25], Loss: 0.7560, Validation Loss: 0.5874
# Validation loss decreased (0.594850 --> 0.587388).  Saving model ...
# Epoch [4/25], Loss: 0.6927, Validation Loss: 0.6257
# EarlyStopping counter: 1 out of 5
# Epoch [5/25], Loss: 0.6704, Validation Loss: 0.8358
# EarlyStopping counter: 2 out of 5
# Epoch [6/25], Loss: 0.6910, Validation Loss: 0.7360
# EarlyStopping counter: 3 out of 5
# Epoch [7/25], Loss: 0.8096, Validation Loss: 0.9608
# EarlyStopping counter: 4 out of 5
# Epoch [8/25], Loss: 0.7196, Validation Loss: 0.7044
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 29 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.925926, F1=0.000000, TN=75, FP=0, FN=6, TP=0
# Run 29 completed
# ****************************************************************************************************
#
# Run 30: max_events=20, input_length=30, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7276, Validation Loss: 0.9255
# Validation loss decreased (inf --> 0.925528).  Saving model ...
# Epoch [2/50], Loss: 0.7911, Validation Loss: 0.5948
# Validation loss decreased (0.925528 --> 0.594850).  Saving model ...
# Epoch [3/50], Loss: 0.7560, Validation Loss: 0.5874
# Validation loss decreased (0.594850 --> 0.587388).  Saving model ...
# Epoch [4/50], Loss: 0.6927, Validation Loss: 0.6257
# EarlyStopping counter: 1 out of 5
# Epoch [5/50], Loss: 0.6704, Validation Loss: 0.8358
# EarlyStopping counter: 2 out of 5
# Epoch [6/50], Loss: 0.6910, Validation Loss: 0.7360
# EarlyStopping counter: 3 out of 5
# Epoch [7/50], Loss: 0.8096, Validation Loss: 0.9608
# EarlyStopping counter: 4 out of 5
# Epoch [8/50], Loss: 0.7196, Validation Loss: 0.7044
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 30 Results: Max Events=20, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.925926, F1=0.000000, TN=75, FP=0, FN=6, TP=0
# Run 30 completed
# ****************************************************************************************************
#
# Run 31: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6931, Validation Loss: 0.8043
# Validation loss decreased (inf --> 0.804332).  Saving model ...
# Epoch [2/25], Loss: 0.7014, Validation Loss: 0.5763
# Validation loss decreased (0.804332 --> 0.576349).  Saving model ...
# Epoch [3/25], Loss: 0.5871, Validation Loss: 0.5961
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.6527, Validation Loss: 0.7200
# EarlyStopping counter: 2 out of 5
# Epoch [5/25], Loss: 0.7179, Validation Loss: 0.7976
# EarlyStopping counter: 3 out of 5
# Epoch [6/25], Loss: 0.6701, Validation Loss: 0.6344
# EarlyStopping counter: 4 out of 5
# Epoch [7/25], Loss: 0.6615, Validation Loss: 0.6913
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 31 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=25, Precision=1.000000, Recall=0.052632, Accuracy=0.925926, F1=0.100000, TN=224, FP=0, FN=18, TP=1
# Run 31 completed
# ****************************************************************************************************
#
# Run 32: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6931, Validation Loss: 0.8043
# Validation loss decreased (inf --> 0.804332).  Saving model ...
# Epoch [2/50], Loss: 0.7014, Validation Loss: 0.5763
# Validation loss decreased (0.804332 --> 0.576349).  Saving model ...
# Epoch [3/50], Loss: 0.5871, Validation Loss: 0.5961
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.6527, Validation Loss: 0.7200
# EarlyStopping counter: 2 out of 5
# Epoch [5/50], Loss: 0.7179, Validation Loss: 0.7976
# EarlyStopping counter: 3 out of 5
# Epoch [6/50], Loss: 0.6701, Validation Loss: 0.6344
# EarlyStopping counter: 4 out of 5
# Epoch [7/50], Loss: 0.6615, Validation Loss: 0.6913
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 32 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=1, Prediction Period=1, Num Epochs=50, Precision=1.000000, Recall=0.052632, Accuracy=0.925926, F1=0.100000, TN=224, FP=0, FN=18, TP=1
# Run 32 completed
# ****************************************************************************************************
#
# Run 33: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6821, Validation Loss: 0.5296
# Validation loss decreased (inf --> 0.529647).  Saving model ...
# Epoch [2/25], Loss: 1.1486, Validation Loss: 0.6400
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.6665, Validation Loss: 0.7638
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.6748, Validation Loss: 0.5870
# EarlyStopping counter: 3 out of 5
# Epoch [5/25], Loss: 0.7020, Validation Loss: 0.6556
# EarlyStopping counter: 4 out of 5
# Epoch [6/25], Loss: 0.6814, Validation Loss: 0.6118
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 33 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=25, Precision=0.153846, Recall=0.142857, Accuracy=0.897321, F1=0.148148, TN=199, FP=11, FN=12, TP=2
# Run 33 completed
# ****************************************************************************************************
#
# Run 34: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=2, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6821, Validation Loss: 0.5296
# Validation loss decreased (inf --> 0.529647).  Saving model ...
# Epoch [2/50], Loss: 1.1486, Validation Loss: 0.6400
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.6665, Validation Loss: 0.7638
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.6748, Validation Loss: 0.5870
# EarlyStopping counter: 3 out of 5
# Epoch [5/50], Loss: 0.7020, Validation Loss: 0.6556
# EarlyStopping counter: 4 out of 5
# Epoch [6/50], Loss: 0.6814, Validation Loss: 0.6118
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 34 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=2, Prediction Period=1, Num Epochs=50, Precision=0.153846, Recall=0.142857, Accuracy=0.897321, F1=0.148148, TN=199, FP=11, FN=12, TP=2
# Run 34 completed
# ****************************************************************************************************
#
# Run 35: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.5003, Validation Loss: 0.4345
# Validation loss decreased (inf --> 0.434458).  Saving model ...
# Epoch [2/25], Loss: 0.7963, Validation Loss: 0.7016
# EarlyStopping counter: 1 out of 5
# Epoch [3/25], Loss: 0.7238, Validation Loss: 0.5044
# EarlyStopping counter: 2 out of 5
# Epoch [4/25], Loss: 0.5387, Validation Loss: 0.5944
# EarlyStopping counter: 3 out of 5
# Epoch [5/25], Loss: 0.6475, Validation Loss: 0.4714
# EarlyStopping counter: 4 out of 5
# Epoch [6/25], Loss: 0.3419, Validation Loss: 0.6208
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 35 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=25, Precision=0.172414, Recall=0.294118, Accuracy=0.826923, F1=0.217391, TN=167, FP=24, FN=12, TP=5
# Run 35 completed
# ****************************************************************************************************
#
# Run 36: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=3, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.5003, Validation Loss: 0.4345
# Validation loss decreased (inf --> 0.434458).  Saving model ...
# Epoch [2/50], Loss: 0.7963, Validation Loss: 0.7016
# EarlyStopping counter: 1 out of 5
# Epoch [3/50], Loss: 0.7238, Validation Loss: 0.5044
# EarlyStopping counter: 2 out of 5
# Epoch [4/50], Loss: 0.5387, Validation Loss: 0.5944
# EarlyStopping counter: 3 out of 5
# Epoch [5/50], Loss: 0.6475, Validation Loss: 0.4714
# EarlyStopping counter: 4 out of 5
# Epoch [6/50], Loss: 0.3419, Validation Loss: 0.6208
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 36 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=3, Prediction Period=1, Num Epochs=50, Precision=0.172414, Recall=0.294118, Accuracy=0.826923, F1=0.217391, TN=167, FP=24, FN=12, TP=5
# Run 36 completed
# ****************************************************************************************************
#
# Run 37: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7029, Validation Loss: 0.6650
# Validation loss decreased (inf --> 0.664986).  Saving model ...
# Epoch [2/25], Loss: 0.6676, Validation Loss: 0.6264
# Validation loss decreased (0.664986 --> 0.626436).  Saving model ...
# Epoch [3/25], Loss: 0.6714, Validation Loss: 0.7515
# EarlyStopping counter: 1 out of 5
# Epoch [4/25], Loss: 0.7451, Validation Loss: 0.7369
# EarlyStopping counter: 2 out of 5
# Epoch [5/25], Loss: 0.7155, Validation Loss: 0.5620
# Validation loss decreased (0.626436 --> 0.562047).  Saving model ...
# Epoch [6/25], Loss: 0.7654, Validation Loss: 0.7928
# EarlyStopping counter: 1 out of 5
# Epoch [7/25], Loss: 0.6379, Validation Loss: 0.7660
# EarlyStopping counter: 2 out of 5
# Epoch [8/25], Loss: 0.6999, Validation Loss: 0.7189
# EarlyStopping counter: 3 out of 5
# Epoch [9/25], Loss: 0.6983, Validation Loss: 0.7029
# EarlyStopping counter: 4 out of 5
# Epoch [10/25], Loss: 0.6517, Validation Loss: 0.6682
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 37 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=25, Precision=0.000000, Recall=0.000000, Accuracy=0.881443, F1=0.000000, TN=171, FP=0, FN=23, TP=0
# Run 37 completed
# ****************************************************************************************************
#
# Run 38: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=4, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7029, Validation Loss: 0.6650
# Validation loss decreased (inf --> 0.664986).  Saving model ...
# Epoch [2/50], Loss: 0.6676, Validation Loss: 0.6264
# Validation loss decreased (0.664986 --> 0.626436).  Saving model ...
# Epoch [3/50], Loss: 0.6714, Validation Loss: 0.7515
# EarlyStopping counter: 1 out of 5
# Epoch [4/50], Loss: 0.7451, Validation Loss: 0.7369
# EarlyStopping counter: 2 out of 5
# Epoch [5/50], Loss: 0.7155, Validation Loss: 0.5620
# Validation loss decreased (0.626436 --> 0.562047).  Saving model ...
# Epoch [6/50], Loss: 0.7654, Validation Loss: 0.7928
# EarlyStopping counter: 1 out of 5
# Epoch [7/50], Loss: 0.6379, Validation Loss: 0.7660
# EarlyStopping counter: 2 out of 5
# Epoch [8/50], Loss: 0.6999, Validation Loss: 0.7189
# EarlyStopping counter: 3 out of 5
# Epoch [9/50], Loss: 0.6983, Validation Loss: 0.7029
# EarlyStopping counter: 4 out of 5
# Epoch [10/50], Loss: 0.6517, Validation Loss: 0.6682
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 38 Results: Max Events=30, Input Length=10, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=4, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.881443, F1=0.000000, TN=171, FP=0, FN=23, TP=0
# Run 38 completed
# ****************************************************************************************************
#
# Run 39: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=5, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.5164, Validation Loss: 0.9007
# Validation loss decreased (inf --> 0.900682).  Saving model ...
# Epoch [2/25], Loss: 0.8232, Validation Loss: 0.6510
# Validation loss decreased (0.900682 --> 0.651046).  Saving model ...
# Epoch [3/25], Loss: 0.7061, Validation Loss: 0.6271
# Validation loss decreased (0.651046 --> 0.627129).  Saving model ...
# ...
# EarlyStopping counter: 1 out of 5
# Epoch [6/50], Loss: 0.7295, Validation Loss: 0.6975
# EarlyStopping counter: 2 out of 5
# Epoch [7/50], Loss: 0.6659, Validation Loss: 0.7185
# EarlyStopping counter: 3 out of 5
# Epoch [8/50], Loss: 0.6678, Validation Loss: 0.5983
# EarlyStopping counter: 4 out of 5
# Epoch [9/50], Loss: 0.6739, Validation Loss: 0.6543
# EarlyStopping counter: 5 out of 5
# Early stopping
# Run 90 Results: Max Events=40, Input Length=30, Hidden Size=64, Dropout=0.3, Num Layers=2, Gap=5, Prediction Period=1, Num Epochs=50, Precision=0.000000, Recall=0.000000, Accuracy=0.925926, F1=0.000000, TN=75, FP=0, FN=6, TP=0
# Run 90 completed
# ****************************************************************************************************
#    Run Max Events Input Length Hidden Size  Dropout Num Layers Gap  \
# 0    1         20           10          64 0.300000          2   1
# 1    2         20           10          64 0.300000          2   1
# 2    3         20           10          64 0.300000          2   2
# 3    4         20           10          64 0.300000          2   2
# 4    5         20           10          64 0.300000          2   3
# 5    6         20           10          64 0.300000          2   3
# 6    7         20           10          64 0.300000          2   4
# 7    8         20           10          64 0.300000          2   4
# 8    9         20           10          64 0.300000          2   5
# 9   10         20           10          64 0.300000          2   5
# 10  11         20           20          64 0.300000          2   1
# 11  12         20           20          64 0.300000          2   1
# 12  13         20           20          64 0.300000          2   2
# 13  14         20           20          64 0.300000          2   2
# 14  15         20           20          64 0.300000          2   3
# 15  16         20           20          64 0.300000          2   3
# 16  17         20           20          64 0.300000          2   4
# 17  18         20           20          64 0.300000          2   4
# 18  19         20           20          64 0.300000          2   5
# 19  20         20           20          64 0.300000          2   5
# 20  21         20           30          64 0.300000          2   1
# 21  22         20           30          64 0.300000          2   1
# 22  23         20           30          64 0.300000          2   2
# 23  24         20           30          64 0.300000          2   2
# 24  25         20           30          64 0.300000          2   3
# 25  26         20           30          64 0.300000          2   3
# 26  27         20           30          64 0.300000          2   4
# 27  28         20           30          64 0.300000          2   4
# 28  29         20           30          64 0.300000          2   5
# 29  30         20           30          64 0.300000          2   5
# 30  31         30           10          64 0.300000          2   1
# 31  32         30           10          64 0.300000          2   1
# 32  33         30           10          64 0.300000          2   2
# 33  34         30           10          64 0.300000          2   2
# 34  35         30           10          64 0.300000          2   3
# 35  36         30           10          64 0.300000          2   3
# 36  37         30           10          64 0.300000          2   4
# 37  38         30           10          64 0.300000          2   4
# 38  39         30           10          64 0.300000          2   5
# 39  40         30           10          64 0.300000          2   5
# 40  41         30           20          64 0.300000          2   1
# 41  42         30           20          64 0.300000          2   1
# 42  43         30           20          64 0.300000          2   2
# 43  44         30           20          64 0.300000          2   2
# 44  45         30           20          64 0.300000          2   3
# 45  46         30           20          64 0.300000          2   3
# 46  47         30           20          64 0.300000          2   4
# 47  48         30           20          64 0.300000          2   4
# 48  49         30           20          64 0.300000          2   5
# 49  50         30           20          64 0.300000          2   5
# 50  51         30           30          64 0.300000          2   1
# 51  52         30           30          64 0.300000          2   1
# 52  53         30           30          64 0.300000          2   2
# 53  54         30           30          64 0.300000          2   2
# 54  55         30           30          64 0.300000          2   3
# 55  56         30           30          64 0.300000          2   3
# 56  57         30           30          64 0.300000          2   4
# 57  58         30           30          64 0.300000          2   4
# 58  59         30           30          64 0.300000          2   5
# 59  60         30           30          64 0.300000          2   5
# 60  61         40           10          64 0.300000          2   1
# 61  62         40           10          64 0.300000          2   1
# 62  63         40           10          64 0.300000          2   2
# 63  64         40           10          64 0.300000          2   2
# 64  65         40           10          64 0.300000          2   3
# 65  66         40           10          64 0.300000          2   3
# 66  67         40           10          64 0.300000          2   4
# 67  68         40           10          64 0.300000          2   4
# 68  69         40           10          64 0.300000          2   5
# 69  70         40           10          64 0.300000          2   5
# 70  71         40           20          64 0.300000          2   1
# 71  72         40           20          64 0.300000          2   1
# 72  73         40           20          64 0.300000          2   2
# 73  74         40           20          64 0.300000          2   2
# 74  75         40           20          64 0.300000          2   3
# 75  76         40           20          64 0.300000          2   3
# 76  77         40           20          64 0.300000          2   4
# 77  78         40           20          64 0.300000          2   4
# 78  79         40           20          64 0.300000          2   5
# 79  80         40           20          64 0.300000          2   5
# 80  81         40           30          64 0.300000          2   1
# 81  82         40           30          64 0.300000          2   1
# 82  83         40           30          64 0.300000          2   2
# 83  84         40           30          64 0.300000          2   2
# 84  85         40           30          64 0.300000          2   3
# 85  86         40           30          64 0.300000          2   3
# 86  87         40           30          64 0.300000          2   4
# 87  88         40           30          64 0.300000          2   4
# 88  89         40           30          64 0.300000          2   5
# 89  90         40           30          64 0.300000          2   5
#
#    Prediction Period Num Epochs  Precision   Recall  Accuracy       F1   TN  \
# 0                  1         25   0.000000 0.000000  0.921811 0.000000  224
# 1                  1         50   0.000000 0.000000  0.921811 0.000000  224
# 2                  1         25   0.500000 0.071429  0.937500 0.125000  209
# 3                  1         50   0.500000 0.071429  0.937500 0.125000  209
# 4                  1         25   0.162162 0.352941  0.798077 0.222222  160
# 5                  1         50   0.162162 0.352941  0.798077 0.222222  160
# 6                  1         25   0.272727 0.130435  0.855670 0.176471  163
# 7                  1         50   0.272727 0.130435  0.855670 0.176471  163
# 8                  1         25   0.000000 0.000000  0.917582 0.000000  167
# 9                  1         50   0.000000 0.000000  0.917582 0.000000  167
# 10                 1         25   0.000000 0.000000  0.924242 0.000000  122
# 11                 1         50   0.000000 0.000000  0.924242 0.000000  122
# 12                 1         25   0.000000 0.000000  0.929134 0.000000  118
# 13                 1         50   0.000000 0.000000  0.929134 0.000000  118
# 14                 1         25   0.086207 0.714286  0.545455 0.153846   61
# 15                 1         50   0.086207 0.714286  0.545455 0.153846   61
# 16                 1         25   0.000000 0.000000  0.880342 0.000000  103
# 17                 1         50   0.000000 0.000000  0.880342 0.000000  103
# 18                 1         25   0.000000 0.000000  0.928571 0.000000  104
# 19                 1         50   0.000000 0.000000  0.928571 0.000000  104
# 20                 1         25   0.000000 0.000000  0.901099 0.000000   82
# 21                 1         50   0.000000 0.000000  0.901099 0.000000   82
# 22                 1         25   0.000000 0.000000  0.954545 0.000000   84
# 23                 1         50   0.000000 0.000000  0.954545 0.000000   84
# 24                 1         25   0.166667 0.666667  0.744186 0.266667   60
# 25                 1         50   0.166667 0.666667  0.744186 0.266667   60
# 26                 1         25   0.000000 0.000000  0.819277 0.000000   68
# 27                 1         50   0.000000 0.000000  0.819277 0.000000   68
# 28                 1         25   0.000000 0.000000  0.925926 0.000000   75
# 29                 1         50   0.000000 0.000000  0.925926 0.000000   75
# 30                 1         25   1.000000 0.052632  0.925926 0.100000  224
# 31                 1         50   1.000000 0.052632  0.925926 0.100000  224
# 32                 1         25   0.153846 0.142857  0.897321 0.148148  199
# 33                 1         50   0.153846 0.142857  0.897321 0.148148  199
# 34                 1         25   0.172414 0.294118  0.826923 0.217391  167
# 35                 1         50   0.172414 0.294118  0.826923 0.217391  167
# 36                 1         25   0.000000 0.000000  0.881443 0.000000  171
# 37                 1         50   0.000000 0.000000  0.881443 0.000000  171
# 38                 1         25   0.333333 0.066667  0.912088 0.111111  165
# 39                 1         50   0.333333 0.066667  0.912088 0.111111  165
# 40                 1         25   0.000000 0.000000  0.931818 0.000000  123
# 41                 1         50   0.000000 0.000000  0.931818 0.000000  123
# 42                 1         25   0.300000 0.333333  0.897638 0.315789  111
# 43                 1         50   0.300000 0.333333  0.897638 0.315789  111
# 44                 1         25   0.050000 0.142857  0.793388 0.074074   95
# 45                 1         50   0.050000 0.142857  0.793388 0.074074   95
# 46                 1         25   0.000000 0.000000  0.846154 0.000000   99
# 47                 1         50   0.000000 0.000000  0.846154 0.000000   99
# 48                 1         25   0.083333 0.125000  0.839286 0.100000   93
# 49                 1         50   0.083333 0.125000  0.839286 0.100000   93
# 50                 1         25   0.000000 0.000000  0.901099 0.000000   82
# 51                 1         50   0.000000 0.000000  0.901099 0.000000   82
# 52                 1         25   0.000000 0.000000  0.954545 0.000000   84
# 53                 1         50   0.000000 0.000000  0.954545 0.000000   84
# 54                 1         25   0.200000 0.166667  0.895349 0.181818   76
# 55                 1         50   0.200000 0.166667  0.895349 0.181818   76
# 56                 1         25   0.000000 0.000000  0.891566 0.000000   74
# 57                 1         50   0.000000 0.000000  0.891566 0.000000   74
# 58                 1         25   0.000000 0.000000  0.925926 0.000000   75
# 59                 1         50   0.000000 0.000000  0.925926 0.000000   75
# 60                 1         25   0.500000 0.052632  0.921811 0.095238  223
# 61                 1         50   0.500000 0.052632  0.921811 0.095238  223
# 62                 1         25   0.000000 0.000000  0.937500 0.000000  210
# 63                 1         50   0.000000 0.000000  0.937500 0.000000  210
# 64                 1         25   0.208333 0.294118  0.850962 0.243902  172
# 65                 1         50   0.208333 0.294118  0.850962 0.243902  172
# 66                 1         25   1.000000 0.043478  0.886598 0.083333  171
# 67                 1         50   1.000000 0.043478  0.886598 0.083333  171
# 68                 1         25   0.333333 0.066667  0.912088 0.111111  165
# 69                 1         50   0.333333 0.066667  0.912088 0.111111  165
# 70                 1         25   0.000000 0.000000  0.924242 0.000000  122
# 71                 1         50   0.000000 0.000000  0.924242 0.000000  122
# 72                 1         25   0.085106 0.888889  0.314961 0.155340   32
# 73                 1         50   0.085106 0.888889  0.314961 0.155340   32
# 74                 1         25   0.100000 0.714286  0.611570 0.175439   69
# 75                 1         50   0.100000 0.714286  0.611570 0.175439   69
# 76                 1         25   0.000000 0.000000  0.846154 0.000000   99
# 77                 1         50   0.000000 0.000000  0.846154 0.000000   99
# 78                 1         25   0.000000 0.000000  0.928571 0.000000  104
# 79                 1         50   0.000000 0.000000  0.928571 0.000000  104
# 80                 1         25   0.333333 0.111111  0.890110 0.166667   80
# 81                 1         50   0.333333 0.111111  0.890110 0.166667   80
# 82                 1         25   1.000000 0.250000  0.965909 0.400000   84
# 83                 1         50   1.000000 0.250000  0.965909 0.400000   84
# 84                 1         25   0.181818 0.333333  0.848837 0.235294   71
# 85                 1         50   0.181818 0.333333  0.848837 0.235294   71
# 86                 1         25   0.000000 0.000000  0.891566 0.000000   74
# 87                 1         50   0.000000 0.000000  0.891566 0.000000   74
# 88                 1         25   0.000000 0.000000  0.925926 0.000000   75
# 89                 1         50   0.000000 0.000000  0.925926 0.000000   75
#
#     FP  FN TP
# 0    0  19  0
# 1    0  19  0
# 2    1  13  1
# 3    1  13  1
# 4   31  11  6
# 5   31  11  6
# 6    8  20  3
# 7    8  20  3
# 8    0  15  0
# 9    0  15  0
# 10   1   9  0
# 11   1   9  0
# 12   0   9  0
# 13   0   9  0
# 14  53   2  5
# 15  53   2  5
# 16   8   6  0
# 17   8   6  0
# 18   0   8  0
# 19   0   8  0
# 20   0   9  0
# 21   0   9  0
# 22   0   4  0
# 23   0   4  0
# 24  20   2  4
# 25  20   2  4
# 26   6   9  0
# 27   6   9  0
# 28   0   6  0
# 29   0   6  0
# 30   0  18  1
# 31   0  18  1
# 32  11  12  2
# 33  11  12  2
# 34  24  12  5
# 35  24  12  5
# 36   0  23  0
# 37   0  23  0
# 38   2  14  1
# 39   2  14  1
# 40   0   9  0
# 41   0   9  0
# 42   7   6  3
# 43   7   6  3
# 44  19   6  1
# 45  19   6  1
# 46  12   6  0
# 47  12   6  0
# 48  11   7  1
# 49  11   7  1
# 50   0   9  0
# 51   0   9  0
# 52   0   4  0
# 53   0   4  0
# 54   4   5  1
# 55   4   5  1
# 56   0   9  0
# 57   0   9  0
# 58   0   6  0
# 59   0   6  0
# 60   1  18  1
# 61   1  18  1
# 62   0  14  0
# 63   0  14  0
# 64  19  12  5
# 65  19  12  5
# 66   0  22  1
# 67   0  22  1
# 68   2  14  1
# 69   2  14  1
# 70   1   9  0
# 71   1   9  0
# 72  86   1  8
# 73  86   1  8
# 74  45   2  5
# 75  45   2  5
# 76  12   6  0
# 77  12   6  0
# 78   0   8  0
# 79   0   8  0
# 80   2   8  1
# 81   2   8  1
# 82   0   3  1
# 83   0   3  1
# 84   9   4  2
# 85   9   4  2
# 86   0   9  0
# 87   0   9  0
# 88   0   6  0
# 89   0   6  0
# ____________________________________________________________________________________________________
#
# Time taken for main loop: 4238.00 seconds
#
# ____________________________________________________________________________________________________

# %% [markdown]
# ---

# %% [markdown]
# ### <font color = teal> Display Results (as kernel crashed earlier)

# %%
# import pandas as pd

# # Set display options to show all columns
# pd.set_option('display.max_columns', None)

# # Set display options to show all rows
# pd.set_option('display.max_rows', None)

# # Optionally, you can also set the width of the display
# pd.set_option('display.width', None)

# # If you want to display all the content of each cell (no truncation)
# pd.set_option('display.max_colwidth', None)

# import pandas as pd

# output_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/12.20240709_More_New_Features/02.Full_Train_Test'
# input_file = f"{output_dir}/20240710_182249_results_df.csv"

# results_df = pd.read_csv(input_file)

# # Display the results DataFrame
# display(results_df)

# ################################### Plot Results ################################


# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np

# # Set a pastel color palette with different colors for each plot
# colors = sns.color_palette("pastel", 8)

# # Plot the results
# fig, axes = plt.subplots(2, 4, figsize=(20, 10))

# metrics = ['Precision', 'Recall', 'Accuracy', 'F1', 'TN', 'FP', 'FN', 'TP']
# for i, metric in enumerate(metrics):
#     ax = axes[i//4, i%4]
    
#     # Plot the metric with thicker lines and different colors
#     ax.plot(results_df['Run'], results_df[metric], color=colors[i], linewidth=2.5)
    
#     # Annotate the points
#     for j, txt in enumerate(results_df[metric]):
#         if not np.isnan(txt):  # Only label non-NaN points
#             ax.annotate(f'{txt:.2f}', (results_df['Run'][j], results_df[metric][j]), fontsize=8)
    
#     ax.set_title(metric)
#     ax.set_xlabel('Run')
#     ax.set_ylabel(metric)

# plt.tight_layout()
# plt.show()
