# %% [markdown]
# # <font color = lightcoral>Setting Random Seed
# >
# ### <font color = red> Non-Overlapping Windows
#
# > Running 4 Models for Comparison

# %% [markdown]
# ## <font color = grey> Admin

# %%
import pandas as pd
import os
import gzip
import time
import warnings
import os
import shutil
from datetime import datetime
# Set display option to show the full length of the column
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore")

# Determine the base directory based on the effective user ID
if os.geteuid() == 0:  # root user
    base_dir = '/root'
else:
    base_dir = '/home/sagemaker-user'

# Set the environment variable
os.environ['BASE_DIR'] = base_dir

# Verify the base directory
print(f"Base directory set to: {base_dir}")

import warnings
warnings.simplefilter("ignore")
# Out:
# Base directory set to: /home/sagemaker-user

# %% [markdown]
# # <font color = tomato> Loop

# %%
################################### Parameters and Hyperparameters ################################

# Parameters and Hyperparameters
data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/01.Full_Base/'
input_file = f"{data_dir}/20240704__full__new_features_v1.10.parquet"
output_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/02.Full_Train_Test'

# Hyperparameter variations to test
max_events_list = [5, 10, 20, 30, 40, 50, 100]  # Different values to test
input_length_list = [10, 20, 30]  # Different values to test
hidden_size_list = [64]  # Different values to test
dropout_list = [0.3]  # Different values to test
num_layers_list = [2, 4]  # Different values to test
gap_list = [5]  # Different values to test
prediction_period_list = [1]  # Different values to test
num_epochs_list = [25, 50]  # Different values to test

test_size = 0.2
shuffle = False

output_size = 1
batch_size = 16
learning_rate = 0.001

import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# DataFrame to track results
results_df = pd.DataFrame(columns=['Run', 'Max Events', 'Input Length', 'Hidden Size', 'Dropout', 'Num Layers', 'Gap', 'Prediction Period', 'Num Epochs', 'Precision', 'Recall', 'Accuracy', 'F1', 'TN', 'FP', 'FN', 'TP'])

run_id = 0

for max_events in max_events_list:
    for input_length in input_length_list:
        for hidden_size in hidden_size_list:
            for dropout in dropout_list:
                for num_layers in num_layers_list:
                    for gap in gap_list:
                        for prediction_period in prediction_period_list:
                            for num_epochs in num_epochs_list:
                                run_id += 1
                                print(f"Run {run_id}: max_events={max_events}, input_length={input_length}, hidden_size={hidden_size}, dropout={dropout}, num_layers={num_layers}, gap={gap}, prediction_period={prediction_period}, num_epochs={num_epochs}")

                                # Set random seed for reproducibility
                                random_seed = 42
                                np.random.seed(random_seed)
                                random.seed(random_seed)
                                torch.manual_seed(random_seed)
                                torch.cuda.manual_seed(random_seed)

                                ################################### Data Preprocessing ################################

                                # Load the data
                                df = pd.read_parquet(input_file)

                                # Select derived features and a subset of EventID columns
                                selected_columns = ['time_start_int', 'Class', 'unique_events', 'most_frequent_event', 'transitions', 'entropy']
                                event_id_columns = [col for col in df.columns if col.startswith('EventId_')]

                                # Replace -1 values with 0
                                df[event_id_columns].replace(-1, 0, inplace=True)

                                # Scale numerical features
                                scaler = StandardScaler()
                                numerical_features = ['unique_events', 'transitions', 'entropy']
                                df[selected_columns[2:]] = scaler.fit_transform(df[selected_columns[2:]])

                                # Encode categorical features
                                label_encoder = LabelEncoder()
                                df['most_frequent_event'] = label_encoder.fit_transform(df['most_frequent_event'])

                                # Apply PCA to EventID columns to reduce them to the number of features specified by max_events
                                pca = PCA(n_components=max_events)
                                event_id_pca = pca.fit_transform(df[event_id_columns])

                                # Create a new DataFrame with the reduced EventID features
                                event_id_pca_df = pd.DataFrame(event_id_pca, columns=[f'EventId_PCA_{i+1}' for i in range(max_events)])

                                # Combine the reduced EventID features with the selected columns
                                df_reduced = pd.concat([df[selected_columns], event_id_pca_df], axis=1)

                                ################################### Create Sequences ################################

                                # Function to create non-overlapping sequences
                                def create_sequences(data, time_index_col, feature_cols, target_col, input_length, gap=1, prediction_period=1):
                                    sequences = []
                                    targets = []
                                    
                                    start_idx = 0
                                    while start_idx + input_length + gap + prediction_period <= len(data):
                                        end_idx = start_idx + input_length
                                        sequence = data[feature_cols].iloc[start_idx:end_idx].values
                                        target = data[target_col].iloc[end_idx + gap:end_idx + gap + prediction_period].values[0]
                                        sequences.append(sequence)
                                        targets.append(target)
                                        start_idx = end_idx + gap + prediction_period  # Move to the next non-overlapping sequence
                                        # start_idx += 1  # Move to the next row to create overlapping sequences
                                    
                                    return np.array(sequences), np.array(targets)

                                # feature_cols = selected_columns + selected_event_ids
                                feature_cols = [col for col in df_reduced.columns if col != 'Class']
                                target_col = 'Class'

                                X, y = create_sequences(df_reduced, 'time_start_int', feature_cols, target_col, input_length=input_length, gap=gap, prediction_period=prediction_period)

                                ################################### Split & SMOTE ################################

                                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, shuffle=shuffle, random_state=random_seed)

                                # Flatten X_train to 2D array for SMOTE
                                X_train = X_train.reshape(X_train.shape[0], -1)

                                # Apply SMOTE
                                smote = SMOTE(random_state=random_seed)
                                X_train, y_train = smote.fit_resample(X_train, y_train)

                                # Reshape X_train back to 3D array
                                X_train = X_train.reshape(-1, input_length, max_events + len(selected_columns) - 1)

                                # Drop the first column from X_train and X_test
                                X_train = X_train[:, :, 1:]
                                X_test = X_test[:, :, 1:]

                                ################################### Transformer ################################

                                # Define the Transformer model
                                class TransformerModel(nn.Module):
                                    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
                                        super(TransformerModel, self).__init__()
                                        self.embedding = nn.Linear(input_size, hidden_size)
                                        self.pos_encoder = nn.Embedding(input_length, hidden_size)
                                        self.transformer = nn.Transformer(hidden_size, nhead=4, num_encoder_layers=num_layers, num_decoder_layers=num_layers, dropout=dropout)
                                        self.fc = nn.Linear(hidden_size, output_size)
                                    
                                    def forward(self, x):
                                        x = self.embedding(x)
                                        positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)
                                        x = x + self.pos_encoder(positions)
                                        x = self.transformer(x, x)
                                        x = self.fc(x[:, -1, :])
                                        return x

                                # Convert data to PyTorch tensors
                                X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
                                y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
                                X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
                                y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

                                # Create DataLoader
                                train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
                                train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

                                # Initialize the model, loss function, and optimizer
                                model = TransformerModel(max_events + 4, hidden_size, num_layers, output_size, dropout)
                                criterion = nn.BCEWithLogitsLoss()  # For binary classification
                                optimizer = optim.Adam(model.parameters(), lr=learning_rate)

                                # Training loop
                                for epoch in range(num_epochs):
                                    model.train()
                                    for X_batch, y_batch in train_loader:
                                        outputs = model(X_batch)
                                        loss = criterion(outputs, y_batch)
                                        
                                        optimizer.zero_grad()
                                        loss.backward()
                                        optimizer.step()
                                    
                                    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
                                    
                                ################################### Model Eval ################################

                                # Evaluate the model on the test set
                                model.eval()
                                with torch.no_grad():
                                    test_outputs = model(X_test_tensor)
                                    test_outputs = torch.sigmoid(test_outputs)  # Apply sigmoid to get probabilities
                                    test_outputs = test_outputs.cpu().numpy()

                                    # Convert y_test_tensor to NumPy array only if it is a tensor
                                    if isinstance(y_test_tensor, torch.Tensor):
                                        y_test_tensor = y_test_tensor.cpu().numpy()

                                    test_preds = (test_outputs > 0.5).astype(int)  # Convert probabilities to binary predictions

                                # Calculate evaluation metrics
                                conf_matrix = confusion_matrix(y_test_tensor, test_preds)
                                precision = precision_score(y_test_tensor, test_preds, zero_division=0)
                                recall = recall_score(y_test_tensor, test_preds, zero_division=0)
                                accuracy = accuracy_score(y_test_tensor, test_preds)
                                f1 = f1_score(y_test_tensor, test_preds, zero_division=0)
                                tn, fp, fn, tp = conf_matrix.ravel()

                                # Append results to DataFrame
                                results_df = pd.concat([results_df, pd.DataFrame([{
                                    'Run': run_id,
                                    'Max Events': max_events,
                                    'Input Length': input_length,
                                    'Hidden Size': hidden_size,
                                    'Dropout': dropout,
                                    'Num Layers': num_layers,
                                    'Gap': gap,
                                    'Prediction Period': prediction_period,
                                    'Num Epochs': num_epochs,
                                    'Precision': precision,
                                    'Recall': recall,
                                    'Accuracy': accuracy,
                                    'F1': f1,
                                    'TN': tn,
                                    'FP': fp,
                                    'FN': fn,
                                    'TP': tp
                                }])], ignore_index=True)

                                print(f"Run {run_id} completed")
                                print("*"*100 + "\n")

# Display the results DataFrame
display(results_df)

################################### Plot Results ################################

# Set a pastel color palette
sns.set_palette("pastel")

# Plot the results
fig, axes = plt.subplots(3, 3, figsize=(20, 20))
fig.suptitle('Model Performance Metrics Over Different Runs')

metrics = ['Precision', 'Recall', 'Accuracy', 'F1', 'TN', 'FP', 'FN', 'TP']
for i, metric in enumerate(metrics):
    ax = axes[i//3, i%3]
    ax.plot(results_df['Run'], results_df[metric])
    ax.set_title(metric)
    ax.set_xlabel('Run')
    ax.set_ylabel(metric)

# Remove the last subplot
fig.delaxes(axes[2, 2])

plt.tight_layout()
plt.show()
# Out:
# Run 1: max_events=10, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6795
# Epoch [2/25], Loss: 0.6921
# Epoch [3/25], Loss: 0.6896
# Epoch [4/25], Loss: 0.6767
# Epoch [5/25], Loss: 0.6537
# Epoch [6/25], Loss: 0.7431
# Epoch [7/25], Loss: 0.6796
# Epoch [8/25], Loss: 0.7473
# Epoch [9/25], Loss: 0.7035
# Epoch [10/25], Loss: 0.6834
# Epoch [11/25], Loss: 0.6801
# Epoch [12/25], Loss: 0.6989
# Epoch [13/25], Loss: 0.7584
# Epoch [14/25], Loss: 0.7048
# Epoch [15/25], Loss: 0.7272
# Epoch [16/25], Loss: 0.6760
# Epoch [17/25], Loss: 0.6879
# Epoch [18/25], Loss: 0.7617
# Epoch [19/25], Loss: 0.6908
# Epoch [20/25], Loss: 0.7059
# Epoch [21/25], Loss: 0.6912
# Epoch [22/25], Loss: 0.7122
# Epoch [23/25], Loss: 0.6913
# Epoch [24/25], Loss: 0.6936
# Epoch [25/25], Loss: 0.6485
# Run 1 completed
# ****************************************************************************************************
#
# Run 2: max_events=10, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6795
# Epoch [2/50], Loss: 0.6921
# Epoch [3/50], Loss: 0.6896
# Epoch [4/50], Loss: 0.6767
# Epoch [5/50], Loss: 0.6537
# Epoch [6/50], Loss: 0.7431
# Epoch [7/50], Loss: 0.6796
# Epoch [8/50], Loss: 0.7473
# Epoch [9/50], Loss: 0.7035
# Epoch [10/50], Loss: 0.6834
# Epoch [11/50], Loss: 0.6801
# Epoch [12/50], Loss: 0.6989
# Epoch [13/50], Loss: 0.7584
# Epoch [14/50], Loss: 0.7048
# Epoch [15/50], Loss: 0.7272
# Epoch [16/50], Loss: 0.6760
# Epoch [17/50], Loss: 0.6879
# Epoch [18/50], Loss: 0.7617
# Epoch [19/50], Loss: 0.6908
# Epoch [20/50], Loss: 0.7059
# Epoch [21/50], Loss: 0.6912
# Epoch [22/50], Loss: 0.7122
# Epoch [23/50], Loss: 0.6913
# Epoch [24/50], Loss: 0.6936
# Epoch [25/50], Loss: 0.6485
# Epoch [26/50], Loss: 0.6976
# Epoch [27/50], Loss: 0.7310
# Epoch [28/50], Loss: 0.6860
# Epoch [29/50], Loss: 0.6873
# Epoch [30/50], Loss: 0.6796
# Epoch [31/50], Loss: 0.6936
# Epoch [32/50], Loss: 0.6843
# Epoch [33/50], Loss: 0.6772
# Epoch [34/50], Loss: 0.7504
# Epoch [35/50], Loss: 0.7226
# Epoch [36/50], Loss: 0.6754
# Epoch [37/50], Loss: 0.7141
# Epoch [38/50], Loss: 0.5772
# Epoch [39/50], Loss: 0.7299
# Epoch [40/50], Loss: 0.6999
# Epoch [41/50], Loss: 0.6602
# Epoch [42/50], Loss: 0.6480
# Epoch [43/50], Loss: 0.7188
# Epoch [44/50], Loss: 0.6988
# Epoch [45/50], Loss: 0.7133
# Epoch [46/50], Loss: 0.6677
# Epoch [47/50], Loss: 0.5554
# Epoch [48/50], Loss: 0.8061
# Epoch [49/50], Loss: 0.6094
# Epoch [50/50], Loss: 0.5376
# Run 2 completed
# ****************************************************************************************************
#
# Run 3: max_events=10, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.5970
# Epoch [2/25], Loss: 0.7474
# Epoch [3/25], Loss: 0.7002
# Epoch [4/25], Loss: 0.6945
# Epoch [5/25], Loss: 0.8375
# Epoch [6/25], Loss: 0.6842
# Epoch [7/25], Loss: 0.6986
# Epoch [8/25], Loss: 0.6887
# Epoch [9/25], Loss: 0.6836
# Epoch [10/25], Loss: 0.7100
# Epoch [11/25], Loss: 0.6932
# Epoch [12/25], Loss: 0.6988
# Epoch [13/25], Loss: 0.7214
# Epoch [14/25], Loss: 0.7057
# Epoch [15/25], Loss: 0.7296
# Epoch [16/25], Loss: 0.7090
# Epoch [17/25], Loss: 0.6734
# Epoch [18/25], Loss: 0.7174
# Epoch [19/25], Loss: 0.6884
# Epoch [20/25], Loss: 0.7297
# Epoch [21/25], Loss: 0.7300
# Epoch [22/25], Loss: 0.6865
# Epoch [23/25], Loss: 0.6858
# Epoch [24/25], Loss: 0.6790
# Epoch [25/25], Loss: 0.7101
# Run 3 completed
# ****************************************************************************************************
#
# Run 4: max_events=10, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.5970
# Epoch [2/50], Loss: 0.7474
# Epoch [3/50], Loss: 0.7002
# Epoch [4/50], Loss: 0.6945
# Epoch [5/50], Loss: 0.8375
# Epoch [6/50], Loss: 0.6842
# Epoch [7/50], Loss: 0.6986
# Epoch [8/50], Loss: 0.6887
# Epoch [9/50], Loss: 0.6836
# Epoch [10/50], Loss: 0.7100
# Epoch [11/50], Loss: 0.6932
# Epoch [12/50], Loss: 0.6988
# Epoch [13/50], Loss: 0.7214
# Epoch [14/50], Loss: 0.7057
# Epoch [15/50], Loss: 0.7296
# Epoch [16/50], Loss: 0.7090
# Epoch [17/50], Loss: 0.6734
# Epoch [18/50], Loss: 0.7174
# Epoch [19/50], Loss: 0.6884
# Epoch [20/50], Loss: 0.7297
# Epoch [21/50], Loss: 0.7300
# Epoch [22/50], Loss: 0.6865
# Epoch [23/50], Loss: 0.6858
# Epoch [24/50], Loss: 0.6790
# Epoch [25/50], Loss: 0.7101
# Epoch [26/50], Loss: 0.6940
# Epoch [27/50], Loss: 0.6750
# Epoch [28/50], Loss: 0.6938
# Epoch [29/50], Loss: 0.7193
# Epoch [30/50], Loss: 0.7009
# Epoch [31/50], Loss: 0.6840
# Epoch [32/50], Loss: 0.6907
# Epoch [33/50], Loss: 0.7072
# Epoch [34/50], Loss: 0.6863
# Epoch [35/50], Loss: 0.6899
# Epoch [36/50], Loss: 0.7039
# Epoch [37/50], Loss: 0.7040
# Epoch [38/50], Loss: 0.6800
# Epoch [39/50], Loss: 0.6970
# Epoch [40/50], Loss: 0.7090
# Epoch [41/50], Loss: 0.6765
# Epoch [42/50], Loss: 0.7102
# Epoch [43/50], Loss: 0.6745
# Epoch [44/50], Loss: 0.6972
# Epoch [45/50], Loss: 0.6846
# Epoch [46/50], Loss: 0.6863
# Epoch [47/50], Loss: 0.6706
# Epoch [48/50], Loss: 0.6956
# Epoch [49/50], Loss: 0.6957
# Epoch [50/50], Loss: 0.6941
# Run 4 completed
# ****************************************************************************************************
#
# Run 5: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6543
# Epoch [2/25], Loss: 0.5814
# Epoch [3/25], Loss: 0.7056
# Epoch [4/25], Loss: 0.7656
# Epoch [5/25], Loss: 0.6744
# Epoch [6/25], Loss: 0.6837
# Epoch [7/25], Loss: 0.6860
# Epoch [8/25], Loss: 0.7177
# Epoch [9/25], Loss: 0.6612
# Epoch [10/25], Loss: 0.6316
# Epoch [11/25], Loss: 0.6837
# Epoch [12/25], Loss: 0.5505
# Epoch [13/25], Loss: 0.5313
# Epoch [14/25], Loss: 0.7004
# Epoch [15/25], Loss: 0.7639
# Epoch [16/25], Loss: 0.6938
# Epoch [17/25], Loss: 0.7087
# Epoch [18/25], Loss: 0.6960
# Epoch [19/25], Loss: 0.7056
# Epoch [20/25], Loss: 0.7261
# Epoch [21/25], Loss: 0.6692
# Epoch [22/25], Loss: 0.7148
# Epoch [23/25], Loss: 0.5945
# Epoch [24/25], Loss: 0.6890
# Epoch [25/25], Loss: 0.6969
# Run 5 completed
# ****************************************************************************************************
#
# Run 6: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6543
# Epoch [2/50], Loss: 0.5814
# Epoch [3/50], Loss: 0.7056
# Epoch [4/50], Loss: 0.7656
# Epoch [5/50], Loss: 0.6744
# Epoch [6/50], Loss: 0.6837
# Epoch [7/50], Loss: 0.6860
# Epoch [8/50], Loss: 0.7177
# Epoch [9/50], Loss: 0.6612
# Epoch [10/50], Loss: 0.6316
# Epoch [11/50], Loss: 0.6837
# Epoch [12/50], Loss: 0.5505
# Epoch [13/50], Loss: 0.5313
# Epoch [14/50], Loss: 0.7004
# Epoch [15/50], Loss: 0.7639
# Epoch [16/50], Loss: 0.6938
# Epoch [17/50], Loss: 0.7087
# Epoch [18/50], Loss: 0.6960
# Epoch [19/50], Loss: 0.7056
# Epoch [20/50], Loss: 0.7261
# Epoch [21/50], Loss: 0.6692
# Epoch [22/50], Loss: 0.7148
# Epoch [23/50], Loss: 0.5945
# Epoch [24/50], Loss: 0.6890
# Epoch [25/50], Loss: 0.6969
# Epoch [26/50], Loss: 0.7152
# Epoch [27/50], Loss: 0.5656
# Epoch [28/50], Loss: 0.6901
# Epoch [29/50], Loss: 0.6734
# Epoch [30/50], Loss: 0.6997
# Epoch [31/50], Loss: 0.7723
# Epoch [32/50], Loss: 0.6728
# Epoch [33/50], Loss: 0.7150
# Epoch [34/50], Loss: 0.7428
# Epoch [35/50], Loss: 0.6983
# Epoch [36/50], Loss: 0.6723
# Epoch [37/50], Loss: 0.7164
# Epoch [38/50], Loss: 0.7036
# Epoch [39/50], Loss: 0.6721
# Epoch [40/50], Loss: 0.9152
# Epoch [41/50], Loss: 0.6194
# Epoch [42/50], Loss: 0.6441
# Epoch [43/50], Loss: 0.6550
# Epoch [44/50], Loss: 0.6775
# Epoch [45/50], Loss: 0.7609
# Epoch [46/50], Loss: 0.6667
# Epoch [47/50], Loss: 0.7836
# Epoch [48/50], Loss: 0.6638
# Epoch [49/50], Loss: 0.6870
# Epoch [50/50], Loss: 0.7233
# Run 6 completed
# ****************************************************************************************************
#
# Run 7: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7914
# Epoch [2/25], Loss: 0.7381
# Epoch [3/25], Loss: 0.6836
# Epoch [4/25], Loss: 0.7407
# Epoch [5/25], Loss: 0.7258
# Epoch [6/25], Loss: 0.6642
# Epoch [7/25], Loss: 0.6864
# Epoch [8/25], Loss: 0.7014
# Epoch [9/25], Loss: 0.6745
# Epoch [10/25], Loss: 0.7252
# Epoch [11/25], Loss: 0.7643
# Epoch [12/25], Loss: 0.6965
# Epoch [13/25], Loss: 0.7042
# Epoch [14/25], Loss: 0.7027
# Epoch [15/25], Loss: 0.7605
# Epoch [16/25], Loss: 0.7020
# Epoch [17/25], Loss: 0.6554
# Epoch [18/25], Loss: 0.6947
# Epoch [19/25], Loss: 0.7312
# Epoch [20/25], Loss: 0.6599
# Epoch [21/25], Loss: 0.6907
# Epoch [22/25], Loss: 0.7021
# Epoch [23/25], Loss: 0.6849
# Epoch [24/25], Loss: 0.6940
# Epoch [25/25], Loss: 0.6857
# Run 7 completed
# ****************************************************************************************************
#
# Run 8: max_events=20, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7914
# Epoch [2/50], Loss: 0.7381
# Epoch [3/50], Loss: 0.6836
# Epoch [4/50], Loss: 0.7407
# Epoch [5/50], Loss: 0.7258
# Epoch [6/50], Loss: 0.6642
# Epoch [7/50], Loss: 0.6864
# Epoch [8/50], Loss: 0.7014
# Epoch [9/50], Loss: 0.6745
# Epoch [10/50], Loss: 0.7252
# Epoch [11/50], Loss: 0.7643
# Epoch [12/50], Loss: 0.6965
# Epoch [13/50], Loss: 0.7042
# Epoch [14/50], Loss: 0.7027
# Epoch [15/50], Loss: 0.7605
# Epoch [16/50], Loss: 0.7020
# Epoch [17/50], Loss: 0.6554
# Epoch [18/50], Loss: 0.6947
# Epoch [19/50], Loss: 0.7312
# Epoch [20/50], Loss: 0.6599
# Epoch [21/50], Loss: 0.6907
# Epoch [22/50], Loss: 0.7021
# Epoch [23/50], Loss: 0.6849
# Epoch [24/50], Loss: 0.6940
# Epoch [25/50], Loss: 0.6857
# Epoch [26/50], Loss: 0.6946
# Epoch [27/50], Loss: 0.7065
# Epoch [28/50], Loss: 0.6975
# Epoch [29/50], Loss: 0.7054
# Epoch [30/50], Loss: 0.7052
# Epoch [31/50], Loss: 0.6911
# Epoch [32/50], Loss: 0.6803
# Epoch [33/50], Loss: 0.7121
# Epoch [34/50], Loss: 0.6972
# Epoch [35/50], Loss: 0.6910
# Epoch [36/50], Loss: 0.6500
# Epoch [37/50], Loss: 0.7210
# Epoch [38/50], Loss: 0.6920
# Epoch [39/50], Loss: 0.6796
# Epoch [40/50], Loss: 0.6839
# Epoch [41/50], Loss: 0.6974
# Epoch [42/50], Loss: 0.6772
# Epoch [43/50], Loss: 0.7076
# Epoch [44/50], Loss: 0.7115
# Epoch [45/50], Loss: 0.6813
# Epoch [46/50], Loss: 0.6847
# Epoch [47/50], Loss: 0.7155
# Epoch [48/50], Loss: 0.6997
# Epoch [49/50], Loss: 0.6997
# Epoch [50/50], Loss: 0.6864
# Run 8 completed
# ****************************************************************************************************
#
# Run 9: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6835
# Epoch [2/25], Loss: 0.7151
# Epoch [3/25], Loss: 0.7193
# Epoch [4/25], Loss: 0.6634
# Epoch [5/25], Loss: 0.5380
# Epoch [6/25], Loss: 0.6911
# Epoch [7/25], Loss: 0.6669
# Epoch [8/25], Loss: 0.7544
# Epoch [9/25], Loss: 0.7051
# Epoch [10/25], Loss: 0.7347
# Epoch [11/25], Loss: 0.7146
# Epoch [12/25], Loss: 0.6687
# Epoch [13/25], Loss: 0.6790
# Epoch [14/25], Loss: 0.6928
# Epoch [15/25], Loss: 0.7024
# Epoch [16/25], Loss: 0.7059
# Epoch [17/25], Loss: 0.6908
# Epoch [18/25], Loss: 0.6985
# Epoch [19/25], Loss: 0.6695
# Epoch [20/25], Loss: 0.6707
# Epoch [21/25], Loss: 0.6883
# Epoch [22/25], Loss: 0.6639
# Epoch [23/25], Loss: 0.6837
# Epoch [24/25], Loss: 0.6523
# Epoch [25/25], Loss: 0.6885
# Run 9 completed
# ****************************************************************************************************
#
# Run 10: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6835
# Epoch [2/50], Loss: 0.7151
# Epoch [3/50], Loss: 0.7193
# Epoch [4/50], Loss: 0.6634
# Epoch [5/50], Loss: 0.5380
# Epoch [6/50], Loss: 0.6911
# Epoch [7/50], Loss: 0.6669
# Epoch [8/50], Loss: 0.7544
# Epoch [9/50], Loss: 0.7051
# Epoch [10/50], Loss: 0.7347
# Epoch [11/50], Loss: 0.7146
# Epoch [12/50], Loss: 0.6687
# Epoch [13/50], Loss: 0.6790
# Epoch [14/50], Loss: 0.6928
# Epoch [15/50], Loss: 0.7024
# Epoch [16/50], Loss: 0.7059
# Epoch [17/50], Loss: 0.6908
# Epoch [18/50], Loss: 0.6985
# Epoch [19/50], Loss: 0.6695
# Epoch [20/50], Loss: 0.6707
# Epoch [21/50], Loss: 0.6883
# Epoch [22/50], Loss: 0.6639
# Epoch [23/50], Loss: 0.6837
# Epoch [24/50], Loss: 0.6523
# Epoch [25/50], Loss: 0.6885
# Epoch [26/50], Loss: 0.7160
# Epoch [27/50], Loss: 0.6650
# Epoch [28/50], Loss: 0.7030
# Epoch [29/50], Loss: 0.7107
# Epoch [30/50], Loss: 0.6841
# Epoch [31/50], Loss: 0.7176
# Epoch [32/50], Loss: 0.6939
# Epoch [33/50], Loss: 0.6893
# Epoch [34/50], Loss: 0.6947
# Epoch [35/50], Loss: 0.6860
# Epoch [36/50], Loss: 0.6728
# Epoch [37/50], Loss: 0.7047
# Epoch [38/50], Loss: 0.6618
# Epoch [39/50], Loss: 0.6993
# Epoch [40/50], Loss: 0.6867
# Epoch [41/50], Loss: 0.6881
# Epoch [42/50], Loss: 0.7023
# Epoch [43/50], Loss: 0.6808
# Epoch [44/50], Loss: 0.7049
# Epoch [45/50], Loss: 0.6825
# Epoch [46/50], Loss: 0.6553
# Epoch [47/50], Loss: 0.6853
# Epoch [48/50], Loss: 0.6825
# Epoch [49/50], Loss: 0.6871
# Epoch [50/50], Loss: 0.6777
# Run 10 completed
# ****************************************************************************************************
#
# Run 11: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7170
# Epoch [2/25], Loss: 0.7860
# Epoch [3/25], Loss: 0.7939
# Epoch [4/25], Loss: 0.6093
# Epoch [5/25], Loss: 0.6925
# Epoch [6/25], Loss: 0.6462
# Epoch [7/25], Loss: 0.6708
# Epoch [8/25], Loss: 0.6990
# Epoch [9/25], Loss: 0.8085
# Epoch [10/25], Loss: 0.6865
# Epoch [11/25], Loss: 0.7187
# Epoch [12/25], Loss: 0.6873
# Epoch [13/25], Loss: 0.6952
# Epoch [14/25], Loss: 0.6889
# Epoch [15/25], Loss: 0.6781
# Epoch [16/25], Loss: 0.6900
# Epoch [17/25], Loss: 0.6570
# Epoch [18/25], Loss: 0.6364
# Epoch [19/25], Loss: 0.6601
# Epoch [20/25], Loss: 0.6951
# Epoch [21/25], Loss: 0.6952
# Epoch [22/25], Loss: 0.7201
# Epoch [23/25], Loss: 0.6732
# Epoch [24/25], Loss: 0.7065
# Epoch [25/25], Loss: 0.6935
# Run 11 completed
# ****************************************************************************************************
#
# Run 12: max_events=30, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7170
# Epoch [2/50], Loss: 0.7860
# Epoch [3/50], Loss: 0.7939
# Epoch [4/50], Loss: 0.6093
# Epoch [5/50], Loss: 0.6925
# Epoch [6/50], Loss: 0.6462
# Epoch [7/50], Loss: 0.6708
# Epoch [8/50], Loss: 0.6990
# Epoch [9/50], Loss: 0.8085
# Epoch [10/50], Loss: 0.6865
# Epoch [11/50], Loss: 0.7187
# Epoch [12/50], Loss: 0.6873
# Epoch [13/50], Loss: 0.6952
# Epoch [14/50], Loss: 0.6889
# Epoch [15/50], Loss: 0.6781
# Epoch [16/50], Loss: 0.6900
# Epoch [17/50], Loss: 0.6570
# Epoch [18/50], Loss: 0.6364
# Epoch [19/50], Loss: 0.6601
# Epoch [20/50], Loss: 0.6951
# Epoch [21/50], Loss: 0.6952
# Epoch [22/50], Loss: 0.7201
# Epoch [23/50], Loss: 0.6732
# Epoch [24/50], Loss: 0.7065
# Epoch [25/50], Loss: 0.6935
# Epoch [26/50], Loss: 0.7173
# Epoch [27/50], Loss: 0.6991
# Epoch [28/50], Loss: 0.7125
# Epoch [29/50], Loss: 0.6971
# Epoch [30/50], Loss: 0.6810
# Epoch [31/50], Loss: 0.7131
# Epoch [32/50], Loss: 0.6398
# Epoch [33/50], Loss: 0.7343
# Epoch [34/50], Loss: 0.7484
# Epoch [35/50], Loss: 0.7033
# Epoch [36/50], Loss: 0.6980
# Epoch [37/50], Loss: 0.7024
# Epoch [38/50], Loss: 0.7049
# Epoch [39/50], Loss: 0.6849
# Epoch [40/50], Loss: 0.7089
# Epoch [41/50], Loss: 0.7039
# Epoch [42/50], Loss: 0.6850
# Epoch [43/50], Loss: 0.6861
# Epoch [44/50], Loss: 0.6757
# Epoch [45/50], Loss: 0.6942
# Epoch [46/50], Loss: 0.6911
# Epoch [47/50], Loss: 0.6901
# Epoch [48/50], Loss: 0.6958
# Epoch [49/50], Loss: 0.7029
# Epoch [50/50], Loss: 0.7082
# Run 12 completed
# ****************************************************************************************************
#
# Run 13: max_events=40, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6863
# Epoch [2/25], Loss: 0.7551
# Epoch [3/25], Loss: 0.7122
# Epoch [4/25], Loss: 0.6997
# Epoch [5/25], Loss: 0.6938
# Epoch [6/25], Loss: 0.6021
# Epoch [7/25], Loss: 0.7024
# Epoch [8/25], Loss: 0.7957
# Epoch [9/25], Loss: 0.6474
# Epoch [10/25], Loss: 0.7316
# Epoch [11/25], Loss: 0.5861
# Epoch [12/25], Loss: 1.0766
# Epoch [13/25], Loss: 0.6059
# Epoch [14/25], Loss: 0.6273
# Epoch [15/25], Loss: 0.6991
# Epoch [16/25], Loss: 0.7070
# Epoch [17/25], Loss: 0.5366
# Epoch [18/25], Loss: 0.6848
# Epoch [19/25], Loss: 0.6785
# Epoch [20/25], Loss: 0.6958
# Epoch [21/25], Loss: 0.6138
# Epoch [22/25], Loss: 0.6100
# Epoch [23/25], Loss: 1.0562
# Epoch [24/25], Loss: 0.7070
# Epoch [25/25], Loss: 0.7021
# Run 13 completed
# ****************************************************************************************************
#
# Run 14: max_events=40, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6863
# Epoch [2/50], Loss: 0.7551
# Epoch [3/50], Loss: 0.7122
# Epoch [4/50], Loss: 0.6997
# Epoch [5/50], Loss: 0.6938
# Epoch [6/50], Loss: 0.6021
# Epoch [7/50], Loss: 0.7024
# Epoch [8/50], Loss: 0.7957
# Epoch [9/50], Loss: 0.6474
# Epoch [10/50], Loss: 0.7316
# Epoch [11/50], Loss: 0.5861
# Epoch [12/50], Loss: 1.0766
# Epoch [13/50], Loss: 0.6059
# Epoch [14/50], Loss: 0.6273
# Epoch [15/50], Loss: 0.6991
# Epoch [16/50], Loss: 0.7070
# Epoch [17/50], Loss: 0.5366
# Epoch [18/50], Loss: 0.6848
# Epoch [19/50], Loss: 0.6785
# Epoch [20/50], Loss: 0.6958
# Epoch [21/50], Loss: 0.6138
# Epoch [22/50], Loss: 0.6100
# Epoch [23/50], Loss: 1.0562
# Epoch [24/50], Loss: 0.7070
# Epoch [25/50], Loss: 0.7021
# Epoch [26/50], Loss: 0.6683
# Epoch [27/50], Loss: 0.6754
# Epoch [28/50], Loss: 0.7126
# Epoch [29/50], Loss: 0.6572
# Epoch [30/50], Loss: 0.7278
# Epoch [31/50], Loss: 0.7095
# Epoch [32/50], Loss: 0.6935
# Epoch [33/50], Loss: 0.5536
# Epoch [34/50], Loss: 0.5676
# Epoch [35/50], Loss: 0.7439
# Epoch [36/50], Loss: 0.6223
# Epoch [37/50], Loss: 0.6486
# Epoch [38/50], Loss: 0.7663
# Epoch [39/50], Loss: 0.5439
# Epoch [40/50], Loss: 0.6665
# Epoch [41/50], Loss: 0.7471
# Epoch [42/50], Loss: 0.6909
# Epoch [43/50], Loss: 0.3802
# Epoch [44/50], Loss: 0.6704
# Epoch [45/50], Loss: 0.5901
# Epoch [46/50], Loss: 0.8054
# Epoch [47/50], Loss: 0.5393
# Epoch [48/50], Loss: 0.7213
# Epoch [49/50], Loss: 0.7227
# Epoch [50/50], Loss: 0.6106
# Run 14 completed
# ****************************************************************************************************
#
# Run 15: max_events=40, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.6574
# Epoch [2/25], Loss: 0.7059
# Epoch [3/25], Loss: 0.7029
# Epoch [4/25], Loss: 0.8040
# Epoch [5/25], Loss: 0.6886
# Epoch [6/25], Loss: 0.6934
# Epoch [7/25], Loss: 0.6894
# Epoch [8/25], Loss: 0.7158
# Epoch [9/25], Loss: 0.7142
# Epoch [10/25], Loss: 0.6856
# Epoch [11/25], Loss: 0.6893
# Epoch [12/25], Loss: 0.6943
# Epoch [13/25], Loss: 0.7382
# Epoch [14/25], Loss: 0.7044
# Epoch [15/25], Loss: 0.6810
# Epoch [16/25], Loss: 0.6882
# Epoch [17/25], Loss: 0.6883
# Epoch [18/25], Loss: 0.6927
# Epoch [19/25], Loss: 0.7223
# Epoch [20/25], Loss: 0.7008
# Epoch [21/25], Loss: 0.6864
# Epoch [22/25], Loss: 0.6974
# Epoch [23/25], Loss: 0.6770
# Epoch [24/25], Loss: 0.6720
# Epoch [25/25], Loss: 0.6950
# Run 15 completed
# ****************************************************************************************************
#
# Run 16: max_events=40, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.6574
# Epoch [2/50], Loss: 0.7059
# Epoch [3/50], Loss: 0.7029
# Epoch [4/50], Loss: 0.8040
# Epoch [5/50], Loss: 0.6886
# Epoch [6/50], Loss: 0.6934
# Epoch [7/50], Loss: 0.6894
# Epoch [8/50], Loss: 0.7158
# Epoch [9/50], Loss: 0.7142
# Epoch [10/50], Loss: 0.6856
# Epoch [11/50], Loss: 0.6893
# Epoch [12/50], Loss: 0.6943
# Epoch [13/50], Loss: 0.7382
# Epoch [14/50], Loss: 0.7044
# Epoch [15/50], Loss: 0.6810
# Epoch [16/50], Loss: 0.6882
# Epoch [17/50], Loss: 0.6883
# Epoch [18/50], Loss: 0.6927
# Epoch [19/50], Loss: 0.7223
# Epoch [20/50], Loss: 0.7008
# Epoch [21/50], Loss: 0.6864
# Epoch [22/50], Loss: 0.6974
# Epoch [23/50], Loss: 0.6770
# Epoch [24/50], Loss: 0.6720
# Epoch [25/50], Loss: 0.6950
# Epoch [26/50], Loss: 0.7056
# Epoch [27/50], Loss: 0.6906
# Epoch [28/50], Loss: 0.7001
# Epoch [29/50], Loss: 0.7108
# Epoch [30/50], Loss: 0.6850
# Epoch [31/50], Loss: 0.6928
# Epoch [32/50], Loss: 0.7059
# Epoch [33/50], Loss: 0.6897
# Epoch [34/50], Loss: 0.6972
# Epoch [35/50], Loss: 0.6707
# Epoch [36/50], Loss: 0.6890
# Epoch [37/50], Loss: 0.6908
# Epoch [38/50], Loss: 0.6969
# Epoch [39/50], Loss: 0.6926
# Epoch [40/50], Loss: 0.6876
# Epoch [41/50], Loss: 0.7040
# Epoch [42/50], Loss: 0.6969
# Epoch [43/50], Loss: 0.7030
# Epoch [44/50], Loss: 0.6932
# Epoch [45/50], Loss: 0.6945
# Epoch [46/50], Loss: 0.6854
# Epoch [47/50], Loss: 0.6872
# Epoch [48/50], Loss: 0.7194
# Epoch [49/50], Loss: 0.6943
# Epoch [50/50], Loss: 0.6937
# Run 16 completed
# ****************************************************************************************************
#
# Run 17: max_events=50, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7089
# Epoch [2/25], Loss: 0.6203
# Epoch [3/25], Loss: 0.6690
# Epoch [4/25], Loss: 0.7046
# Epoch [5/25], Loss: 0.7336
# Epoch [6/25], Loss: 0.6455
# Epoch [7/25], Loss: 0.7238
# Epoch [8/25], Loss: 0.6736
# Epoch [9/25], Loss: 0.6436
# Epoch [10/25], Loss: 0.7886
# Epoch [11/25], Loss: 0.6892
# Epoch [12/25], Loss: 0.5229
# Epoch [13/25], Loss: 0.6556
# Epoch [14/25], Loss: 0.7127
# Epoch [15/25], Loss: 0.5957
# Epoch [16/25], Loss: 0.6519
# Epoch [17/25], Loss: 0.6782
# Epoch [18/25], Loss: 0.7490
# Epoch [19/25], Loss: 0.6007
# Epoch [20/25], Loss: 0.4754
# Epoch [21/25], Loss: 0.6621
# Epoch [22/25], Loss: 0.7236
# Epoch [23/25], Loss: 0.5492
# Epoch [24/25], Loss: 0.7630
# Epoch [25/25], Loss: 0.6981
# Run 17 completed
# ****************************************************************************************************
#
# Run 18: max_events=50, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7089
# Epoch [2/50], Loss: 0.6203
# Epoch [3/50], Loss: 0.6690
# Epoch [4/50], Loss: 0.7046
# Epoch [5/50], Loss: 0.7336
# Epoch [6/50], Loss: 0.6455
# Epoch [7/50], Loss: 0.7238
# Epoch [8/50], Loss: 0.6736
# Epoch [9/50], Loss: 0.6436
# Epoch [10/50], Loss: 0.7886
# Epoch [11/50], Loss: 0.6892
# Epoch [12/50], Loss: 0.5229
# Epoch [13/50], Loss: 0.6556
# Epoch [14/50], Loss: 0.7127
# Epoch [15/50], Loss: 0.5957
# Epoch [16/50], Loss: 0.6519
# Epoch [17/50], Loss: 0.6782
# Epoch [18/50], Loss: 0.7490
# Epoch [19/50], Loss: 0.6007
# Epoch [20/50], Loss: 0.4754
# Epoch [21/50], Loss: 0.6621
# Epoch [22/50], Loss: 0.7236
# Epoch [23/50], Loss: 0.5492
# Epoch [24/50], Loss: 0.7630
# Epoch [25/50], Loss: 0.6981
# Epoch [26/50], Loss: 0.6563
# Epoch [27/50], Loss: 0.5781
# Epoch [28/50], Loss: 0.6840
# Epoch [29/50], Loss: 0.4785
# Epoch [30/50], Loss: 0.6841
# Epoch [31/50], Loss: 0.5567
# Epoch [32/50], Loss: 0.7097
# Epoch [33/50], Loss: 0.7509
# Epoch [34/50], Loss: 0.6814
# Epoch [35/50], Loss: 0.7476
# Epoch [36/50], Loss: 0.6760
# Epoch [37/50], Loss: 0.6252
# Epoch [38/50], Loss: 0.5706
# Epoch [39/50], Loss: 0.6343
# Epoch [40/50], Loss: 0.6024
# Epoch [41/50], Loss: 0.7057
# Epoch [42/50], Loss: 0.7288
# Epoch [43/50], Loss: 0.6771
# Epoch [44/50], Loss: 0.6592
# Epoch [45/50], Loss: 0.7388
# Epoch [46/50], Loss: 0.6712
# Epoch [47/50], Loss: 0.5964
# Epoch [48/50], Loss: 0.6832
# Epoch [49/50], Loss: 0.6105
# Epoch [50/50], Loss: 0.6722
# Run 18 completed
# ****************************************************************************************************
#
# Run 19: max_events=50, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7147
# Epoch [2/25], Loss: 0.6201
# Epoch [3/25], Loss: 0.7028
# Epoch [4/25], Loss: 0.7391
# Epoch [5/25], Loss: 0.6730
# Epoch [6/25], Loss: 0.6784
# Epoch [7/25], Loss: 0.7426
# Epoch [8/25], Loss: 0.7543
# Epoch [9/25], Loss: 0.7036
# Epoch [10/25], Loss: 0.6827
# Epoch [11/25], Loss: 0.6442
# Epoch [12/25], Loss: 0.6942
# Epoch [13/25], Loss: 0.6911
# Epoch [14/25], Loss: 0.6913
# Epoch [15/25], Loss: 0.7064
# Epoch [16/25], Loss: 0.6483
# Epoch [17/25], Loss: 0.7174
# Epoch [18/25], Loss: 0.6804
# Epoch [19/25], Loss: 0.6916
# Epoch [20/25], Loss: 0.7230
# Epoch [21/25], Loss: 0.6747
# Epoch [22/25], Loss: 0.6891
# Epoch [23/25], Loss: 0.6925
# Epoch [24/25], Loss: 0.6725
# Epoch [25/25], Loss: 0.7051
# Run 19 completed
# ****************************************************************************************************
#
# Run 20: max_events=50, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7147
# Epoch [2/50], Loss: 0.6201
# Epoch [3/50], Loss: 0.7028
# Epoch [4/50], Loss: 0.7391
# Epoch [5/50], Loss: 0.6730
# Epoch [6/50], Loss: 0.6784
# Epoch [7/50], Loss: 0.7426
# Epoch [8/50], Loss: 0.7543
# Epoch [9/50], Loss: 0.7036
# Epoch [10/50], Loss: 0.6827
# Epoch [11/50], Loss: 0.6442
# Epoch [12/50], Loss: 0.6942
# Epoch [13/50], Loss: 0.6911
# Epoch [14/50], Loss: 0.6913
# Epoch [15/50], Loss: 0.7064
# Epoch [16/50], Loss: 0.6483
# Epoch [17/50], Loss: 0.7174
# Epoch [18/50], Loss: 0.6804
# Epoch [19/50], Loss: 0.6916
# Epoch [20/50], Loss: 0.7230
# Epoch [21/50], Loss: 0.6747
# Epoch [22/50], Loss: 0.6891
# Epoch [23/50], Loss: 0.6925
# Epoch [24/50], Loss: 0.6725
# Epoch [25/50], Loss: 0.7051
# Epoch [26/50], Loss: 0.7024
# Epoch [27/50], Loss: 0.7116
# Epoch [28/50], Loss: 0.6971
# Epoch [29/50], Loss: 0.6880
# Epoch [30/50], Loss: 0.7231
# Epoch [31/50], Loss: 0.6785
# Epoch [32/50], Loss: 0.7024
# Epoch [33/50], Loss: 0.7223
# Epoch [34/50], Loss: 0.7107
# Epoch [35/50], Loss: 0.7051
# Epoch [36/50], Loss: 0.7210
# Epoch [37/50], Loss: 0.6964
# Epoch [38/50], Loss: 0.7117
# Epoch [39/50], Loss: 0.6964
# Epoch [40/50], Loss: 0.6877
# Epoch [41/50], Loss: 0.7083
# Epoch [42/50], Loss: 0.6972
# Epoch [43/50], Loss: 0.7075
# Epoch [44/50], Loss: 0.6805
# Epoch [45/50], Loss: 0.7027
# Epoch [46/50], Loss: 0.6937
# Epoch [47/50], Loss: 0.6812
# Epoch [48/50], Loss: 0.6980
# Epoch [49/50], Loss: 0.7213
# Epoch [50/50], Loss: 0.6971
# Run 20 completed
# ****************************************************************************************************
#
# Run 21: max_events=100, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7303
# Epoch [2/25], Loss: 0.6845
# Epoch [3/25], Loss: 0.6935
# Epoch [4/25], Loss: 0.7154
# Epoch [5/25], Loss: 0.6930
# Epoch [6/25], Loss: 0.6995
# Epoch [7/25], Loss: 0.6904
# Epoch [8/25], Loss: 0.6611
# Epoch [9/25], Loss: 0.7174
# Epoch [10/25], Loss: 0.6790
# Epoch [11/25], Loss: 0.7245
# Epoch [12/25], Loss: 0.6990
# Epoch [13/25], Loss: 0.6882
# Epoch [14/25], Loss: 0.7692
# Epoch [15/25], Loss: 0.5566
# Epoch [16/25], Loss: 0.6689
# Epoch [17/25], Loss: 0.6863
# Epoch [18/25], Loss: 0.6920
# Epoch [19/25], Loss: 0.5850
# Epoch [20/25], Loss: 0.6701
# Epoch [21/25], Loss: 0.6769
# Epoch [22/25], Loss: 0.6858
# Epoch [23/25], Loss: 0.7319
# Epoch [24/25], Loss: 0.5907
# Epoch [25/25], Loss: 0.6381
# Run 21 completed
# ****************************************************************************************************
#
# Run 22: max_events=100, input_length=10, hidden_size=64, dropout=0.3, num_layers=2, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7303
# Epoch [2/50], Loss: 0.6845
# Epoch [3/50], Loss: 0.6935
# Epoch [4/50], Loss: 0.7154
# Epoch [5/50], Loss: 0.6930
# Epoch [6/50], Loss: 0.6995
# Epoch [7/50], Loss: 0.6904
# Epoch [8/50], Loss: 0.6611
# Epoch [9/50], Loss: 0.7174
# Epoch [10/50], Loss: 0.6790
# Epoch [11/50], Loss: 0.7245
# Epoch [12/50], Loss: 0.6990
# Epoch [13/50], Loss: 0.6882
# Epoch [14/50], Loss: 0.7692
# Epoch [15/50], Loss: 0.5566
# Epoch [16/50], Loss: 0.6689
# Epoch [17/50], Loss: 0.6863
# Epoch [18/50], Loss: 0.6920
# Epoch [19/50], Loss: 0.5850
# Epoch [20/50], Loss: 0.6701
# Epoch [21/50], Loss: 0.6769
# Epoch [22/50], Loss: 0.6858
# Epoch [23/50], Loss: 0.7319
# Epoch [24/50], Loss: 0.5907
# Epoch [25/50], Loss: 0.6381
# Epoch [26/50], Loss: 0.6663
# Epoch [27/50], Loss: 0.6781
# Epoch [28/50], Loss: 0.6564
# Epoch [29/50], Loss: 0.7286
# Epoch [30/50], Loss: 0.7158
# Epoch [31/50], Loss: 0.7144
# Epoch [32/50], Loss: 0.6714
# Epoch [33/50], Loss: 0.6259
# Epoch [34/50], Loss: 0.6873
# Epoch [35/50], Loss: 0.5680
# Epoch [36/50], Loss: 0.7467
# Epoch [37/50], Loss: 0.6835
# Epoch [38/50], Loss: 0.8539
# Epoch [39/50], Loss: 0.5349
# Epoch [40/50], Loss: 0.7410
# Epoch [41/50], Loss: 0.6884
# Epoch [42/50], Loss: 0.7032
# Epoch [43/50], Loss: 0.6939
# Epoch [44/50], Loss: 0.6942
# Epoch [45/50], Loss: 0.6833
# Epoch [46/50], Loss: 0.7468
# Epoch [47/50], Loss: 0.7890
# Epoch [48/50], Loss: 0.7234
# Epoch [49/50], Loss: 0.7843
# Epoch [50/50], Loss: 0.7223
# Run 22 completed
# ****************************************************************************************************
#
# Run 23: max_events=100, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=25
# Epoch [1/25], Loss: 0.7955
# Epoch [2/25], Loss: 0.5681
# Epoch [3/25], Loss: 0.6851
# Epoch [4/25], Loss: 0.7438
# Epoch [5/25], Loss: 0.7014
# Epoch [6/25], Loss: 0.7118
# Epoch [7/25], Loss: 0.6931
# Epoch [8/25], Loss: 0.7122
# Epoch [9/25], Loss: 0.6776
# Epoch [10/25], Loss: 0.6632
# Epoch [11/25], Loss: 0.6866
# Epoch [12/25], Loss: 0.6598
# Epoch [13/25], Loss: 0.7032
# Epoch [14/25], Loss: 0.6980
# Epoch [15/25], Loss: 0.7025
# Epoch [16/25], Loss: 0.6872
# Epoch [17/25], Loss: 0.6774
# Epoch [18/25], Loss: 0.7110
# Epoch [19/25], Loss: 0.6821
# Epoch [20/25], Loss: 0.6767
# Epoch [21/25], Loss: 0.7042
# Epoch [22/25], Loss: 0.7026
# Epoch [23/25], Loss: 0.7070
# Epoch [24/25], Loss: 0.6876
# Epoch [25/25], Loss: 0.7205
# Run 23 completed
# ****************************************************************************************************
#
# Run 24: max_events=100, input_length=10, hidden_size=64, dropout=0.3, num_layers=4, gap=1, prediction_period=1, num_epochs=50
# Epoch [1/50], Loss: 0.7955
# Epoch [2/50], Loss: 0.5681
# Epoch [3/50], Loss: 0.6851
# Epoch [4/50], Loss: 0.7438
# Epoch [5/50], Loss: 0.7014
# Epoch [6/50], Loss: 0.7118
# Epoch [7/50], Loss: 0.6931
# Epoch [8/50], Loss: 0.7122
# Epoch [9/50], Loss: 0.6776
# Epoch [10/50], Loss: 0.6632
# Epoch [11/50], Loss: 0.6866
# Epoch [12/50], Loss: 0.6598
# Epoch [13/50], Loss: 0.7032
# Epoch [14/50], Loss: 0.6980
# Epoch [15/50], Loss: 0.7025
# Epoch [16/50], Loss: 0.6872
# Epoch [17/50], Loss: 0.6774
# Epoch [18/50], Loss: 0.7110
# Epoch [19/50], Loss: 0.6821
# Epoch [20/50], Loss: 0.6767
# Epoch [21/50], Loss: 0.7042
# Epoch [22/50], Loss: 0.7026
# Epoch [23/50], Loss: 0.7070
# Epoch [24/50], Loss: 0.6876
# Epoch [25/50], Loss: 0.7205
# Epoch [26/50], Loss: 0.6940
# Epoch [27/50], Loss: 0.6789
# Epoch [28/50], Loss: 0.6962
# Epoch [29/50], Loss: 0.6946
# Epoch [30/50], Loss: 0.7004
# Epoch [31/50], Loss: 0.6967
# Epoch [32/50], Loss: 0.6872
# Epoch [33/50], Loss: 0.7231
# Epoch [34/50], Loss: 0.6954
# Epoch [35/50], Loss: 0.6861
# Epoch [36/50], Loss: 0.6746
# Epoch [37/50], Loss: 0.6866
# Epoch [38/50], Loss: 0.7055
# Epoch [39/50], Loss: 0.7010
# Epoch [40/50], Loss: 0.6940
# Epoch [41/50], Loss: 0.7051
# Epoch [42/50], Loss: 0.6696
# Epoch [43/50], Loss: 0.6757
# Epoch [44/50], Loss: 0.6867
# Epoch [45/50], Loss: 0.6752
# Epoch [46/50], Loss: 0.6769
# Epoch [47/50], Loss: 0.7111
# Epoch [48/50], Loss: 0.6949
# Epoch [49/50], Loss: 0.6844
# Epoch [50/50], Loss: 0.7018
# Run 24 completed
# ****************************************************************************************************
#    Run Max Events Input Length Hidden Size  Dropout Num Layers Gap  \
# 0    1         10           10          64      0.3          2   1
# 1    2         10           10          64      0.3          2   1
# 2    3         10           10          64      0.3          4   1
# 3    4         10           10          64      0.3          4   1
# 4    5         20           10          64      0.3          2   1
# 5    6         20           10          64      0.3          2   1
# 6    7         20           10          64      0.3          4   1
# 7    8         20           10          64      0.3          4   1
# 8    9         30           10          64      0.3          2   1
# 9   10         30           10          64      0.3          2   1
# 10  11         30           10          64      0.3          4   1
# 11  12         30           10          64      0.3          4   1
# 12  13         40           10          64      0.3          2   1
# 13  14         40           10          64      0.3          2   1
# 14  15         40           10          64      0.3          4   1
# 15  16         40           10          64      0.3          4   1
# 16  17         50           10          64      0.3          2   1
# 17  18         50           10          64      0.3          2   1
# 18  19         50           10          64      0.3          4   1
# 19  20         50           10          64      0.3          4   1
# 20  21        100           10          64      0.3          2   1
# 21  22        100           10          64      0.3          2   1
# 22  23        100           10          64      0.3          4   1
# 23  24        100           10          64      0.3          4   1
#
#    Prediction Period Num Epochs  Precision  Recall  Accuracy        F1   TN  \
# 0                  1         25   0.082305    1.00  0.082305  0.152091    0
# 1                  1         50   0.176471    0.15  0.872428  0.162162  209
# 2                  1         25   0.082305    1.00  0.082305  0.152091    0
# 3                  1         50   0.000000    0.00  0.917695  0.000000  223
# 4                  1         25   0.000000    0.00  0.917695  0.000000  223
# 5                  1         50   0.082645    1.00  0.086420  0.152672    1
# 6                  1         25   0.000000    0.00  0.917695  0.000000  223
# 7                  1         50   0.000000    0.00  0.917695  0.000000  223
# 8                  1         25   0.082305    1.00  0.082305  0.152091    0
# 9                  1         50   0.082305    1.00  0.082305  0.152091    0
# 10                 1         25   0.082305    1.00  0.082305  0.152091    0
# 11                 1         50   0.082305    1.00  0.082305  0.152091    0
# 12                 1         25   0.000000    0.00  0.917695  0.000000  223
# 13                 1         50   0.000000    0.00  0.897119  0.000000  218
# 14                 1         25   0.082305    1.00  0.082305  0.152091    0
# 15                 1         50   0.000000    0.00  0.917695  0.000000  223
# 16                 1         25   0.000000    0.00  0.917695  0.000000  223
# 17                 1         50   0.153846    0.10  0.880658  0.121212  212
# 18                 1         25   0.082305    1.00  0.082305  0.152091    0
# 19                 1         50   0.082305    1.00  0.082305  0.152091    0
# 20                 1         25   0.000000    0.00  0.913580  0.000000  222
# 21                 1         50   0.333333    0.10  0.909465  0.153846  219
# 22                 1         25   0.082305    1.00  0.082305  0.152091    0
# 23                 1         50   0.000000    0.00  0.917695  0.000000  223
#
#      FP  FN  TP
# 0   223   0  20
# 1    14  17   3
# 2   223   0  20
# 3     0  20   0
# 4     0  20   0
# 5   222   0  20
# 6     0  20   0
# 7     0  20   0
# 8   223   0  20
# 9   223   0  20
# 10  223   0  20
# 11  223   0  20
# 12    0  20   0
# 13    5  20   0
# 14  223   0  20
# 15    0  20   0
# 16    0  20   0
# 17   11  18   2
# 18  223   0  20
# 19  223   0  20
# 20    1  20   0
# 21    4  18   2
# 22  223   0  20
# 23    0  20   0

# %% [markdown]
# # <font color = tomato> Common

# %%
# ################################### Parameters and Hyperparameters ################################

# # Parameters and Hyperparameters
# data_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/01.Full_Base/'
# input_file = f"{data_dir}/20240704__full__new_features_v1.10.parquet"
# output_dir = '/home/ubuntu/efs-w210-capstone-ebs/11.Data/01.BGL/10.20240705_StartOver_NewFeatures/02.Full_Train_Test'

# max_events = 10
# input_length = 10
# gap = 1
# prediction_period = 1
# test_size = 0.2
# shuffle = False

# hidden_size = 64
# num_layers = 2
# output_size = 1
# num_epochs = 50
# batch_size = 16
# learning_rate = 0.001
# dropout = 0.3  # Adding dropout to prevent overfitting

# # Set random seed for reproducibility
# random_seed = 42

# print("Parameters and Hyperparameters Set")
# print("*"*100 + "\n")

# ################################### Data Preprocessing ################################

# # Data Preprocessing
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import StandardScaler, LabelEncoder
# from sklearn.decomposition import PCA

# # Load the data
# df = pd.read_parquet(input_file)

# # Select derived features and a subset of EventID columns
# selected_columns = ['time_start_int', 'Class', 'unique_events', 'most_frequent_event', 'transitions', 'entropy']
# event_id_columns = [col for col in df.columns if col.startswith('EventId_')]

# # Replace -1 values with 0
# df[event_id_columns].replace(-1, 0, inplace=True)

# # Scale numerical features
# scaler = StandardScaler()
# numerical_features = ['unique_events', 'transitions', 'entropy']
# df[selected_columns[2:]] = scaler.fit_transform(df[selected_columns[2:]])

# # Encode categorical features
# label_encoder = LabelEncoder()
# df['most_frequent_event'] = label_encoder.fit_transform(df['most_frequent_event'])

# # Apply PCA to EventID columns to reduce them to 50 features
# pca = PCA(n_components=max_events)
# event_id_pca = pca.fit_transform(df[event_id_columns])

# # Create a new DataFrame with the reduced EventID features
# event_id_pca_df = pd.DataFrame(event_id_pca, columns=[f'EventId_PCA_{i+1}' for i in range(max_events)])

# # Combine the reduced EventID features with the selected columns
# df_reduced = pd.concat([df[selected_columns], event_id_pca_df], axis=1)

# print("Data Preprocessed")
# print("*"*100 + "\n")

# ################################### Create Sequences ################################

# # Function to create non-overlapping sequences
# def create_sequences(data, time_index_col, feature_cols, target_col, input_length=input_length, gap=1, prediction_period=1):
#     sequences = []
#     targets = []
    
#     start_idx = 0
#     while start_idx + input_length + gap + prediction_period <= len(data):
#         end_idx = start_idx + input_length
#         sequence = data[feature_cols].iloc[start_idx:end_idx].values
#         target = data[target_col].iloc[end_idx + gap:end_idx + gap + prediction_period].values[0]
#         sequences.append(sequence)
#         targets.append(target)
#         start_idx = end_idx + gap + prediction_period  # Move to the next non-overlapping sequence
    
#     return np.array(sequences), np.array(targets)

# # feature_cols = selected_columns + selected_event_ids
# feature_cols = [col for col in df_reduced.columns if col != 'Class']
# target_col = 'Class'

# X, y = create_sequences(df_reduced, 'time_start_int', feature_cols, target_col)

# print("Created Sequences")
# print("*"*100 + "\n")

# ################################### Split & SMOTE ################################

# # Split data into training and testing sets
# from sklearn.model_selection import train_test_split
# from imblearn.over_sampling import SMOTE

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, shuffle=shuffle)

# # Flatten X_train to 2D array for SMOTE
# X_train = X_train.reshape(X_train.shape[0], -1)

# # Apply SMOTE
# smote = SMOTE(random_state=42)
# X_train, y_train = smote.fit_resample(X_train, y_train)

# # Reshape X_train back to 3D array
# X_train = X_train.reshape(-1, input_length, max_events + 5)

# # Drop the first column from X_train and X_test
# X_train = X_train[:, :, 1:]
# X_test = X_test[:, :, 1:]

# # Save the datasets
# np.save(f'{output_dir}/X_train.npy', X_train)
# np.save(f'{output_dir}/X_test.npy', X_test)
# np.save(f'{output_dir}/y_train.npy', y_train)
# np.save(f'{output_dir}/y_test.npy', y_test)

# print("Split, SMOTE & Train/Test Saved")
# print("*"*100 + "\n")
# Out:
# Parameters and Hyperparameters Set
# ****************************************************************************************************
#
# Data Preprocessed
# ****************************************************************************************************
#
# Created Sequences
# ****************************************************************************************************
#
# Split, SMOTE & Train/Test Saved
# ****************************************************************************************************

# %% [markdown]
# ___
# # <font color = tomato> Models - Single Run

# %% [markdown]
# ## <font color = grey> LSTM

# %% [markdown]
# ---

# %%
# ################################### LSTM ################################

# # Define the LSTM model with Dropout
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import DataLoader, TensorDataset

# class LSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
#         super(LSTMModel, self).__init__()
#         self.hidden_size = hidden_size
#         self.num_layers = num_layers
#         self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
#         self.fc = nn.Linear(hidden_size, output_size)
    
#     def forward(self, x):
#         h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#         c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#         out, _ = self.lstm(x, (h0, c0))
#         out = self.fc(out[:, -1, :])
#         return out

# # Set random seeds for PyTorch
# torch.manual_seed(random_seed)
# torch.cuda.manual_seed(random_seed)
# np.random.seed(random_seed)

# # Convert data to PyTorch tensors
# X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
# X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# # Create DataLoader
# train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# # Initialize the model, loss function, and optimizer
# model = LSTMModel(max_events + 4, hidden_size, num_layers, output_size, dropout)
# criterion = nn.BCEWithLogitsLoss()  # For binary classification
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Training loop
# for epoch in range(num_epochs):
#     model.train()
#     for X_batch, y_batch in train_loader:
#         outputs = model(X_batch)
#         loss = criterion(outputs, y_batch)
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
    
#     print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    
# print("Model Trained")
# print("*"*100 + "\n")

# ################################### Model Eval ################################

# from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score

# # Evaluate the model on the test set
# model.eval()
# with torch.no_grad():
#     test_outputs = model(X_test_tensor)
#     test_outputs = torch.sigmoid(test_outputs)  # Apply sigmoid to get probabilities
#     test_outputs = test_outputs.cpu().numpy()

#     # Convert y_test_tensor to NumPy array only if it is a tensor
#     if isinstance(y_test_tensor, torch.Tensor):
#         y_test_tensor = y_test_tensor.cpu().numpy()

#     test_preds = (test_outputs > 0.5).astype(int)  # Convert probabilities to binary predictions

# # Calculate evaluation metrics
# conf_matrix = confusion_matrix(y_test_tensor, test_preds)
# precision = precision_score(y_test_tensor, test_preds)
# recall = recall_score(y_test_tensor, test_preds)
# accuracy = accuracy_score(y_test_tensor, test_preds)
# f1 = f1_score(y_test_tensor, test_preds)

# print("Confusion Matrix:\n", conf_matrix)
# print(f"Precision: {precision:.4f}")
# print(f"Recall: {recall:.4f}")
# print(f"Accuracy: {accuracy:.4f}")
# print(f"F1 Score: {f1:.4f}")

# # Visualize the confusion matrix
# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.title('Confusion Matrix')
# plt.show()

# %% [markdown]
# ## <font color = grey> Single - Transformer Model

# %% [markdown]
# ---

# %%
# ################################### Transformer ################################

# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import DataLoader, TensorDataset

# # Define the Transformer model
# class TransformerModel(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
#         super(TransformerModel, self).__init__()
#         self.embedding = nn.Linear(input_size, hidden_size)
#         self.pos_encoder = nn.Embedding(input_length, hidden_size)
#         self.transformer = nn.Transformer(hidden_size, nhead=4, num_encoder_layers=num_layers, num_decoder_layers=num_layers, dropout=dropout)
#         self.fc = nn.Linear(hidden_size, output_size)
    
#     def forward(self, x):
#         x = self.embedding(x)
#         positions = torch.arange(0, x.size(1), device=x.device).unsqueeze(0)
#         x = x + self.pos_encoder(positions)
#         x = self.transformer(x, x)
#         x = self.fc(x[:, -1, :])
#         return x

# # Set random seeds for PyTorch
# torch.manual_seed(random_seed)
# torch.cuda.manual_seed(random_seed)
# np.random.seed(random_seed)

# # Convert data to PyTorch tensors
# X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
# X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# # Create DataLoader
# train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# # Initialize the model, loss function, and optimizer
# model = TransformerModel(max_events + 4, hidden_size, num_layers, output_size, dropout)
# criterion = nn.BCEWithLogitsLoss()  # For binary classification
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Training loop
# for epoch in range(num_epochs):
#     model.train()
#     for X_batch, y_batch in train_loader:
#         outputs = model(X_batch)
#         loss = criterion(outputs, y_batch)
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
    
#     print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    
# print("Model Trained")
# print("*"*100 + "\n")

# ################################### Model Eval ################################

# from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score

# # Evaluate the model on the test set
# model.eval()
# with torch.no_grad():
#     test_outputs = model(X_test_tensor)
#     test_outputs = torch.sigmoid(test_outputs)  # Apply sigmoid to get probabilities
#     test_outputs = test_outputs.cpu().numpy()

#     # Convert y_test_tensor to NumPy array only if it is a tensor
#     if isinstance(y_test_tensor, torch.Tensor):
#         y_test_tensor = y_test_tensor.cpu().numpy()

#     test_preds = (test_outputs > 0.5).astype(int)  # Convert probabilities to binary predictions

# # Calculate evaluation metrics
# conf_matrix = confusion_matrix(y_test_tensor, test_preds)
# precision = precision_score(y_test_tensor, test_preds)
# recall = recall_score(y_test_tensor, test_preds)
# accuracy = accuracy_score(y_test_tensor, test_preds)
# f1 = f1_score(y_test_tensor, test_preds)

# print("Confusion Matrix:\n", conf_matrix)
# print(f"Precision: {precision:.4f}")
# print(f"Recall: {recall:.4f}")
# print(f"Accuracy: {accuracy:.4f}")
# print(f"F1 Score: {f1:.4f}")

# # Visualize the confusion matrix
# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.title('Confusion Matrix')
# plt.show()
