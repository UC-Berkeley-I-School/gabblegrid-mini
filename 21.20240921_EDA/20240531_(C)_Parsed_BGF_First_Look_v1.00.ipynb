# %% [markdown]
# # Initial Exploration of the parsed BGL logs

# %%
# Set display option to show the full length of the column
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Raw Data

# %%
import os
import gzip

# Determine the base directory based on the effective user ID
if os.geteuid() == 0:  # root user
    base_dir = '/root'
else:
    base_dir = '/home/sagemaker-user'

# Set the environment variable
os.environ['BASE_DIR'] = base_dir

# Verify the base directory
print(f"Base directory set to: {base_dir}")

# Define the file path
file_path = os.path.join(base_dir, '11.Data/01.BGL/01.Raw_CFDR/bgl2.gz')

# Load and read the first 10 lines of the data
with gzip.open(file_path, 'rt') as f:
    lines = [next(f).strip() for _ in range(10)]

# Print the first 10 lines to understand the structure
for i, line in enumerate(lines, start=1):
    print(f"Line {i}: {line}")
# Out:
# Base directory set to: /root
# Line 1: - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.363779 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 2: - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.527847 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 3: - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.675872 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 4: - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.823719 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 5: - 1117838570 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.50.982731 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 6: - 1117838571 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.51.131467 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 7: - 1117838571 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.51.293532 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 8: - 1117838571 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.51.428563 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 9: - 1117838571 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.51.601412 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected
# Line 10: - 1117838571 2005.06.03 R02-M1-N0-C:J12-U11 2005-06-03-15.42.51.749199 R02-M1-N0-C:J12-U11 RAS KERNEL INFO instruction cache parity error corrected

# %% [markdown]
# ## Template File

# %%
import os

# Determine the base directory based on the effective user ID
if os.geteuid() == 0:  # root user
    base_dir = '/root'
else:
    base_dir = '/home/sagemaker-user'

# Set the environment variable
os.environ['BASE_DIR'] = base_dir

# Verify the base directory
print(f"Base directory set to: {base_dir}")

# Define the file path for BGL_templates.csv
template_file_path = os.path.join(base_dir, '08.GIT_Repos_REF/02.ait-aecid/templates/BGL_templates.csv')

# Load and read the first 10 lines of the template file
with open(template_file_path, 'r') as f:
    lines = [next(f).strip() for _ in range(10)]

# Print the first 10 lines to understand the structure
for i, line in enumerate(lines, start=1):
    print(f"Line {i}: {line}")
# Out:
# Base directory set to: /root
# Line 1: <*>:<*> <*>:<*> <*>:<*> <*>:<*>
# Line 2: <*> <*> <*> BGLERR_IDO_PKT_TIMEOUT connection lost to node/link/service card
# Line 3: <*> correctable errors exceeds threshold (iar <*> lr <*>
# Line 4: <*> ddr error(s) detected and corrected on rank <*> symbol <*> over <*> seconds
# Line 5: <*> ddr errors(s) detected and corrected on rank <*> symbol <*>, bit <*>
# Line 6: <*> double-hummer alignment exceptions
# Line 7: <*> exited abnormally due to signal: Aborted
# Line 8: <*> exited normally with exit code <*>
# Line 9: <*> floating point alignment exceptions
# Line 10: <*> L3 <*> error(s) (dcr <*> detected and corrected over <*> seconds

# %%
import os
import pandas as pd

# Determine the base directory based on the effective user ID
if os.geteuid() == 0:  # root user
    base_dir = '/root'
else:
    base_dir = '/home/sagemaker-user'

# Set the environment variable
os.environ['BASE_DIR'] = base_dir

# Verify the base directory
print(f"Base directory set to: {base_dir}")

# Define the file path for BGL_templates.csv
template_file_path = os.path.join(base_dir, '08.GIT_Repos_REF/02.ait-aecid/templates/BGL_templates.csv')

# Read the file line by line into a list
with open(template_file_path, 'r') as file:
    lines = file.readlines()

# Create a DataFrame from the list
BGL_templates_df = pd.DataFrame(lines, columns=['template'])

# Display the first few lines of the DataFrame to verify the content
print(BGL_templates_df.head())
# Out:
# Base directory set to: /root
#                                                                             template
# 0                                                  <*>:<*> <*>:<*> <*>:<*> <*>:<*>\n
# 1     <*> <*> <*> BGLERR_IDO_PKT_TIMEOUT connection lost to node/link/service card\n
# 2                         <*> correctable errors exceeds threshold (iar <*> lr <*>\n
# 3  <*> ddr error(s) detected and corrected on rank <*> symbol <*> over <*> seconds\n
# 4         <*> ddr errors(s) detected and corrected on rank <*> symbol <*>, bit <*>\n

# %%
# Set display option to show the full length of the column
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)


BGL_templates_df.head(200)
# Out:
#                                                                                                                                                                                                                           template
# 0                                                                                                                                                                                                <*>:<*> <*>:<*> <*>:<*> <*>:<*>\n
# 1                                                                                                                                                   <*> <*> <*> BGLERR_IDO_PKT_TIMEOUT connection lost to node/link/service card\n
# 2                                                                                                                                                                       <*> correctable errors exceeds threshold (iar <*> lr <*>\n
# 3                                                                                                                                                <*> ddr error(s) detected and corrected on rank <*> symbol <*> over <*> seconds\n
# 4                                                                                                                                                       <*> ddr errors(s) detected and corrected on rank <*> symbol <*>, bit <*>\n
# 5                                                                                                                                                                                         <*> double-hummer alignment exceptions\n
# 6                                                                                                                                                                                   <*> exited abnormally due to signal: Aborted\n
# 7                                                                                                                                                                                         <*> exited normally with exit code <*>\n
# 8                                                                                                                                                                                        <*> floating point alignment exceptions\n
# 9                                                                                                                                                           <*> L3 <*> error(s) (dcr <*> detected and corrected over <*> seconds\n
# 10                                                                                                                                                                           <*> L3 <*> error(s) (dcr <*> detected and corrected\n
# 11                                                                          <*> microseconds spent in the rbs signal handler during <*> calls. <*> microseconds was the maximum time for a single instance of a correctable ddr.\n
# 12                                                                                                                                                                                          <*> PGOOD error latched on link card\n
# 13                                                                                                                                                                                        <*> power module <*> is not accessible\n
# 14                                                                                                                                                                                                       <*> TLB error interrupt\n
# 15                                                                                                                                                   <*> torus non-crc error(s) (dcr <*> detected and corrected over <*> seconds\n
# 16                                                                                                                                                                    <*> torus non-crc error(s) (dcr <*> detected and corrected\n
# 17                                                                                                                                                    <*> torus receiver <*> input pipe error(s) (dcr <*> detected and corrected\n
# 18                                                                                                                                   <*> torus receiver <*> input pipe error(s) (dcr <*> detected and corrected over <*> seconds\n
# 19                                                                                                                                                                <*> torus <*> <*> <*> error(s) (dcr <*> detected and corrected\n
# 20                                                                                                                                               <*> torus <*> <*> <*> error(s) (dcr <*> detected and corrected over <*> seconds\n
# 21                                                      <*> total interrupts. <*> critical input interrupts. <*> microseconds total spent on critical input interrupts, <*> microseconds max time in a critical input interrupt.\n
# 22                                                                                                                                                            <*> tree receiver <*> in re-synch state event(s) (dcr <*> detected\n
# 23                                                                                                                                           <*> tree receiver <*> in re-synch state event(s) (dcr <*> detected over <*> seconds\n
# 24                                                                                                                                                                                     Added <*> subnets and <*> addresses to DB\n
# 25                                                                                                                                                                                                       address parity error..0\n
# 26                                                                                                                                                                                 auxiliary processor.........................0\n
# 27                                                                                                                                                           Bad cable going into LinkCard <*> Jtag <*> Port <*> - <*> bad wires\n
# 28                                                                                                                                                                    BglIdoChip table has <*> IDOs with the same IP address <*>\n
# 29                                                                                                                                                               BGLMASTER FAILURE mmcs_server exited normally with exit code 13\n
# 30                                                                                                                 BGLMaster has been started: ./BGLMaster --consoleip 127.0.0.1 --consoleport 32035 --configfile bglmaster.init\n
# 31                                                                                                 BGLMaster has been started: ./BGLMaster --consoleip 127.0.0.1 --consoleport 32035 --configfile bglmaster.init --autorestart y\n
# 32                                                                       BGLMaster has been started: ./BGLMaster --consoleip 127.0.0.1 --consoleport 32035 --configfile bglmaster.init --autorestart y --db2profile /u/bgdb2cli/\n
# 33                                                                                                                                                                                 byte ordering exception.....................0\n
# 34                                                                                                                                                                                Can not get assembly information for node card\n
# 35                                                                                                                                                                                                                   capture <*>\n
# 36                                                                                                                                                                                        capture first <*> <*> error address..0\n
# 37                                                                                                                                                                                                    CE sym <*> at <*> mask <*>\n
# 38                                                                                                                                                                                         CHECK_INITIAL_GLOBAL_INTERRUPT_VALUES\n
# 39                                                                                                                                                                                                       chip select...........0\n
# 40                                                                                                                                      ciod: <*> coordinate <*> exceeds physical dimension <*> at line <*> of node map file <*>\n
# 41                                                                                                                                                                   ciod: cpu <*> at treeaddr <*> sent unrecognized message <*>\n
# 42                                                                                                                               ciod: duplicate canonical-rank <*> to logical-rank <*> mapping at line <*> of node map file <*>\n
# 43                                                                                                                                                            ciod: Error creating node map from file <*> Argument list too long\n
# 44                                                                                                                                                                       ciod: Error creating node map from file <*> Bad address\n
# 45                                                                                                                                                               ciod: Error creating node map from file <*> Bad file descriptor\n
# 46                                                                                                                                                             ciod: Error creating node map from file <*> Block device required\n
# 47                                                                                                                                                            ciod: Error creating node map from file <*> Cannot allocate memory\n
# 48                                                                                                                                                           ciod: Error creating node map from file <*> Device or resource busy\n
# 49                                                                                                                                                                ciod: Error creating node map from file <*> No child processes\n
# 50                                                                                                                                                         ciod: Error creating node map from file <*> No such file or directory\n
# 51                                                                                                                                                                 ciod: Error creating node map from file <*> Permission denied\n
# 52                                                                                                                                                  ciod: Error creating node map from file <*> Resource temporarily unavailable\n
# 53                                                                                                                                                   ciod: Error loading <*> invalid or missing program image, Exec format error\n
# 54                                                                                                                                                      ciod: Error loading <*> invalid or missing program image, No such device\n
# 55                                                                                                                                           ciod: Error loading <*> invalid or missing program image, No such file or directory\n
# 56                                                                                                                                                   ciod: Error loading <*> invalid or missing program image, Permission denied\n
# 57                                                                                                                                                                               ciod: Error loading <*> not a CNK program image\n
# 58                                                                                                                                                                      ciod: Error loading <*> program image too big, <*> > <*>\n
# 59                                                                                                                                     ciod: Error loading -mode VN: invalid or missing program image, No such file or directory\n
# 60                                                                                                                                                               ciod: Error opening node map file <*> No such file or directory\n
# 61                                                                                                                                       ciod: Error reading message prefix after <*> on CioStream socket to <*> <*> <*> <*> <*>\n
# 62                                                                                                                                        ciod: Error reading message prefix on CioStream socket to <*> Connection reset by peer\n
# 63                                                                                                                                            ciod: Error reading message prefix on CioStream socket to <*> Connection timed out\n
# 64                                                                                                                                           ciod: Error reading message prefix on CioStream socket to <*> Link has been severed\n
# 65                                                                                                                                                ciod: failed to read message prefix on control stream (CioStream socket to <*>\n
# 66                                                                                                                                                                   ciod: for node <*> incomplete data written to core file <*>\n
# 67                                                                                                                                                               ciod: for node <*> read continuation request but ioState is <*>\n
# 68                                                                                                                                                                                ciod: generated <*> core files for program <*>\n
# 69                                                                                                                                   ciod: In packet from node <*> <*> message code <*> is not <*> or 4294967295 <*> <*> <*> <*>\n
# 70                                                                                                                                            ciod: In packet from node <*> <*> message still ready for node <*> <*> <*> <*> <*>\n
# 71                                                                                                                                                                             ciod: LOGIN chdir(<*>) failed: Input/output error\n
# 72                                                                                                                                                                      ciod: LOGIN chdir(<*>) failed: No such file or directory\n
# 73                                                                                                                                                                                     ciod: LOGIN <*> failed: Permission denied\n
# 74                                                                                                                                                                               ciod: Message code <*> is not <*> or 4294967295\n
# 75                                                                                                                                                              ciod: Missing or invalid fields on line <*> of node map file <*>\n
# 76                                                                                                                                                                     ciod: pollControlDescriptors: Detected the debugger died.\n
# 77                                                                                                                                                                                         ciod: Received signal <*> <*> <*> <*>\n
# 78                                                                                                                                                    ciod: sendMsgToDebugger: error sending PROGRAM_EXITED message to debugger.\n
# 79                                                                                                                                                                         ciod: Unexpected eof at line <*> of node map file <*>\n
# 80                                                                                                                                                                                                     ciodb has been restarted.\n
# 81                                                                                                                                                                                    close EDRAM pages as soon as possible....0\n
# 82                             com.ibm.bgldevices.BulkPowerModule with VPD of com.ibm.bgldevices.BulkPowerModule$VpdReply: IBM Part Number: 53P5763, Vendor: Cherokee International, Vendor Serial Number: 4274124, Assembly <*>\n
# 83                                                                                                                                                                            command manager unit summary.....................0\n
# 84                                                                                                                                                                                                 Controlling BG/L rows [ <*> ]\n
# 85                                                                                                                                                                                              core configuration register: <*>\n
# 86                                                                                                                                                                                            Core Configuration Register 0: <*>\n
# 87                                                                                                                                                                                                               correctable <*>\n
# 88                                                                                                                                                                                   correctable error detected in directory <*>\n
# 89                                                                                                                                                                                  correctable error detected in EDRAM bank <*>\n
# 90                                                                                                                                                                                                  critical input interrupt <*>\n
# 91                                                                                                                                                                     critical input interrupt <*> <*> warning for <*> <*> wire\n
# 92                                                                                                                      critical input interrupt <*> <*> warning for torus <*> wire, suppressing further interrupts of same type\n
# 93                                                                                                                                                                                                              data <*> plb <*>\n
# 94                                                                                                                                                                                                             data address: <*>\n
# 95                                                                                                                                                                                           data address space................0\n
# 96                                                                                                                                                                   data cache <*> parity error detected. attempting to correct\n
# 97                                                                                                                                                                                                        data storage interrupt\n
# 98                                                                                                                                                                                            data store interrupt caused by <*>\n
# 99                                                                                                                                                                  data TLB error interrupt data address space................0\n
# 100                                                                                                                                                                                                  dbcr0=<*> dbsr=<*> ccr0=<*>\n
# 101                                                                                                                                                                                                       d-cache <*> parity <*>\n
# 102                                                                                                                                                                                                                DCR <*> : <*>\n
# 103                                                                                                                                                          ddr: activating redundant bit steering for next allocation: <*> <*>\n
# 104                                                                                                                                                                              ddr: activating redundant bit steering: <*> <*>\n
# 105                                                                                                                                                                    ddr: excessive soft failures, consider replacing the card\n
# 106                                                                                                                                                                                            DDR failing <*> register: <*> <*>\n
# 107                                                                                                                                                                                               DDR failing info register: <*>\n
# 108                                                                                                                                                                       DDR failing info register: DDR Fail Info Register: <*>\n
# 109                                                                                                                                                                                          DDR machine check register: <*> <*>\n
# 110                                                                                                                                                                        ddr: redundant bit steering failed, sequencer timeout\n
# 111                                                                                                                                                                                       ddr: Suppressing further CE interrupts\n
# 112                                                                                                      ddr: Unable to steer <*> <*> - rank is already steering symbol <*> Due to multiple symbols being over the correctable e\n
# 113                                                           ddr: Unable to steer <*> <*> - rank is already steering symbol <*> Due to multiple symbols being over the correctable error threshold, consider replacing the card\n
# 114                                                                                                        ddr: Unable to steer <*> <*> - rank is already steering symbol <*> Due to multiple symbols being over the correctable\n
# 115                                                                                                                                                                                             ddrSize == <*> || ddrSize == <*>\n
# 116                                                                                                                                                                                          debug interrupt enable............0\n
# 117                                                                                                                                                                                          debug wait enable.................0\n
# 118                                                                                                                                                    DeclareServiceNetworkCharacteristics has been run but the DB is not empty\n
# 119                                                                                                                              DeclareServiceNetworkCharacteristics has been run with the force option but the DB is not empty\n
# 120                                                                                                                                                                                   disable all access to cache directory....0\n
# 121                                                                                                                                                                                   disable apu instruction broadcast........0\n
# 122                                                                                                                                                                       disable flagging of DDR UE's as major internal error.0\n
# 123                                                                                                                                                                                   disable speculative access...............0\n
# 124                                                                                                                                                                                   disable store gathering..................0\n
# 125                                                                                                                                                                                   disable trace broadcast..................0\n
# 126                                                                                                                                                                                   disable write lines 2:4..................0\n
# 127                                                                                                                                                                                                           divide-by-zero <*>\n
# 128                                                                                                                                                                                              enable <*> exceptions.........0\n
# 129                                                                                                                                                                                   enable invalid operation exceptions......0\n
# 130                                                                                                                                                                                   enable non-IEEE mode.....................0\n
# 131                                                                                                                                                                                   enabled exception summary................0\n
# 132                                                                                                                                                                               EndServiceAction <*> performed upon <*> by <*>\n
# 133                                                                                                                                                                           EndServiceAction <*> was performed upon <*> by <*>\n
# 134                                                                                                                                   EndServiceAction is restarting the <*> cards in Midplane <*> as part of Service Action <*>\n
# 135                                                                                                                                         EndServiceAction is restarting the <*> in midplane <*> as part of Service Action <*>\n
# 136                                                                                                                Error getting detailed hw info for node, caught java.io.IOException: Problems with the chip, clear all resets\n
# 137                                                                                                  Error getting detailed hw info for node, caught java.io.IOException: Problems with the chip, could not enable clock domains\n
# 138                                                                                                       Error getting detailed hw info for node, caught java.io.IOException: Problems with the chip, could not pull all resets\n
# 139                                                                                                               Error receiving packet on tree network, expecting type <*> instead of type <*> <*> <*> <*> <*> <*> <*> <*> <*>\n
# 140                                                                                                                Error receiving packet on tree network, packet index <*> greater than max 366 <*> <*> <*> <*> <*> <*> <*> <*>\n
# 141                                                                                                                                                   Error sending packet on tree network, packet at address <*> is not aligned\n
# 142                                                                                                                                                                                 error threshold, consider replacing the card\n
# 143                                                                                                                                                                                            Error: unable to mount filesystem\n
# 144                                                                                                                                                                                                                exception <*>\n
# 145                                                                                                                                                                                             Exception Syndrome Register: <*>\n
# 146                                                                                                                                                                                            exception syndrome register: <*> \n
# 147                                                                                                                                    Expected 10 active FanModules, but found 9 ( Found <*> <*> <*> <*> <*> <*> <*> <*> <*> ).\n
# 148                                                                                                                                                                                                 external input interrupt <*>\n
# 149                                                                                                                                                       external input interrupt <*> <*> <*> tree receiver <*> in resynch mode\n
# 150                                                                                                                                      external input interrupt <*> <*> number of corrected SRAM errors has exceeded threshold\n
# 151                                                                                         external input interrupt <*> <*> number of corrected SRAM errors has exceeded threshold, suppressing further interrupts of same type\n
# 152                                                                                                                                         external input interrupt <*> <*> torus sender <*> retransmission error was corrected\n
# 153                                                                                                                                                          external input interrupt <*> <*> tree header with no target waiting\n
# 154                                                                                                                                                                   external input interrupt <*> <*> uncorrectable torus error\n
# 155                                                                                                                                                                                                           floating point <*>\n
# 156                                                                                                                                                                                                    floating point instr. <*>\n
# 157                                                                                                                                                                                                    Floating Point Registers:\n
# 158                                                                                                                                                                              Floating Point Status and Control Register: <*>\n
# 159                                                                                                                                                                                         floating point unavailable interrupt\n
# 160                                                                                                                                                                                                  floating pt ex mode <*> <*>\n
# 161                                                                                                                                                                                   force load/store alignment...............0\n
# 162                                                                                                                                         Found invalid node ecid in processor card slot <*> ecid 0000000000000000000000000000\n
# 163                                                                                                                                                                                                       fpr<*>=<*> <*> <*> <*>\n
# 164                                                                                                                                                                                                                 fraction <*>\n
# 165                                                                                                                                                                                                   General Purpose Registers:\n
# 166                                                                                                                                                                                                   general purpose registers:\n
# 167                                                                                                                                                                                                               generating <*>\n
# 168                                                                                              gister: machine state register: machine state register: machine state register: machine state register: machine state register:\n
# 169                                                                                                                                                                                               guaranteed <*> cache block <*>\n
# 170                                                                          Hardware monitor caught java.lang.IllegalStateException: while executing I2C Operation caught java.net.SocketException: Broken pipe and is stopping\n
# 171                                                                                                                                                Hardware monitor caught java.net.SocketException: Broken pipe and is stopping\n
# 172                                                                                                                                                                                                             iar <*> dear <*>\n
# 173                                                                                                                                                                                          i-cache parity error..............0\n
# 174                                                                                                                                                                                                          icache prefetch <*>\n
# 175                                                                                                                                                         Ido chip status changed: <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*>\n
# 176                                                                                                                                                                                                           Ido packet timeout\n
# 177                                                                                                                                                                                idoproxy communication failure: socket closed\n
# 178                                                                                                                idoproxydb has been started: $Name: <*> $ Input parameters: -enableflush -loguserinfo db.properties BlueGene1\n
# 179                                                             idoproxydb hit ASSERT condition: ASSERT expression=<*> Source file=<*> Source line=<*> Function=<*> IdoTransportMgr::SendPacket(IdoUdpMgr<*>, BglCtlPavTrace<*>)\n
# 180                                idoproxydb hit ASSERT condition: ASSERT expression=!(nMsgLen > 0x10000) Source file=idomarshalerio.cpp Source line=1929 Function=int IdoMarshalerRecvBuffer::ReadBlock(IdoMsg::IdoMsgHdr<*>&)\n
# 181                                                             idoproxydb hit ASSERT condition: ASSERT expression=pTargetMgr Source file=idoclientmgr.cpp Source line=353 Function=int IdoClientMgr::TargetClose(const char<*>)\n
# 182                                               idoproxydb hit ASSERT condition: ASSERT expression=!(RecvMsgHdr.ulLen > 0x10000) Source file=idomarshalerio.cpp Source line=387 Function=virtual int IdoMarshalerIo::RunRecv()\n
# 183                                                                                                                                                                                                        imprecise machine <*>\n
# 184                                                                                                                                                                                                                  inexact <*>\n
# 185                          instance of a correctable ddr. RAS KERNEL INFO <*> microseconds spent in the rbs signal handler during <*> calls. <*> microseconds was the maximum time for a single instance of a correctable ddr.\n
# 186                                                                                                                                                                                                     instruction address: <*>\n
# 187                                                                                                                                                                                          instruction address space.........0\n
# 188                                                                                                                                                                                     instruction cache parity error corrected\n
# 189                                                                                                                                                                                                          instruction plb <*>\n
# 190                                                                                                                                                                                                      interrupt threshold...0\n
# 191                                                                                                                                                                                                                  invalid <*>\n
# 192                                                                                                                                                                                              invalid operation exception <*>\n
# 193                                                                                                                                                                                              job <*> timed out. Block freed.\n
# 194  <*>Kernel detected <*> integer alignment exceptions <*> iar <*> dear <*> <*> iar <*> dear <*> <*> iar <*> dear <*> <*> iar <*> dear <*> <*> iar <*> dear <*> <*> iar <*> dear <*> <*> iar <*> dear <*> <*> iar <*> dear <*>\n
# 195                                                                                                                                                                                                                 kernel panic\n
# 196                                                                                                                                  L1 DCACHE summary averages: #ofDirtyLines: <*> out of 1024 #ofDirtyDblWord: <*> out of 4096\n
# 197                                                                                                                                                                                                     L3 <*> <*> register: <*>\n
# 198                                                                                                                                                                                                      L3 major internal error\n
# 199                                                                                                                                                                                             LinkCard is not fully functional\n

# %% [markdown]
# ## Parsed Data

# %%
import pandas as pd

# Define the file path
# parsed_file_path = '/home/sagemaker-user/11.Data/01.BGL/03.Parsed_CFDR/parsed.csv'
parsed_file_path = '/root/11.Data/01.BGL/03.Parsed_CFDR/parsed.csv'

# Load the data into a DataFrame
df = pd.read_csv(parsed_file_path, sep=';')

# Display basic information about the DataFrame
print("Basic Information:")
print(df.info())
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4747963 entries, 0 to 4747962
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   id          int64
#  1   event_type  int64
#  2   seq_id      object
#  3   time        float64
#  4   label       object
#  5   eventlabel  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 217.3+ MB
# None

# %%
# Display the first few lines of the DataFrame
print("\nFirst few lines:")
print(df.head())
# Out:
# First few lines:
#    id  event_type               seq_id          time    label eventlabel
# 0   1         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 1   2         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 2   3         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 3   4         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 4   5         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal

# %%
df.head(20)
# Out:
#     id  event_type               seq_id          time    label eventlabel
# 0    1         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 1    2         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 2    3         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 3    4         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 4    5         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 5    6         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 6    7         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 7    8         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 8    9         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 9   10         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 10  11         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 11  12         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 12  13         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 13  14         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 14  15         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 15  16         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 16  17         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 17  18         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 18  19         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal
# 19  20         189  R02-M1-N0-C:J12-U11  1.117813e+09  Anomaly     Normal

# %%
# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#                  id    event_type          time
# count  4.747963e+06  4.747963e+06  4.747963e+06
# mean   2.373982e+06  1.271027e+02  1.123975e+09
# std    1.370619e+06  8.594136e+01  5.226260e+06
# min    1.000000e+00  1.000000e+00  1.117813e+09
# 25%    1.186992e+06  3.800000e+01  1.120121e+09
# 50%    2.373982e+06  1.680000e+02  1.121574e+09
# 75%    3.560972e+06  1.680000e+02  1.128723e+09
# max    4.747963e+06  4.010000e+02  1.136362e+09

# %%
# Count unique values in each column
print("\nUnique Values Count:")
print(df.nunique())
# Out:
# Unique Values Count:
# id            4747963
# event_type        394
# seq_id          69251
# time          4747955
# label               2
# eventlabel         44
# dtype: int64
