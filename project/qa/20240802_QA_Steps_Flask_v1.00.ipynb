# %% [markdown]
# ![image.png](attachment:45d6bd25-5717-4bcc-ab39-1310f5c9f699.png)

# %% [markdown]
# ![image.png](attachment:99712353-0da4-48dc-9db9-4eea4149ebae.png)

# %% [markdown]
# ![image.png](attachment:d6c2a465-d369-42d0-8f64-11a997fd1b7d.png)

# %% [markdown]
# ![image.png](attachment:0614e774-589d-42e5-bbaf-872bdd9bdeec.png)

# %% [markdown]
# ![image.png](attachment:98a2c5d2-e4d0-41d2-a26d-c8417c0764c4.png)
