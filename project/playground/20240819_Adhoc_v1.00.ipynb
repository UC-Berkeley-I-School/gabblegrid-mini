# %%
import pandas as pd

# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Specify the file path
parquet_file = '/home/ubuntu/efs-w210-capstone-ebs/00.GabbleGrid/project/admin/01.Templates/A-Template_Detail.parquet'

# Load the Parquet file into a DataFrame
df = pd.read_parquet(parquet_file)

# Display the head (first few rows) of the DataFrame
# print("Head of the DataFrame:")
# display(df.head())

# Display the tail (last few rows) of the DataFrame
print("\nTail of the DataFrame:")
display(df.tail(10))
# Out:
# Tail of the DataFrame:
#            Experiment  Sample  Max_Events  Input_Length  Gap  \
# 21003  20240823153147       1           5            20    1
# 21004  20240823153147       2           5            20    1
# 21005  20240823153147       3           5            20    1
# 21006  20240823153147       4           5            20    1
# 21007  20240823153147       5           5            20    1
# 21008  20240823153147       6           5            20    1
# 21009  20240823153147       7           5            20    1
# 21010  20240823153147       8           5            20    1
# 21011  20240823153147       9           5            20    1
# 21012  20240823153147      10           5            20    1
#
#        Prediction_Period       Exp_Start_Time  Num_Tests  \
# 21003                  1  2005-11-08 16:10:00         10
# 21004                  1  2005-11-08 16:10:00         10
# 21005                  1  2005-11-08 16:10:00         10
# 21006                  1  2005-11-08 16:10:00         10
# 21007                  1  2005-11-08 16:10:00         10
# 21008                  1  2005-11-08 16:10:00         10
# 21009                  1  2005-11-08 16:10:00         10
# 21010                  1  2005-11-08 16:10:00         10
# 21011                  1  2005-11-08 16:10:00         10
# 21012                  1  2005-11-08 16:10:00         10
#
#                                               Model_Name  Precision  Recall  \
# 21003  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21004  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21005  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21006  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21007  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21008  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21009  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21010  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21011  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
# 21012  20240712_Transformers_Non_Overlapping_run_11_o...        0.0     0.0
#
#        Accuracy  F1_Score  TN  FP  FN  TP  Total_Seq_Start  Total_Seq_End  \
# 21003       1.0       0.0  10   0   0   0            11615          11636
# 21004       1.0       0.0  10   0   0   0            11637          11658
# 21005       1.0       0.0  10   0   0   0            11659          11680
# 21006       1.0       0.0  10   0   0   0            11681          11702
# 21007       1.0       0.0  10   0   0   0            11703          11724
# 21008       1.0       0.0  10   0   0   0            11725          11746
# 21009       1.0       0.0  10   0   0   0            11747          11768
# 21010       1.0       0.0  10   0   0   0            11769          11790
# 21011       1.0       0.0  10   0   0   0            11791          11812
# 21012       1.0       0.0  10   0   0   0            11813          11834
#
#        Source_Seq_Start  Source_Seq_End  Gap_Seq_Start  Gap_Seq_End  \
# 21003             11615           11634          11635        11635
# 21004             11637           11656          11657        11657
# 21005             11659           11678          11679        11679
# 21006             11681           11700          11701        11701
# 21007             11703           11722          11723        11723
# 21008             11725           11744          11745        11745
# 21009             11747           11766          11767        11767
# 21010             11769           11788          11789        11789
# 21011             11791           11810          11811        11811
# 21012             11813           11832          11833        11833
#
#        Prediction_Seq_Start  Prediction_Seq_End  Predicted  Actual  \
# 21003                 11636               11636          0     0.0
# 21004                 11658               11658          0     0.0
# 21005                 11680               11680          0     0.0
# 21006                 11702               11702          0     0.0
# 21007                 11724               11724          0     0.0
# 21008                 11746               11746          0     0.0
# 21009                 11768               11768          0     0.0
# 21010                 11790               11790          0     0.0
# 21011                 11812               11812          0     0.0
# 21012                 11834               11834          0     0.0
#
#         Sample_Start_Time  Class  unique_events  most_frequent_event  \
# 21003 2005-11-08 16:10:00      0              1                   68
# 21004 2005-11-08 22:55:00      0              1                  231
# 21005 2005-11-09 11:15:00      0              1                  763
# 21006 2005-11-09 16:55:00      0              7                  776
# 21007 2005-11-10 06:45:00      0              3                  246
# 21008 2005-11-10 16:20:00      0              3                   95
# 21009 2005-11-10 23:00:00      0              2                  108
# 21010 2005-11-11 08:10:00      0              1                   68
# 21011 2005-11-11 16:15:00      0              1                  231
# 21012 2005-11-12 03:05:00      0              7                  504
#
#        transitions   entropy  hour_of_day  day_of_week  event_count  \
# 21003            0  0.000000           16            1            1
# 21004            0  0.000000           22            1            1
# 21005            0  0.000000           11            2            2
# 21006           34  1.901381           16            2           57
# 21007            2  1.098612            6            3            3
# 21008            2  1.098612           16            3           12
# 21009            1  0.348832           23            3         4608
# 21010            0  0.000000            8            4            2
# 21011            0  0.000000           16            4            2
# 21012           12  1.838799            3            5           21
#
#        top_event_frequency  prev_event_count  transition_rate  \
# 21003                35433               8.0         0.000000
# 21004                35433               2.0         0.000000
# 21005                35433               1.0         0.000000
# 21006                35415            4609.0         0.596491
# 21007                35433               2.0         0.666667
# 21008                35433              13.0         0.166667
# 21009                35433             266.0         0.000217
# 21010                35433              28.0         0.000000
# 21011                35433               2.0         0.000000
# 21012                35427              19.0         0.571429
#
#        high_transition_rate  prev_entropy  entropy_change  \
# 21003                     0      0.000000        0.000000
# 21004                     0      0.693147       -0.693147
# 21005                     0      0.000000        0.000000
# 21006                     1      0.350804        1.550577
# 21007                     1      0.693147        0.405465
# 21008                     0      1.377820       -0.279207
# 21009                     0      1.586548       -1.237716
# 21010                     0      1.617696       -1.617696
# 21011                     0      0.000000        0.000000
# 21012                     1      1.430103        0.408696
#
#        rolling_event_count  rolling_unique_event_count  \
# 21003                 26.0                        10.0
# 21004                  6.0                        11.0
# 21005                 12.0                        10.0
# 21006              18945.0                        25.0
# 21007                644.0                        25.0
# 21008                 62.0                        27.0
# 21009               4886.0                        49.0
# 21010                384.0                        30.0
# 21011                  9.0                        11.0
# 21012                635.0                        65.0
#
#                         runtime_most_frequent_consl_text  \
# 21003  "ciod: generated  core files for program ", "C...
# 21004  "ddr: Unable to steer rank=, symbol= - rank is...
# 21005  " tree receiver  in re-synch state event(s) (d...
# 21006  " torus receiver  input pipe error(s) (dcr ) d...
# 21007  "critical input interrupt (unit= bit=): warnin...
# 21008  " ddr errors(s) detected and corrected on rank...
# 21009  "iar  dear ", "CE sym , at , mask ", " ddr err...
# 21010  "ciod: generated  core files for program ", "T...
# 21011  "ddr: Unable to steer rank=, symbol= - rank is...
# 21012  "   error(s) (dcr ) detected and corrected", "...
#
#                        runtime_least_frequent_consl_text
# 21003  "ciod: generated  core files for program ", "C...
# 21004  "ddr: Unable to steer rank=, symbol= - rank is...
# 21005  " tree receiver  in re-synch state event(s) (d...
# 21006  " torus receiver  input pipe error(s) (dcr ) d...
# 21007  "critical input interrupt (unit= bit=): warnin...
# 21008  " ddr errors(s) detected and corrected on rank...
# 21009  "iar  dear ", "CE sym , at , mask ", " ddr err...
# 21010  "ciod: generated  core files for program ", "T...
# 21011  "ddr: Unable to steer rank=, symbol= - rank is...
# 21012  "   error(s) (dcr ) detected and corrected", "...
