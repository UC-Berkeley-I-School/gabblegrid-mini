# %%
import pandas as pd

# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Specify the file path
parquet_file = '/home/ubuntu/efs-w210-capstone-ebs/00.GabbleGrid/project/admin/01.Templates/A-Template_Detail.parquet'

# Load the Parquet file into a DataFrame
df = pd.read_parquet(parquet_file)

# Display the head (first few rows) of the DataFrame
# print("Head of the DataFrame:")
# display(df.head())

# Display the tail (last few rows) of the DataFrame
print("\nTail of the DataFrame:")
display(df.tail(10))
# Out:
# Tail of the DataFrame:
#            Experiment  Sample  Max_Events  Input_Length  Gap  \
# 22594  20240902180726       4           5            30    3
# 22595  20240902180726       5           5            30    3
# 22596  20240902180726       6           5            30    3
# 22597  20240902180726       7           5            30    3
# 22598  20240902180726       8           5            30    3
# 22599  20240902180726       9           5            30    3
# 22600  20240902180726      10           5            30    3
# 22601  20240902180726      11           5            30    3
# 22602  20240902180726      12           5            30    3
# 22603  20240902180726      13           5            30    3
#
#        Prediction_Period       Exp_Start_Time  Num_Tests  \
# 22594                  1  2005-12-24 00:55:00         13
# 22595                  1  2005-12-24 00:55:00         13
# 22596                  1  2005-12-24 00:55:00         13
# ...
