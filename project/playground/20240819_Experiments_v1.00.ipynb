# %%
import pandas as pd

# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Specify the file path
parquet_file = '/home/ubuntu/efs-w210-capstone-ebs/00.GabbleGrid/project/admin/01.Templates/A-Template_Detail.parquet'

# Load the Parquet file into a DataFrame
df = pd.read_parquet(parquet_file)

# Display the head (first few rows) of the DataFrame
# print("Head of the DataFrame:")
# display(df.head())

# Display the tail (last few rows) of the DataFrame
print("\nTail of the DataFrame:")
display(df.tail(10))
# Out:
# Tail of the DataFrame:
#            Experiment  Sample  Max_Events  Input_Length  Gap  \
# 22560  20240829015952      12          40            30    2
# 22561  20240829015952      13          40            30    2
# 22562  20240829015952      14          40            30    2
# 22563  20240829015952      15          40            30    2
# 22564  20240829015952      16          40            30    2
# 22565  20240829015952      17          40            30    2
# 22566  20240829015952      18          40            30    2
# 22567  20240829015952      19          40            30    2
# 22568  20240829015952      20          40            30    2
# 22569  20240829015952      21          40            30    2
#
#        Prediction_Period       Exp_Start_Time  Num_Tests  \
# 22560                  1  2005-12-18 00:05:00         21
# 22561                  1  2005-12-18 00:05:00         21
# 22562                  1  2005-12-18 00:05:00         21
# 22563                  1  2005-12-18 00:05:00         21
# 22564                  1  2005-12-18 00:05:00         21
# 22565                  1  2005-12-18 00:05:00         21
# 22566                  1  2005-12-18 00:05:00         21
# 22567                  1  2005-12-18 00:05:00         21
# 22568                  1  2005-12-18 00:05:00         21
# 22569                  1  2005-12-18 00:05:00         21
#
#                                               Model_Name  Precision  Recall  \
# 22560  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22561  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22562  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22563  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22564  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22565  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22566  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22567  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22568  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22569  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
#
#        Accuracy  F1_Score  TN  FP  FN  TP  Total_Seq_Start  Total_Seq_End  \
# 22560       1.0       1.0  20   0   0   1            14200          14232
# 22561       1.0       1.0  20   0   0   1            14233          14265
# 22562       1.0       1.0  20   0   0   1            14266          14298
# 22563       1.0       1.0  20   0   0   1            14299          14331
# 22564       1.0       1.0  20   0   0   1            14332          14364
# 22565       1.0       1.0  20   0   0   1            14365          14397
# 22566       1.0       1.0  20   0   0   1            14398          14430
# 22567       1.0       1.0  20   0   0   1            14431          14463
# 22568       1.0       1.0  20   0   0   1            14464          14496
# 22569       1.0       1.0  20   0   0   1            14497          14529
#
#        Source_Seq_Start  Source_Seq_End  Gap_Seq_Start  Gap_Seq_End  \
# 22560             14200           14229          14230        14231
# 22561             14233           14262          14263        14264
# 22562             14266           14295          14296        14297
# 22563             14299           14328          14329        14330
# 22564             14332           14361          14362        14363
# 22565             14365           14394          14395        14396
# 22566             14398           14427          14428        14429
# 22567             14431           14460          14461        14462
# 22568             14464           14493          14494        14495
# 22569             14497           14526          14527        14528
#
#        Prediction_Seq_Start  Prediction_Seq_End  Predicted  Actual  \
# 22560                 14232               14232          0     0.0
# 22561                 14265               14265          0     0.0
# 22562                 14298               14298          0     0.0
# 22563                 14331               14331          0     0.0
# 22564                 14364               14364          0     0.0
# 22565                 14397               14397          1     1.0
# 22566                 14430               14430          0     0.0
# 22567                 14463               14463          0     0.0
# 22568                 14496               14496          0     0.0
# 22569                 14529               14529          0     0.0
#
#         Sample_Start_Time  Class  unique_events  most_frequent_event  \
# 22560 2005-12-26 19:00:00      0              1                  228
# 22561 2005-12-26 21:45:00      0              1                  228
# 22562 2005-12-27 00:30:00      0              1                  228
# 22563 2005-12-27 03:10:00      0              1                  228
# 22564 2005-12-27 06:10:00      0              1                  228
# 22565 2005-12-28 06:25:00      1             57                  561
# 22566 2005-12-29 12:05:00      0              6                  193
# 22567 2005-12-31 14:15:00      0              2                  976
# 22568 2006-01-02 18:30:00      0              5                   68
# 22569 2006-01-03 11:45:00      0              3                  193
#
#        transitions   entropy  hour_of_day  day_of_week  event_count  \
# 22560            0  0.000000           19            0          182
# 22561            0  0.000000           21            0          154
# 22562            0  0.000000            0            1          197
# 22563            0  0.000000            3            1          136
# 22564            0  0.000000            6            1          158
# 22565           70  3.393212            6            2          156
# 22566           84  1.654873           12            3          110
# 22567            1  0.693147           14            5            2
# 22568            6  0.238469           18            0          268
# 22569           16  0.964963           11            1           18
#
#        top_event_frequency  prev_event_count  transition_rate  \
# 22560                35433             199.0         0.000000
# 22561                35433             249.0         0.000000
# 22562                35433              94.0         0.000000
# 22563                35433             208.0         0.000000
# 22564                35433             148.0         0.000000
# 22565                35344              10.0         0.448718
# 22566                35416               2.0         0.763636
# 22567                35433              67.0         0.500000
# 22568                35431              10.0         0.022388
# 22569                35433              16.0         0.888889
#
#        high_transition_rate  prev_entropy  entropy_change  \
# 22560                     0      0.000000        0.000000
# 22561                     0      0.000000        0.000000
# 22562                     0      0.000000        0.000000
# 22563                     0      0.000000        0.000000
# 22564                     0      0.000000        0.000000
# 22565                     0      0.639032        2.754180
# 22566                     1      0.693147        0.961726
# 22567                     0      1.350037       -0.656890
# 22568                     0      1.609438       -1.370969
# 22569                     1      0.983274       -0.018311
#
#        rolling_event_count  rolling_unique_event_count  \
# 22560               1037.0                        10.0
# 22561               1042.0                        10.0
# 22562               1096.0                        10.0
# 22563                898.0                        10.0
# 22564                765.0                        10.0
# 22565                268.0                        77.0
# 22566                115.0                        16.0
# 22567                157.0                        21.0
# 22568                406.0                        29.0
# 22569                 77.0                        20.0
#
#                         runtime_most_frequent_consl_text  \
# 22560         "instruction cache parity error corrected"
# 22561         "instruction cache parity error corrected"
# 22562         "instruction cache parity error corrected"
# 22563         "instruction cache parity error corrected"
# 22564  "instruction cache parity error corrected", " ...
# 22565  "ciod: Error reading message prefix on CioStre...
# 22566  " ddr error(s) detected and corrected on rank ...
# 22567  "ddr: activating redundant bit steering for ne...
# 22568  "ciod: generated  core files for program ", "i...
# 22569  " ddr error(s) detected and corrected on rank ...
#
#                        runtime_least_frequent_consl_text
# 22560         "instruction cache parity error corrected"
# 22561         "instruction cache parity error corrected"
# 22562         "instruction cache parity error corrected"
# 22563         "instruction cache parity error corrected"
# 22564  "instruction cache parity error corrected", " ...
# 22565  "ciod: Error reading message prefix on CioStre...
# 22566  " ddr error(s) detected and corrected on rank ...
# 22567  "ddr: activating redundant bit steering for ne...
# 22568  "ciod: generated  core files for program ", "i...
# 22569  " ddr error(s) detected and corrected on rank ...
