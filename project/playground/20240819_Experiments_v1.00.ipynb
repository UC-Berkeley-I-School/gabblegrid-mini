# %%
import pandas as pd

# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Specify the file path
parquet_file = '/home/ubuntu/efs-w210-capstone-ebs/00.GabbleGrid/project/admin/01.Templates/A-Template_Detail.parquet'

# Load the Parquet file into a DataFrame
df = pd.read_parquet(parquet_file)

# Display the head (first few rows) of the DataFrame
# print("Head of the DataFrame:")
# display(df.head())

# Display the tail (last few rows) of the DataFrame
print("\nTail of the DataFrame:")
display(df.tail(10))
# Out:
# Tail of the DataFrame:
#            Experiment  Sample  Max_Events  Input_Length  Gap  \
# 21648  20240824003115       4           5            30    3
# 21649  20240824003115       5           5            30    3
# 21650  20240824003115       6           5            30    3
# 21651  20240824003115       7           5            30    3
# 21652  20240824003115       8           5            30    3
# 21653  20240824003115       9           5            30    3
# 21654  20240824003115      10           5            30    3
# 21655  20240824003115      11           5            30    3
# 21656  20240824003115      12           5            30    3
# 21657  20240824003115      13           5            30    3
#
#        Prediction_Period       Exp_Start_Time  Num_Tests  \
# 21648                  1  2005-12-24 00:55:00         13
# 21649                  1  2005-12-24 00:55:00         13
# 21650                  1  2005-12-24 00:55:00         13
# 21651                  1  2005-12-24 00:55:00         13
# 21652                  1  2005-12-24 00:55:00         13
# 21653                  1  2005-12-24 00:55:00         13
# 21654                  1  2005-12-24 00:55:00         13
# 21655                  1  2005-12-24 00:55:00         13
# 21656                  1  2005-12-24 00:55:00         13
# 21657                  1  2005-12-24 00:55:00         13
#
#                                               Model_Name  Precision  Recall  \
# 21648  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21649  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21650  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21651  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21652  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21653  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21654  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21655  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21656  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
# 21657  20240712_Transformers_Non_Overlapping_run_25_o...        0.5     1.0
#
#        Accuracy  F1_Score  TN  FP  FN  TP  Total_Seq_Start  Total_Seq_End  \
# 21648  0.923077  0.666667  11   1   0   1            14172          14205
# 21649  0.923077  0.666667  11   1   0   1            14206          14239
# 21650  0.923077  0.666667  11   1   0   1            14240          14273
# 21651  0.923077  0.666667  11   1   0   1            14274          14307
# 21652  0.923077  0.666667  11   1   0   1            14308          14341
# 21653  0.923077  0.666667  11   1   0   1            14342          14375
# 21654  0.923077  0.666667  11   1   0   1            14376          14409
# 21655  0.923077  0.666667  11   1   0   1            14410          14443
# 21656  0.923077  0.666667  11   1   0   1            14444          14477
# 21657  0.923077  0.666667  11   1   0   1            14478          14511
#
#        Source_Seq_Start  Source_Seq_End  Gap_Seq_Start  Gap_Seq_End  \
# 21648             14172           14201          14202        14204
# 21649             14206           14235          14236        14238
# 21650             14240           14269          14270        14272
# 21651             14274           14303          14304        14306
# 21652             14308           14337          14338        14340
# 21653             14342           14371          14372        14374
# 21654             14376           14405          14406        14408
# 21655             14410           14439          14440        14442
# 21656             14444           14473          14474        14476
# 21657             14478           14507          14508        14510
#
#        Prediction_Seq_Start  Prediction_Seq_End  Predicted  Actual  \
# 21648                 14205               14205          0     0.0
# 21649                 14239               14239          0     0.0
# 21650                 14273               14273          0     0.0
# 21651                 14307               14307          0     0.0
# 21652                 14341               14341          1     0.0
# 21653                 14375               14375          0     0.0
# 21654                 14409               14409          0     0.0
# 21655                 14443               14443          0     0.0
# 21656                 14477               14477          1     1.0
# 21657                 14511               14511          0     0.0
#
#         Sample_Start_Time  Class  unique_events  most_frequent_event  \
# 21648 2005-12-26 16:40:00      0              1                  228
# 21649 2005-12-26 19:30:00      0              1                  228
# 21650 2005-12-26 22:20:00      0              1                  228
# 21651 2005-12-27 01:10:00      0              1                  228
# 21652 2005-12-27 03:55:00      0              1                  228
# 21653 2005-12-27 07:00:00      0              1                  228
# 21654 2005-12-28 10:45:00      0              2                  193
# 21655 2005-12-29 23:25:00      0              3                  236
# 21656 2006-01-01 08:30:00      0              1                  328
# 21657 2006-01-03 08:25:00      0              1                  228
#
#        transitions   entropy  hour_of_day  day_of_week  event_count  \
# 21648            0  0.000000           16            0          185
# 21649            0  0.000000           19            0          253
# 21650            0  0.000000           22            0          197
# 21651            0  0.000000            1            1          192
# 21652            0  0.000000            3            1            1
# 21653            0  0.000000            7            1          148
# 21654            1  0.693147           10            2            2
# 21655            2  1.098612           23            3            3
# 21656            0  0.000000            8            6           32
# 21657            0  0.000000            8            1            1
#
#        top_event_frequency  prev_event_count  transition_rate  \
# 21648                35433             257.0         0.000000
# 21649                35433             210.0         0.000000
# 21650                35433             191.0         0.000000
# 21651                35433             193.0         0.000000
# 21652                35433               2.0         0.000000
# 21653                35433             102.0         0.000000
# 21654                35433              10.0         0.500000
# 21655                35433               6.0         0.666667
# 21656                35433               8.0         0.000000
# 21657                35433               1.0         0.000000
#
#        high_transition_rate  prev_entropy  entropy_change  \
# 21648                     0      0.000000        0.000000
# 21649                     0      0.000000        0.000000
# 21650                     0      0.000000        0.000000
# 21651                     0      0.000000        0.000000
# 21652                     0      0.000000        0.000000
# 21653                     0      0.000000        0.000000
# 21654                     0      1.054920       -0.361773
# 21655                     1      1.242453       -0.143841
# 21656                     0      1.559581       -1.559581
# 21657                     0      0.000000        0.000000
#
#        rolling_event_count  rolling_unique_event_count  \
# 21648               1157.0                        10.0
# 21649               1102.0                        10.0
# 21650                953.0                        10.0
# 21651                974.0                        10.0
# 21652                203.0                        10.0
# 21653                676.0                        10.0
# 21654                106.0                        21.0
# 21655                191.0                        27.0
# 21656                 54.0                        20.0
# 21657                  6.0                        10.0
#
#                         runtime_most_frequent_consl_text  \
# 21648         "instruction cache parity error corrected"
# 21649         "instruction cache parity error corrected"
# 21650         "instruction cache parity error corrected"
# 21651         "instruction cache parity error corrected"
# 21652         "instruction cache parity error corrected"
# 21653  "instruction cache parity error corrected", " ...
# 21654  " ddr error(s) detected and corrected on rank ...
# 21655  "ddr: Suppressing further CE interrupts", "dat...
# 21656  "ciod: Error loading  invalid or missing progr...
# 21657  "instruction cache parity error corrected", " ...
#
#                        runtime_least_frequent_consl_text
# 21648         "instruction cache parity error corrected"
# 21649         "instruction cache parity error corrected"
# 21650         "instruction cache parity error corrected"
# 21651         "instruction cache parity error corrected"
# 21652         "instruction cache parity error corrected"
# 21653  "instruction cache parity error corrected", " ...
# 21654  " ddr error(s) detected and corrected on rank ...
# 21655  "ddr: Suppressing further CE interrupts", "dat...
# 21656  "ciod: Error loading  invalid or missing progr...
# 21657  "instruction cache parity error corrected", " ...
