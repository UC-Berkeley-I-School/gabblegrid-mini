# %%
import pandas as pd

# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Specify the file path
parquet_file = '/home/ubuntu/efs-w210-capstone-ebs/00.GabbleGrid/project/admin/01.Templates/A-Template_Detail.parquet'

# Load the Parquet file into a DataFrame
df = pd.read_parquet(parquet_file)

# Display the head (first few rows) of the DataFrame
# print("Head of the DataFrame:")
# display(df.head())

# Display the tail (last few rows) of the DataFrame
print("\nTail of the DataFrame:")
display(df.tail(10))
# Out:
# Tail of the DataFrame:
#            Experiment  Sample  Max_Events  Input_Length  Gap  \
# 22374  20240828004804      12          40            30    2
# 22375  20240828004804      13          40            30    2
# 22376  20240828004804      14          40            30    2
# 22377  20240828004804      15          40            30    2
# 22378  20240828004804      16          40            30    2
# 22379  20240828004804      17          40            30    2
# 22380  20240828004804      18          40            30    2
# 22381  20240828004804      19          40            30    2
# 22382  20240828004804      20          40            30    2
# 22383  20240828004804      21          40            30    2
#
#        Prediction_Period       Exp_Start_Time  Num_Tests  \
# 22374                  1  2005-12-18 00:05:00         21
# 22375                  1  2005-12-18 00:05:00         21
# 22376                  1  2005-12-18 00:05:00         21
# 22377                  1  2005-12-18 00:05:00         21
# 22378                  1  2005-12-18 00:05:00         21
# 22379                  1  2005-12-18 00:05:00         21
# 22380                  1  2005-12-18 00:05:00         21
# 22381                  1  2005-12-18 00:05:00         21
# 22382                  1  2005-12-18 00:05:00         21
# 22383                  1  2005-12-18 00:05:00         21
#
#                                               Model_Name  Precision  Recall  \
# 22374  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22375  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22376  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22377  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22378  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22379  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22380  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22381  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22382  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
# 22383  20240712_Transformers_Non_Overlapping_run_143_...        1.0     1.0
#
#        Accuracy  F1_Score  TN  FP  FN  TP  Total_Seq_Start  Total_Seq_End  \
# 22374       1.0       1.0  20   0   0   1            14200          14232
# 22375       1.0       1.0  20   0   0   1            14233          14265
# 22376       1.0       1.0  20   0   0   1            14266          14298
# 22377       1.0       1.0  20   0   0   1            14299          14331
# 22378       1.0       1.0  20   0   0   1            14332          14364
# 22379       1.0       1.0  20   0   0   1            14365          14397
# 22380       1.0       1.0  20   0   0   1            14398          14430
# 22381       1.0       1.0  20   0   0   1            14431          14463
# 22382       1.0       1.0  20   0   0   1            14464          14496
# 22383       1.0       1.0  20   0   0   1            14497          14529
#
#        Source_Seq_Start  Source_Seq_End  Gap_Seq_Start  Gap_Seq_End  \
# 22374             14200           14229          14230        14231
# 22375             14233           14262          14263        14264
# 22376             14266           14295          14296        14297
# 22377             14299           14328          14329        14330
# 22378             14332           14361          14362        14363
# 22379             14365           14394          14395        14396
# 22380             14398           14427          14428        14429
# 22381             14431           14460          14461        14462
# 22382             14464           14493          14494        14495
# 22383             14497           14526          14527        14528
#
#        Prediction_Seq_Start  Prediction_Seq_End  Predicted  Actual  \
# 22374                 14232               14232          0     0.0
# 22375                 14265               14265          0     0.0
# 22376                 14298               14298          0     0.0
# 22377                 14331               14331          0     0.0
# 22378                 14364               14364          0     0.0
# 22379                 14397               14397          1     1.0
# 22380                 14430               14430          0     0.0
# 22381                 14463               14463          0     0.0
# 22382                 14496               14496          0     0.0
# 22383                 14529               14529          0     0.0
#
#         Sample_Start_Time  Class  unique_events  most_frequent_event  \
# 22374 2005-12-26 19:00:00      0              1                  228
# 22375 2005-12-26 21:45:00      0              1                  228
# 22376 2005-12-27 00:30:00      0              1                  228
# 22377 2005-12-27 03:10:00      0              1                  228
# 22378 2005-12-27 06:10:00      0              1                  228
# 22379 2005-12-28 06:25:00      1             57                  561
# 22380 2005-12-29 12:05:00      0              6                  193
# 22381 2005-12-31 14:15:00      0              2                  976
# 22382 2006-01-02 18:30:00      0              5                   68
# 22383 2006-01-03 11:45:00      0              3                  193
#
#        transitions   entropy  hour_of_day  day_of_week  event_count  \
# 22374            0  0.000000           19            0          182
# 22375            0  0.000000           21            0          154
# 22376            0  0.000000            0            1          197
# 22377            0  0.000000            3            1          136
# 22378            0  0.000000            6            1          158
# 22379           70  3.393212            6            2          156
# 22380           84  1.654873           12            3          110
# 22381            1  0.693147           14            5            2
# 22382            6  0.238469           18            0          268
# 22383           16  0.964963           11            1           18
#
#        top_event_frequency  prev_event_count  transition_rate  \
# 22374                35433             199.0         0.000000
# 22375                35433             249.0         0.000000
# 22376                35433              94.0         0.000000
# 22377                35433             208.0         0.000000
# 22378                35433             148.0         0.000000
# 22379                35344              10.0         0.448718
# 22380                35416               2.0         0.763636
# 22381                35433              67.0         0.500000
# 22382                35431              10.0         0.022388
# 22383                35433              16.0         0.888889
#
#        high_transition_rate  prev_entropy  entropy_change  \
# 22374                     0      0.000000        0.000000
# 22375                     0      0.000000        0.000000
# 22376                     0      0.000000        0.000000
# 22377                     0      0.000000        0.000000
# 22378                     0      0.000000        0.000000
# 22379                     0      0.639032        2.754180
# 22380                     1      0.693147        0.961726
# 22381                     0      1.350037       -0.656890
# 22382                     0      1.609438       -1.370969
# 22383                     1      0.983274       -0.018311
#
#        rolling_event_count  rolling_unique_event_count  \
# 22374               1037.0                        10.0
# 22375               1042.0                        10.0
# 22376               1096.0                        10.0
# 22377                898.0                        10.0
# 22378                765.0                        10.0
# 22379                268.0                        77.0
# 22380                115.0                        16.0
# 22381                157.0                        21.0
# 22382                406.0                        29.0
# 22383                 77.0                        20.0
#
#                         runtime_most_frequent_consl_text  \
# 22374         "instruction cache parity error corrected"
# 22375         "instruction cache parity error corrected"
# 22376         "instruction cache parity error corrected"
# 22377         "instruction cache parity error corrected"
# 22378  "instruction cache parity error corrected", " ...
# 22379  "ciod: Error reading message prefix on CioStre...
# 22380  " ddr error(s) detected and corrected on rank ...
# 22381  "ddr: activating redundant bit steering for ne...
# 22382  "ciod: generated  core files for program ", "i...
# 22383  " ddr error(s) detected and corrected on rank ...
#
#                        runtime_least_frequent_consl_text
# 22374         "instruction cache parity error corrected"
# 22375         "instruction cache parity error corrected"
# 22376         "instruction cache parity error corrected"
# 22377         "instruction cache parity error corrected"
# 22378  "instruction cache parity error corrected", " ...
# 22379  "ciod: Error reading message prefix on CioStre...
# 22380  " ddr error(s) detected and corrected on rank ...
# 22381  "ddr: activating redundant bit steering for ne...
# 22382  "ciod: generated  core files for program ", "i...
# 22383  " ddr error(s) detected and corrected on rank ...
