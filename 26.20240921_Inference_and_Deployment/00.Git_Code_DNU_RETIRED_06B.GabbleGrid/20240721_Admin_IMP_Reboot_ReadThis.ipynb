# %% [markdown]
# ![image.png](attachment:7e391a79-2458-4b73-9343-e370e9cb64dc.png)

# %% [markdown]
# ![image.png](attachment:68d4d87e-5746-4332-84dd-b551f8cdaa8f.png)

# %% [markdown]
# ---
# ![image.png](attachment:a48a28d0-f330-4774-850b-36d32c332763.png)
# ![image.png](attachment:50674444-8ccd-4888-bd1d-fa2aa7714ccf.png)
