# %%
# sudo journalctl -u gabblegrid.service -f

# %%
# sudo journalctl -u gabblegrid.service -b

# --> for batch (if after the fact)

# %%
# sudo systemctl restart gabblegrid.service

# %% [markdown]
# ![image.png](attachment:d36ba68a-2dc0-4662-a6b0-0b93258f3e2e.png)

# %% [markdown]
# ### /etc/systemd/system/gabblegrid.service
