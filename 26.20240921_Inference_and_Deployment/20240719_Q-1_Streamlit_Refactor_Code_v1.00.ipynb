# %% [markdown]
# # <font color = salmon> Refactor GOLD Code into different Files

# %% [markdown]
# ## <font color = grey> 20240720_streamlit_dynamic_v2.50_GOLD_Save_This.py

# %% [markdown]
# ---
# ![image.png](attachment:0469aa1b-0ea2-4d94-88a4-9f7ea7b2b862.png)
# ---

# %% [markdown]
# ---
# 2005-11-08 18:50:00
#
# 2005-12-01 16:50:00
#
# 2005-12-01 16:50:00
# ___

# %% [markdown]
# ___
#
# ![image.png](attachment:ca90f4f4-fd90-4cab-a01e-171ef387dc99.png)
# ____
